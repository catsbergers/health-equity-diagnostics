# %% [markdown]
# <h1>Geocoding Notebook - Liberian - Holcomb Edits<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Packages-and-functions" data-toc-modified-id="Packages-and-functions-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Packages and functions</a></span></li><li><span><a href="#Prepare-and-match-admin-boundary-data" data-toc-modified-id="Prepare-and-match-admin-boundary-data-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Prepare and match admin boundary data</a></span><ul class="toc-item"><li><span><a href="#Match-health-list-admin-names-to-shapefile-admin-names" data-toc-modified-id="Match-health-list-admin-names-to-shapefile-admin-names-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Match health list admin names to shapefile admin names</a></span><ul class="toc-item"><li><span><a href="#Match-orgunitlevel4-to-Geob-Adm-3" data-toc-modified-id="Match-orgunitlevel4-to-Geob-Adm-3-2.1.1"><span class="toc-item-num">2.1.1&nbsp;&nbsp;</span>Match orgunitlevel4 to Geob Adm 3</a></span></li><li><span><a href="#Match-orgunitlevel3-to-Geob-Adm-2" data-toc-modified-id="Match-orgunitlevel3-to-Geob-Adm-2-2.1.2"><span class="toc-item-num">2.1.2&nbsp;&nbsp;</span>Match orgunitlevel3 to Geob Adm 2</a></span></li><li><span><a href="#Match-orgunitlevel2-to-Geob-Adm-1" data-toc-modified-id="Match-orgunitlevel2-to-Geob-Adm-1-2.1.3"><span class="toc-item-num">2.1.3&nbsp;&nbsp;</span>Match orgunitlevel2 to Geob Adm 1</a></span></li></ul></li></ul></li><li><span><a href="#Match-to-locations-from-alternative-sources-based-on-facility-name" data-toc-modified-id="Match-to-locations-from-alternative-sources-based-on-facility-name-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Match to locations from alternative sources based on facility name</a></span><ul class="toc-item"><li><span><a href="#Health-Sites-IO" data-toc-modified-id="Health-Sites-IO-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Health Sites IO</a></span></li><li><span><a href="#Health-Sites-IO-using-orgunitlevel-5-name" data-toc-modified-id="Health-Sites-IO-using-orgunitlevel-5-name-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Health Sites IO using orgunitlevel 5 name</a></span></li></ul></li><li><span><a href="#Geocoding-with-APIs" data-toc-modified-id="Geocoding-with-APIs-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Geocoding with APIs</a></span><ul class="toc-item"><li><span><a href="#Facility-name-and-admin-3-names" data-toc-modified-id="Facility-name-and-admin-3-names-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Facility name and admin 3 names</a></span></li><li><span><a href="#Facility-name-and-admin-2-names" data-toc-modified-id="Facility-name-and-admin-2-names-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Facility name and admin 2 names</a></span></li><li><span><a href="#Facility-name-and-admin-1-names" data-toc-modified-id="Facility-name-and-admin-1-names-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Facility name and admin 1 names</a></span></li><li><span><a href="#Orgunitlevel5-names" data-toc-modified-id="Orgunitlevel5-names-4.4"><span class="toc-item-num">4.4&nbsp;&nbsp;</span>Orgunitlevel5 names</a></span></li><li><span><a href="#Orgunitlevel4-names" data-toc-modified-id="Orgunitlevel4-names-4.5"><span class="toc-item-num">4.5&nbsp;&nbsp;</span>Orgunitlevel4 names</a></span></li><li><span><a href="#Admin-3--and-admin-2-names" data-toc-modified-id="Admin-3--and-admin-2-names-4.6"><span class="toc-item-num">4.6&nbsp;&nbsp;</span>Admin 3  and admin 2 names</a></span></li><li><span><a href="#Admin-3--and-admin-1-names" data-toc-modified-id="Admin-3--and-admin-1-names-4.7"><span class="toc-item-num">4.7&nbsp;&nbsp;</span>Admin 3  and admin 1 names</a></span></li></ul></li><li><span><a href="#Map-and-save-results" data-toc-modified-id="Map-and-save-results-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Map and save results</a></span><ul class="toc-item"><li><span><a href="#Join-attributes-from-adminsitrative-polygons" data-toc-modified-id="Join-attributes-from-adminsitrative-polygons-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Join attributes from adminsitrative polygons</a></span></li></ul></li></ul></div>

# %% [markdown]
# Version: March 23, 2023
#
# This notebook works with health facilities from the HMIS Database and attempts to geolocate them, by joining them to administrative shapefiles, other sources of geo-located health facilities, and running queries with geocoding APIs.
#
# **Data Sources**
# - Health facilities (hierarchy list)
# - Geoboundaries (Adm1 through 4)
# - FEWS Admin-2 boundaries (updated post 2017)
# - Health Sites IO
# - RHINoVision Master Facility List Decision Support System

# %% [markdown]
# # Packages and functions

# %%
import os, sys
import geopandas as gpd
import jellyfish
import pandas as pd
from geopy.geocoders import GeoNames, Nominatim, Bing, GoogleV3
from shapely.geometry import Point
from tqdm import tqdm
from thefuzz import fuzz
from thefuzz import process
import matplotlib.pyplot as plt
from string import ascii_uppercase
import contextily as ctx
from os.path import join
from dotenv import load_dotenv, find_dotenv

# %%
from ctypes.util import find_library
find_library('c')
# Out:
# '/usr/lib/libc.dylib'

# %%
def remove_words(data_frame, column_name, words_to_remove = ['community', 'clinic', 'centre', 'center', 'hospital', 'health', 'government']):
    """ Remove words from strings in a specified column
    
    Args:
        data_frame: Pandas data frame
        column_name: Column name to remove words from
        words_to_remove: List of words

    Returns:
        Removes words in place

    """
    for word in words_to_remove:
        data_frame[column_name] = data_frame[column_name].str.replace(word, "")
    data_frame[column_name] = data_frame[column_name].str.strip()
        
def report_geocoding(records):
    """ Report value counts and % from geocoding_method column.
    
    Args:
        records: Pandas data frame

    Returns:
        Table with count stats 
    """
    table = records[['NAME', 'geocoding_method']].groupby('geocoding_method').count().rename(columns={'NAME':'count'})
    table.loc[:, "pct"] = table/(table['count'].sum())
    table = table.style.format({
        'pct': '{:,.1%}'.format,
    })
    return(table)

def match_name(name, list_names, min_score=0):
    """ Uses fuzzy matching between one string and a list of candidate names.
    
    Args:
        name: string
        list_names: list of candidate names to match
        min_score: minimum score allowed

    Returns:
        Returns name with the highest match, and match score
        If no match is higher than min score, returns "" and -1
    """
    # -1 score incase we don't get any matches
    max_score = -1
    # Returning empty name for no match as well
    max_name = ""
    # Iterating over all names in the other
    for name2 in list_names:
        #Finding fuzzy match score
        score = fuzz.ratio(name, name2)
        phon1 = jellyfish.soundex(name)
        phon2 = jellyfish.soundex(name2)
        phon_score = fuzz.ratio(phon1, phon2)
        print(f"{name} vs {name2}: phon: {phon_score}, fuzzy: {score}")
        winning_score = phon_score if (phon_score >= score and phon_score > 50) else score
        # Checking if we are above our threshold and have a better score
        if (winning_score > min_score) & (winning_score > max_score):
            max_name = name2
            max_score = winning_score
    return (max_name, max_score)

def match_to_closest(row, gdf, column='ADMIN2'):
    """ Spatial join using closest distance algorithm.
    
    Args:
        row: row from geo data frame
        gdf: gdf with attributes to join
        column: attribute to join

    Returns:
        Returns specified attribute of closest feature
    """
    distances = [row.geometry.distance(pol) for pol in gdf.geometry]
    min_id = np.argmin(distances)
    closest = gdf.iloc[min_id]
    return closest[column]

def run_geocoding(idx, row, master_table, admin_area, components, country_code):
    """
    Geocoding workflow to be applied to each row in a dataset
    
    Args:
        idx: index
        row: row with index and names to geocode
        master_table: master table to store results
        admin_area: gdf of admin area to ensure result falls within
        components: list of names of attributes to use in query
        country_code: two letter iso code
    
    Returns:
        Stores geocoding results in master_table object
    """
    admin_bounds = admin_area.bounds
    bb = [(admin_bounds.iloc[0].miny, admin_bounds.iloc[0].minx), (admin_bounds.iloc[0].maxy, admin_bounds.iloc[0].maxx)]
    method = ' and '.join(components)
    items = [row[item] for item in components]
    query = ', '.join(items)
    
    geocoding_result = None
    geocoding_method = "None"
    # Try Geocoding with OSM
    try:
        res = geolocator_osm.geocode(query, country_codes=country_code)
        # if within admin
        if admin_area.contains(Point(res.longitude,res.latitude)).values[0] == True:
            geocoding_result = res
            geocoding_method = f"{method} query OSM"
        else:
            raise Exception("OSM point not valid or not within polygon")
    except:
        # Try Geocoding with Bing Maps
        try:
            res = geolocator_bing.geocode(query)
            # if within admin
            if admin_area.contains(Point(res.longitude,res.latitude)).values[0] == True:
                geocoding_result = res
                geocoding_method = f"{method} query Bing"
            else:
                raise Exception("Bing point not valid or not within polygon")
        except:
            # Try Geocoding with Google
            try:
                res = geolocator_google.geocode(query = query, region = country_code, bounds = bb)
                if res:
                    # if within admin
                    if admin_area.contains(Point(res.longitude,res.latitude)).values[0] == True:
                        geocoding_result = res
                        geocoding_method = f"{method} query Google"
            except:
                raise Exception("Google point not valid or not within polygon")
    
    master_table.loc[idx, "geocoding_method"] = geocoding_method
    if geocoding_result:
        master_table.loc[idx, "longitude"] = res.longitude
        master_table.loc[idx, "latitude"] = res.latitude

# %% [markdown]
# # Prepare and match admin boundary data

# %%
iso3 = "LBR"
country = "Liberia"
input_dir = "/Users/dianaholcomb/Documents/GWU/6501_Capstone/workspace/data"
output_dir = join(input_dir, "output", iso3)
# if not os.path.exists(out_folder):
#     os.mkdir(out_folder)

# %%
# geob4 = gpd.read_file(f"https://github.com/wmgeolab/geoBoundaries/raw/b7dd6a5/releaseData/gbOpen/{iso3}/ADM4/geoBoundaries-{iso3}-ADM4.geojson")
# geob3 = gpd.read_file(f"https://github.com/wmgeolab/geoBoundaries/raw/b7dd6a5/releaseData/gbOpen/{iso3}/ADM3/geoBoundaries-{iso3}-ADM3.geojson")
geob2 = gpd.read_file(f"https://github.com/wmgeolab/geoBoundaries/raw/b7dd6a5/releaseData/gbOpen/{iso3}/ADM2/geoBoundaries-{iso3}-ADM2.geojson")
geob1 = gpd.read_file(f"https://github.com/wmgeolab/geoBoundaries/raw/b7dd6a5/releaseData/gbOpen/{iso3}/ADM1/geoBoundaries-{iso3}-ADM1.geojson")

# %%
fig, ax = plt.subplots(1, 2, figsize=(10,10))
# geob4.boundary.plot(ax=ax[0, 0], color='black', linewidth=0.5).set_axis_off()
# geob3.boundary.plot(ax=ax[0, 1], color='black', linewidth=1).set_axis_off()
geob2.boundary.plot(ax=ax[0], color='black').set_axis_off()
geob1.boundary.plot(ax=ax[1], color='black').set_axis_off()
# plt.axis('off')

# %%
master_table = pd.read_csv(os.path.join(input_dir, "liberia2022-11-15.csv"), low_memory=False)

# %%
len(master_table)
# Out:
# 72008

# %%
master_table.head(2)
# Out:
#   orgunitlevel1 orgunitlevel2      orgunitlevel3       orgunitlevel4  \
# 0       Liberia         Sinoe  Tarjuwon District  Gbason Town Clinic
# 1       Liberia         Sinoe  Tarjuwon District  Gbason Town Clinic
#
#   organisationunitid organisationunitname organisationunitcode  \
# 0        DAmhVvbzEl6   Gbason Town Clinic               LR5GZ3
# 1        DAmhVvbzEl6   Gbason Town Clinic               LR5GZ3
#
#   organisationunitdescription  periodid   periodname  periodcode  \
# 0                         NaN    202207    July 2022      202207
# 1                         NaN    202208  August 2022      202208
#
#    perioddescription       dataid             dataname datacode  \
# 0                NaN  OEkmu8lM1lr  OPD new cases total      NaN
# 1                NaN  OEkmu8lM1lr  OPD new cases total      NaN
#
#   datadescription  Total date_downloaded
# 0             NaN   20.0      2022-11-15
# 1             NaN   93.0      2022-11-15

# %%
master_table.drop(['periodid','periodname','periodcode','perioddescription','dataid','dataname',
                                  'datacode','datadescription','Total','date_downloaded'], axis=1, inplace=True)

# %%
master_table.drop_duplicates(subset=['orgunitlevel2','orgunitlevel3','orgunitlevel4','organisationunitid',
                                      'organisationunitname'], keep='first', inplace=True)
master_table.reset_index(inplace=True)

# %%
len(master_table)
# Out:
# 848

# %%
print(f"Unique Level 2: {len(master_table.orgunitlevel2.unique())}")
print(f"Unique Level 3: {len(master_table.orgunitlevel3.unique())}")
print(f"Unique Level 4: {len(master_table.orgunitlevel4.unique())}")
print(f"Unique Level 5: {len(master_table.organisationunitname.unique())}")
# Out:
# Unique Level 2: 15
# Unique Level 3: 93
# Unique Level 4: 846
# Unique Level 5: 846

# %%
print(f"Unique Geoboundaries Adm 1: {len(geob1)}")
print(f"Unique Geoboundaries Adm 2: {len(geob2)}")
# Out:
# Unique Geoboundaries Adm 1: 15
# Unique Geoboundaries Adm 2: 136

# %% [markdown]
# ## Match health list admin names to shapefile admin names
# ### Match orgunitlevel4 to Geob Adm 3
# Try using fuzzy matching

# %%
level4_list = list(master_table.orgunitlevel4.unique())
level4_list.sort()
level3_list = list(master_table.orgunitlevel3.unique())
level3_list.sort()
geob2_list = list(geob2.shapeName)
geob2_list.sort()

# %% [markdown]
# Print names to inspect

# %%
for letter in ascii_uppercase:
    level3_sublist = [name for name in level3_list if name[0]==letter]
    geob2_sublist = [name for name in geob2_list if name[0]==letter]

    if len(level3_sublist)>0:
        print(f"Master list level 4 ({len(level3_sublist)})")
        print("\t"+str(level3_sublist))
    if len(geob2_sublist) >0:
        print(f"Geoboundaries adm3({len(geob2_sublist)})")
        print("\t"+str(geob2_sublist))
        
    print("\n")
# Out:
# Master list level 4 (11)
# 	["B'Hai District", 'Barclayville District', 'Barrobo Farjah District', 'Barrobo Whojah District', 'Belleh District', 'Bokomu District', 'Bopolu District', 'Buah District', 'Buchanan District', 'Bushrod District', 'Butaw District']
# Geoboundaries adm3(15)
# 	["B'hai", 'Barclayville', 'Beawor', 'Belleh', 'Bleebo', 'Bodae', 'Boe & Quilla', 'Boinsen', 'Bokomu', 'Bokon', 'Bolloh', 'Bopolu', 'Buah', 'Butaw', 'Buu-Yao']
#
#
# Master list level 4 (8)
# 	['Campwood District', 'Careysburg District', 'Cavalla District', 'Central C District', 'Central Monrovia district', 'Chedepo District', 'Commonwealth District', 'Commonwealth-C District']
# Geoboundaries adm3(7)
# 	['Careysburg', 'Cavala', 'Central Rivercess', 'Chedepo', 'Commonwealth', 'Commonwealth 1', 'Commonwealth 2']
#
#
# Master list level 4 (9)
# 	['District # 1', 'District # 2', 'District # 3 A&B', 'District # 3 C', 'District # 4', 'Doedian District', 'Dorbor District', 'Dowein', 'Dugbe River District']
# Geoboundaries adm3(10)
# 	['District #1', 'District #2', 'District #3', 'District #4', 'Doe', 'Doedain', 'Dorbor', 'Dowein', 'Dugbe River', 'Dweh']
#
#
#
#
# Master list level 4 (3)
# 	['Firestone District', 'Foya District', 'Fuamah']
# Geoboundaries adm3(7)
# 	['Felo-Jekwi', 'Fen River', 'Fenetoe', 'Firestone', 'Forpoh', 'Foya', 'Fuamah']
#
#
# Master list level 4 (9)
# 	['Garwula District', 'Gbao District', 'Gbarma District', 'Gbeapo District', 'Gbehlay-Geh District', 'Gblonee District', 'Gibi District', 'Gola konneh District', 'Greenville District']
# Geoboundaries adm3(20)
# 	['Garr-Bain', 'Garraway', 'Garwula', 'Gbao', 'Gbarma', 'Gbeapo', 'Gbehlay-Geh', 'Gbi & Doru', 'Gboe-Ploe', 'Gbor', 'Gee', 'Gibi', 'Glaro', 'Glio-Twarbo', 'Golakonneh', 'Gounwolaila', 'Grand Cess Wedabo', 'Greater Monrovia', 'Greenville', 'Gwelekpoken']
#
#
# Master list level 4 (1)
# 	['Harper District']
# Geoboundaries adm3(1)
# 	['Harper']
#
#
#
#
# Master list level 4 (6)
# 	['Jeade District', 'Jedepo District', 'Joe River District', 'Jorquelleh', 'Jowein District', 'Jraoh District']
# Geoboundaries adm3(5)
# 	['Jaedae', 'Jeadepo', 'Jo River', 'Jorquelleh', 'Juarzon']
#
#
# Master list level 4 (10)
# 	['Kakata District', 'Karluway 1 District', 'Karluway 2 District', 'Klay', 'Kokoyah', 'Kolahun District', 'Kongba District', 'Konobo District', 'Kpaai', 'Kpanyan District']
# Geoboundaries adm3(14)
# 	['Kakata', 'Karforh', 'Karluway #1', 'Karluway #2', 'Klay', 'Kokoyah', 'Kolahun', 'Kongba', 'Konobo', 'Kpaai', 'Kparblee', 'Kpayan', 'Kpi', 'Kulu Shaw Boe']
#
#
# Geoboundaries adm3(2)
# 	['Leewehpea-Mahn', 'Lower Jloh']
#
#
# Master list level 4 (1)
# 	['Mambah-Kaba District']
# Geoboundaries adm3(2)
# 	['Mambah Kaba', 'Meinpea-Mahn']
#
#
# Geoboundaries adm3(7)
# 	['Nanee', 'Neekreen', 'Norwein', 'Nrokwia-Wesldow', 'Nyenawliken', 'Nyenebo', 'Nyorken']
#
#
# Master list level 4 (1)
# 	['Owensgrove District']
# Geoboundaries adm3(1)
# 	['Owensgrove']
#
#
# Master list level 4 (6)
# 	['Panta', 'Pleebo District', 'Porkpa District', 'Potupo District', 'Putu District', 'Pynes Town District']
# Geoboundaries adm3(7)
# 	['Panta', 'Plahn Nyarn', 'Pleebo/Sodoken', 'Porkpa', 'Potupo', 'Putu', 'Pynes Town']
#
#
# Geoboundaries adm3(1)
# 	['Quardu Boundi']
#
#
#
#
# Master list level 4 (11)
# 	['Saclepea Mah District', 'Salala', 'Salayea District', 'Sanniquelleh Mahn District', 'Sanoyea', 'Sarbo District', 'Senjeh', 'Somalia Drive District', 'St Paul River District', 'Suakoko', 'Suehn Mecca']
# Geoboundaries adm3(15)
# 	['Salala', 'Salayea', 'Sam Gbalor', 'Sanniquellie Mahn', 'Sanoyeah', 'Sanquin Dist #1', 'Sanquin Dist #2', 'Sanquin Dist #3', 'Sarbo', 'Seekon', 'Senjeh', 'St. John River City', 'St. Paul River', 'Suakoko', 'Suehn Mecca']
#
#
# Master list level 4 (9)
# 	['Tappita District', 'Tarjuwon District', 'Tarsue District', 'Tchien District', 'Tewor District', 'Tienpo District', 'Timbo District', 'Todee District', 'Trehn District']
# Geoboundaries adm3(7)
# 	['Tchien', 'Tewor', 'Todee', 'Trenbo', 'Tukpahblee', 'Tuobo', 'Twan River']
#
#
# Geoboundaries adm3(1)
# 	['Upper Jloh']
#
#
# Master list level 4 (2)
# 	['Vahun District', 'Voinjama District']
# Geoboundaries adm3(2)
# 	['Vahun', 'Voinjama']
#
#
# Master list level 4 (1)
# 	['Webbo District']
# Geoboundaries adm3(4)
# 	['Wedjah', 'Wee-Gbehyi-Mahn', 'Whojah', 'Wlogba']
#
#
#
#
# Master list level 4 (2)
# 	['Yarnie District', 'Yarwein Mehnsohnneh District']
# Geoboundaries adm3(4)
# 	['Yarmein', 'Yarpea Mahn', 'Yarwein Mehnsonnoh', 'Yeallequelleh']
#
#
# Master list level 4 (3)
# 	['Zoe-Geh District', 'Zorzor District', 'Zota']
# Geoboundaries adm3(4)
# 	['Zarflahn', 'Zoe-Gbao', 'Zorzor', 'Zota']

# %% [markdown]
# ### Match orgunitlevel3 to Geob Adm 2

# %%
master_table.loc[:, "orgunitlevel3_edit"] = master_table.orgunitlevel3

# %%
remove_words(geob2, "shapeName", [" City Council", " District Council", " Municipal Council", " District"])
remove_words(master_table, "orgunitlevel3_edit", [" District"])

# %%
master_table.loc[master_table.orgunitlevel3_edit == "Chattogram", "orgunitlevel3_edit"] = "Chittagong"

# %%
level3_list = list(master_table.orgunitlevel3_edit.unique())
level3_list.sort()
geob2_list = list(geob2.shapeName)
geob2_list.sort()

# %%
for letter in ascii_uppercase:
    level3_sublist = [name for name in level3_list if name[0]==letter]
    geob2_sublist = [name for name in geob2_list if name[0]==letter]
    if len(level3_sublist)>0:
        print("Master list level 3")
        print("\t"+str(level3_sublist))
    if len(geob2_sublist) >0:
        print("Geoboundaries adm2")
        print("\t"+str(geob2_sublist))
# Out:
# Master list level 3
# 	["B'Hai", 'Barclayville', 'Barrobo Farjah', 'Barrobo Whojah', 'Belleh', 'Bokomu', 'Bopolu', 'Buah', 'Buchanan', 'Bushrod', 'Butaw']
# Geoboundaries adm2
# 	["B'hai", 'Barclayville', 'Beawor', 'Belleh', 'Bleebo', 'Bodae', 'Boe & Quilla', 'Boinsen', 'Bokomu', 'Bokon', 'Bolloh', 'Bopolu', 'Buah', 'Butaw', 'Buu-Yao']
# Master list level 3
# 	['Campwood', 'Careysburg', 'Cavalla', 'Central C', 'Central Monrovia district', 'Chedepo', 'Commonwealth', 'Commonwealth-C']
# Geoboundaries adm2
# 	['Careysburg', 'Cavala', 'Central Rivercess', 'Chedepo', 'Commonwealth', 'Commonwealth 1', 'Commonwealth 2']
# Master list level 3
# 	['District # 1', 'District # 2', 'District # 3 A&B', 'District # 3 C', 'District # 4', 'Doedian', 'Dorbor', 'Dowein', 'Dugbe River']
# Geoboundaries adm2
# 	['District #1', 'District #2', 'District #3', 'District #4', 'Doe', 'Doedain', 'Dorbor', 'Dowein', 'Dugbe River', 'Dweh']
# Master list level 3
# 	['Firestone', 'Foya', 'Fuamah']
# Geoboundaries adm2
# 	['Felo-Jekwi', 'Fen River', 'Fenetoe', 'Firestone', 'Forpoh', 'Foya', 'Fuamah']
# Master list level 3
# 	['Garwula', 'Gbao', 'Gbarma', 'Gbeapo', 'Gbehlay-Geh', 'Gblonee', 'Gibi', 'Gola konneh', 'Greenville']
# Geoboundaries adm2
# 	['Garr-Bain', 'Garraway', 'Garwula', 'Gbao', 'Gbarma', 'Gbeapo', 'Gbehlay-Geh', 'Gbi & Doru', 'Gboe-Ploe', 'Gbor', 'Gee', 'Gibi', 'Glaro', 'Glio-Twarbo', 'Golakonneh', 'Gounwolaila', 'Grand Cess Wedabo', 'Greater Monrovia', 'Greenville', 'Gwelekpoken']
# Master list level 3
# 	['Harper']
# Geoboundaries adm2
# 	['Harper']
# Master list level 3
# 	['Jeade', 'Jedepo', 'Joe River', 'Jorquelleh', 'Jowein', 'Jraoh']
# Geoboundaries adm2
# 	['Jaedae', 'Jeadepo', 'Jo River', 'Jorquelleh', 'Juarzon']
# Master list level 3
# 	['Kakata', 'Karluway 1', 'Karluway 2', 'Klay', 'Kokoyah', 'Kolahun', 'Kongba', 'Konobo', 'Kpaai', 'Kpanyan']
# Geoboundaries adm2
# 	['Kakata', 'Karforh', 'Karluway #1', 'Karluway #2', 'Klay', 'Kokoyah', 'Kolahun', 'Kongba', 'Konobo', 'Kpaai', 'Kparblee', 'Kpayan', 'Kpi', 'Kulu Shaw Boe']
# Geoboundaries adm2
# 	['Leewehpea-Mahn', 'Lower Jloh']
# Master list level 3
# 	['Mambah-Kaba']
# Geoboundaries adm2
# 	['Mambah Kaba', 'Meinpea-Mahn']
# Geoboundaries adm2
# 	['Nanee', 'Neekreen', 'Norwein', 'Nrokwia-Wesldow', 'Nyenawliken', 'Nyenebo', 'Nyorken']
# Master list level 3
# 	['Owensgrove']
# Geoboundaries adm2
# 	['Owensgrove']
# Master list level 3
# 	['Panta', 'Pleebo', 'Porkpa', 'Potupo', 'Putu', 'Pynes Town']
# Geoboundaries adm2
# 	['Panta', 'Plahn Nyarn', 'Pleebo/Sodoken', 'Porkpa', 'Potupo', 'Putu', 'Pynes Town']
# Geoboundaries adm2
# 	['Quardu Boundi']
# Master list level 3
# 	['Saclepea Mah', 'Salala', 'Salayea', 'Sanniquelleh Mahn', 'Sanoyea', 'Sarbo', 'Senjeh', 'Somalia Drive', 'St Paul River', 'Suakoko', 'Suehn Mecca']
# Geoboundaries adm2
# 	['Salala', 'Salayea', 'Sam Gbalor', 'Sanniquellie Mahn', 'Sanoyeah', 'Sanquin Dist #1', 'Sanquin Dist #2', 'Sanquin Dist #3', 'Sarbo', 'Seekon', 'Senjeh', 'St. John River City', 'St. Paul River', 'Suakoko', 'Suehn Mecca']
# Master list level 3
# 	['Tappita', 'Tarjuwon', 'Tarsue', 'Tchien', 'Tewor', 'Tienpo', 'Timbo', 'Todee', 'Trehn']
# Geoboundaries adm2
# 	['Tchien', 'Tewor', 'Todee', 'Trenbo', 'Tukpahblee', 'Tuobo', 'Twan River']
# Geoboundaries adm2
# 	['Upper Jloh']
# Master list level 3
# 	['Vahun', 'Voinjama']
# Geoboundaries adm2
# 	['Vahun', 'Voinjama']
# Master list level 3
# 	['Webbo']
# Geoboundaries adm2
# 	['Wedjah', 'Wee-Gbehyi-Mahn', 'Whojah', 'Wlogba']
# Master list level 3
# 	['Yarnie', 'Yarwein Mehnsohnneh']
# Geoboundaries adm2
# 	['Yarmein', 'Yarpea Mahn', 'Yarwein Mehnsonnoh', 'Yeallequelleh']
# Master list level 3
# 	['Zoe-Geh', 'Zorzor', 'Zota']
# Geoboundaries adm2
# 	['Zarflahn', 'Zoe-Gbao', 'Zorzor', 'Zota']

# %%
# List for dicts for easy dataframe creation
dict_list = []
# iterating over our players without salaries found above
for name in level3_list:
    
    # Use our method to find best match, we can set a threshold here

    match = match_name(name, geob2_list, 30)
    print(f"{name}: {match}")
    # New dict for storing data
    dict_ = {}
    dict_.update({"name_level3" : name})
    dict_.update({"name_geob2" : match[0]})
    dict_.update({"score" : match[1]})
    dict_list.append(dict_)

table_adm2 = pd.DataFrame(dict_list)
table_adm2_matches = table_adm2[table_adm2.score >= 80]
# Out:
# B'Hai vs B'hai: phon: 100, fuzzy: 80
# B'Hai vs Barclayville: phon: 25, fuzzy: 35
# B'Hai vs Beawor: phon: 75, fuzzy: 36
# B'Hai vs Belleh: phon: 75, fuzzy: 18
# B'Hai vs Bleebo: phon: 50, fuzzy: 18
# B'Hai vs Bodae: phon: 75, fuzzy: 40
# B'Hai vs Boe & Quilla: phon: 50, fuzzy: 24
# B'Hai vs Boinsen: phon: 25, fuzzy: 33
# B'Hai vs Bokomu: phon: 50, fuzzy: 18
# B'Hai vs Bokon: phon: 50, fuzzy: 20
# B'Hai vs Bolloh: phon: 75, fuzzy: 18
# B'Hai vs Bopolu: phon: 50, fuzzy: 18
# B'Hai vs Buah: phon: 100, fuzzy: 44
# B'Hai vs Butaw: phon: 75, fuzzy: 40
# B'Hai vs Buu-Yao: phon: 100, fuzzy: 33
# B'Hai vs Careysburg: phon: 0, fuzzy: 13
# B'Hai vs Cavala: phon: 25, fuzzy: 18
# B'Hai vs Central Rivercess: phon: 0, fuzzy: 18
# B'Hai vs Chedepo: phon: 25, fuzzy: 0
# B'Hai vs Commonwealth: phon: 0, fuzzy: 12
# B'Hai vs Commonwealth 1: phon: 0, fuzzy: 11
# B'Hai vs Commonwealth 2: phon: 0, fuzzy: 11
# B'Hai vs District #1: phon: 0, fuzzy: 12
# B'Hai vs District #2: phon: 0, fuzzy: 12
# B'Hai vs District #3: phon: 0, fuzzy: 12
# B'Hai vs District #4: phon: 0, fuzzy: 12
# B'Hai vs Doe: phon: 75, fuzzy: 0
# B'Hai vs Doedain: phon: 25, fuzzy: 33
# B'Hai vs Dorbor: phon: 0, fuzzy: 0
# B'Hai vs Dowein: phon: 50, fuzzy: 18
# B'Hai vs Dugbe River: phon: 0, fuzzy: 12
# B'Hai vs Dweh: phon: 75, fuzzy: 0
# B'Hai vs Felo-Jekwi: phon: 0, fuzzy: 13
# B'Hai vs Fen River: phon: 0, fuzzy: 14
# B'Hai vs Fenetoe: phon: 25, fuzzy: 0
# B'Hai vs Firestone: phon: 0, fuzzy: 14
# B'Hai vs Forpoh: phon: 25, fuzzy: 0
# B'Hai vs Foya: phon: 75, fuzzy: 22
# B'Hai vs Fuamah: phon: 50, fuzzy: 18
# B'Hai vs Garr-Bain: phon: 0, fuzzy: 43
# B'Hai vs Garraway: phon: 50, fuzzy: 15
# B'Hai vs Garwula: phon: 25, fuzzy: 17
# B'Hai vs Gbao: phon: 50, fuzzy: 22
# B'Hai vs Gbarma: phon: 0, fuzzy: 18
# B'Hai vs Gbeapo: phon: 25, fuzzy: 18
# B'Hai vs Gbehlay-Geh: phon: 0, fuzzy: 12
# B'Hai vs Gbi & Doru: phon: 0, fuzzy: 13
# B'Hai vs Gboe-Ploe: phon: 0, fuzzy: 0
# B'Hai vs Gbor: phon: 25, fuzzy: 0
# B'Hai vs Gee: phon: 75, fuzzy: 0
# B'Hai vs Gibi: phon: 50, fuzzy: 22
# B'Hai vs Glaro: phon: 25, fuzzy: 20
# B'Hai vs Glio-Twarbo: phon: 0, fuzzy: 12
# B'Hai vs Golakonneh: phon: 0, fuzzy: 13
# B'Hai vs Gounwolaila: phon: 0, fuzzy: 25
# B'Hai vs Grand Cess Wedabo: phon: 0, fuzzy: 9
# B'Hai vs Greater Monrovia: phon: 0, fuzzy: 19
# B'Hai vs Greenville: phon: 0, fuzzy: 13
# B'Hai vs Gwelekpoken: phon: 0, fuzzy: 0
# B'Hai vs Harper: phon: 0, fuzzy: 36
# B'Hai vs Jaedae: phon: 50, fuzzy: 18
# B'Hai vs Jeadepo: phon: 25, fuzzy: 17
# B'Hai vs Jo River: phon: 0, fuzzy: 15
# B'Hai vs Jorquelleh: phon: 0, fuzzy: 0
# B'Hai vs Juarzon: phon: 0, fuzzy: 17
# B'Hai vs Kakata: phon: 25, fuzzy: 18
# B'Hai vs Karforh: phon: 0, fuzzy: 17
# B'Hai vs Karluway #1: phon: 25, fuzzy: 12
# B'Hai vs Karluway #2: phon: 25, fuzzy: 12
# B'Hai vs Klay: phon: 50, fuzzy: 22
# B'Hai vs Kokoyah: phon: 50, fuzzy: 17
# B'Hai vs Kolahun: phon: 25, fuzzy: 17
# B'Hai vs Kongba: phon: 0, fuzzy: 18
# B'Hai vs Konobo: phon: 25, fuzzy: 0
# B'Hai vs Kpaai: phon: 50, fuzzy: 40
# B'Hai vs Kparblee: phon: 0, fuzzy: 15
# B'Hai vs Kpayan: phon: 25, fuzzy: 18
# B'Hai vs Kpi: phon: 50, fuzzy: 25
# B'Hai vs Kulu Shaw Boe: phon: 0, fuzzy: 11
# B'Hai vs Leewehpea-Mahn: phon: 0, fuzzy: 11
# B'Hai vs Lower Jloh: phon: 0, fuzzy: 0
# B'Hai vs Mambah Kaba: phon: 0, fuzzy: 12
# B'Hai vs Meinpea-Mahn: phon: 0, fuzzy: 12
# B'Hai vs Nanee: phon: 50, fuzzy: 20
# B'Hai vs Neekreen: phon: 0, fuzzy: 0
# B'Hai vs Norwein: phon: 25, fuzzy: 17
# B'Hai vs Nrokwia-Wesldow: phon: 0, fuzzy: 10
# B'Hai vs Nyenawliken: phon: 0, fuzzy: 25
# B'Hai vs Nyenebo: phon: 25, fuzzy: 0
# B'Hai vs Nyorken: phon: 0, fuzzy: 0
# B'Hai vs Owensgrove: phon: 0, fuzzy: 0
# B'Hai vs Panta: phon: 25, fuzzy: 20
# B'Hai vs Plahn Nyarn: phon: 0, fuzzy: 12
# B'Hai vs Pleebo/Sodoken: phon: 0, fuzzy: 0
# B'Hai vs Porkpa: phon: 0, fuzzy: 18
# B'Hai vs Potupo: phon: 25, fuzzy: 0
# B'Hai vs Putu: phon: 50, fuzzy: 0
# B'Hai vs Pynes Town: phon: 0, fuzzy: 0
# B'Hai vs Quardu Boundi: phon: 0, fuzzy: 22
# B'Hai vs Salala: phon: 25, fuzzy: 18
# B'Hai vs Salayea: phon: 50, fuzzy: 17
# B'Hai vs Sam Gbalor: phon: 0, fuzzy: 13
# B'Hai vs Sanniquellie Mahn: phon: 0, fuzzy: 18
# B'Hai vs Sanoyeah: phon: 50, fuzzy: 15
# B'Hai vs Sanquin Dist #1: phon: 0, fuzzy: 20
# B'Hai vs Sanquin Dist #2: phon: 0, fuzzy: 20
# B'Hai vs Sanquin Dist #3: phon: 0, fuzzy: 20
# B'Hai vs Sarbo: phon: 25, fuzzy: 20
# B'Hai vs Seekon: phon: 25, fuzzy: 0
# B'Hai vs Senjeh: phon: 25, fuzzy: 0
# B'Hai vs St. John River City: phon: 0, fuzzy: 8
# B'Hai vs St. Paul River: phon: 0, fuzzy: 21
# B'Hai vs Suakoko: phon: 25, fuzzy: 17
# B'Hai vs Suehn Mecca: phon: 0, fuzzy: 12
# B'Hai vs Tchien: phon: 25, fuzzy: 18
# B'Hai vs Tewor: phon: 50, fuzzy: 0
# B'Hai vs Todee: phon: 50, fuzzy: 0
# B'Hai vs Trenbo: phon: 0, fuzzy: 0
# B'Hai vs Tukpahblee: phon: 0, fuzzy: 13
# B'Hai vs Tuobo: phon: 50, fuzzy: 0
# B'Hai vs Twan River: phon: 0, fuzzy: 27
# B'Hai vs Upper Jloh: phon: 0, fuzzy: 0
# B'Hai vs Vahun: phon: 50, fuzzy: 20
# B'Hai vs Voinjama: phon: 0, fuzzy: 15
# B'Hai vs Wedjah: phon: 25, fuzzy: 18
# B'Hai vs Wee-Gbehyi-Mahn: phon: 0, fuzzy: 10
# B'Hai vs Whojah: phon: 50, fuzzy: 18
# B'Hai vs Wlogba: phon: 0, fuzzy: 18
# B'Hai vs Yarmein: phon: 0, fuzzy: 33
# B'Hai vs Yarpea Mahn: phon: 0, fuzzy: 12
# B'Hai vs Yarwein Mehnsonnoh: phon: 0, fuzzy: 17
# B'Hai vs Yeallequelleh: phon: 0, fuzzy: 11
# B'Hai vs Zarflahn: phon: 0, fuzzy: 15
# B'Hai vs Zoe-Gbao: phon: 25, fuzzy: 15
# B'Hai vs Zorzor: phon: 0, fuzzy: 0
# B'Hai vs Zota: phon: 50, fuzzy: 22
# B'Hai: ("B'hai", 100)
# Barclayville vs B'hai: phon: 25, fuzzy: 35
# Barclayville vs Barclayville: phon: 100, fuzzy: 100
# Barclayville vs Beawor: phon: 50, fuzzy: 33
# Barclayville vs Belleh: phon: 50, fuzzy: 44
# Barclayville vs Bleebo: phon: 50, fuzzy: 33
# Barclayville vs Bodae: phon: 25, fuzzy: 35
# Barclayville vs Boe & Quilla: phon: 75, fuzzy: 33
# Barclayville vs Boinsen: phon: 50, fuzzy: 32
# Barclayville vs Bokomu: phon: 50, fuzzy: 11
# Barclayville vs Bokon: phon: 50, fuzzy: 12
# Barclayville vs Bolloh: phon: 50, fuzzy: 33
# Barclayville vs Bopolu: phon: 50, fuzzy: 22
# Barclayville vs Buah: phon: 25, fuzzy: 25
# Barclayville vs Butaw: phon: 25, fuzzy: 24
# Barclayville vs Buu-Yao: phon: 25, fuzzy: 21
# Barclayville vs Careysburg: phon: 50, fuzzy: 27
# Barclayville vs Cavala: phon: 25, fuzzy: 33
# Barclayville vs Central Rivercess: phon: 25, fuzzy: 28
# Barclayville vs Chedepo: phon: 0, fuzzy: 11
# Barclayville vs Commonwealth: phon: 25, fuzzy: 17
# Barclayville vs Commonwealth 1: phon: 25, fuzzy: 15
# Barclayville vs Commonwealth 2: phon: 25, fuzzy: 15
# Barclayville vs District #1: phon: 25, fuzzy: 17
# Barclayville vs District #2: phon: 25, fuzzy: 17
# Barclayville vs District #3: phon: 25, fuzzy: 17
# Barclayville vs District #4: phon: 25, fuzzy: 17
# Barclayville vs Doe: phon: 0, fuzzy: 13
# Barclayville vs Doedain: phon: 0, fuzzy: 21
# Barclayville vs Dorbor: phon: 25, fuzzy: 11
# Barclayville vs Dowein: phon: 0, fuzzy: 11
# Barclayville vs Dugbe River: phon: 25, fuzzy: 17
# Barclayville vs Dweh: phon: 0, fuzzy: 12
# Barclayville vs Felo-Jekwi: phon: 25, fuzzy: 18
# Barclayville vs Fen River: phon: 25, fuzzy: 19
# Barclayville vs Fenetoe: phon: 0, fuzzy: 11
# Barclayville vs Firestone: phon: 50, fuzzy: 19
# Barclayville vs Forpoh: phon: 25, fuzzy: 11
# Barclayville vs Foya: phon: 0, fuzzy: 12
# Barclayville vs Fuamah: phon: 0, fuzzy: 22
# Barclayville vs Garr-Bain: phon: 25, fuzzy: 38
# Barclayville vs Garraway: phon: 25, fuzzy: 40
# Barclayville vs Garwula: phon: 50, fuzzy: 42
# Barclayville vs Gbao: phon: 0, fuzzy: 12
# Barclayville vs Gbarma: phon: 25, fuzzy: 33
# Barclayville vs Gbeapo: phon: 0, fuzzy: 11
# Barclayville vs Gbehlay-Geh: phon: 25, fuzzy: 35
# Barclayville vs Gbi & Doru: phon: 25, fuzzy: 9
# Barclayville vs Gboe-Ploe: phon: 25, fuzzy: 19
# Barclayville vs Gbor: phon: 25, fuzzy: 12
# Barclayville vs Gee: phon: 0, fuzzy: 13
# Barclayville vs Gibi: phon: 0, fuzzy: 12
# Barclayville vs Glaro: phon: 25, fuzzy: 24
# Barclayville vs Glio-Twarbo: phon: 25, fuzzy: 17
# Barclayville vs Golakonneh: phon: 25, fuzzy: 27
# Barclayville vs Gounwolaila: phon: 25, fuzzy: 35
# Barclayville vs Grand Cess Wedabo: phon: 25, fuzzy: 21
# Barclayville vs Greater Monrovia: phon: 25, fuzzy: 29
# Barclayville vs Greenville: phon: 25, fuzzy: 55
# Barclayville vs Gwelekpoken: phon: 25, fuzzy: 17
# Barclayville vs Harper: phon: 25, fuzzy: 33
# Barclayville vs Jaedae: phon: 0, fuzzy: 33
# Barclayville vs Jeadepo: phon: 0, fuzzy: 21
# Barclayville vs Jo River: phon: 25, fuzzy: 20
# Barclayville vs Jorquelleh: phon: 75, fuzzy: 36
# Barclayville vs Juarzon: phon: 50, fuzzy: 21
# Barclayville vs Kakata: phon: 25, fuzzy: 22
# Barclayville vs Karforh: phon: 25, fuzzy: 21
# Barclayville vs Karluway #1: phon: 50, fuzzy: 43
# Barclayville vs Karluway #2: phon: 50, fuzzy: 43
# Barclayville vs Klay: phon: 25, fuzzy: 38
# Barclayville vs Kokoyah: phon: 25, fuzzy: 11
# Barclayville vs Kolahun: phon: 25, fuzzy: 21
# Barclayville vs Kongba: phon: 25, fuzzy: 11
# Barclayville vs Konobo: phon: 0, fuzzy: 0
# Barclayville vs Kpaai: phon: 0, fuzzy: 35
# Barclayville vs Kparblee: phon: 25, fuzzy: 40
# Barclayville vs Kpayan: phon: 0, fuzzy: 22
# Barclayville vs Kpi: phon: 0, fuzzy: 13
# Barclayville vs Kulu Shaw Boe: phon: 25, fuzzy: 24
# Barclayville vs Leewehpea-Mahn: phon: 0, fuzzy: 15
# Barclayville vs Lower Jloh: phon: 75, fuzzy: 18
# Barclayville vs Mambah Kaba: phon: 25, fuzzy: 17
# Barclayville vs Meinpea-Mahn: phon: 0, fuzzy: 17
# Barclayville vs Nanee: phon: 0, fuzzy: 24
# Barclayville vs Neekreen: phon: 25, fuzzy: 20
# Barclayville vs Norwein: phon: 25, fuzzy: 21
# Barclayville vs Nrokwia-Wesldow: phon: 50, fuzzy: 22
# Barclayville vs Nyenawliken: phon: 25, fuzzy: 35
# Barclayville vs Nyenebo: phon: 0, fuzzy: 21
# Barclayville vs Nyorken: phon: 50, fuzzy: 21
# Barclayville vs Owensgrove: phon: 25, fuzzy: 27
# Barclayville vs Panta: phon: 0, fuzzy: 24
# Barclayville vs Plahn Nyarn: phon: 25, fuzzy: 26
# Barclayville vs Pleebo/Sodoken: phon: 25, fuzzy: 15
# Barclayville vs Porkpa: phon: 50, fuzzy: 22
# Barclayville vs Potupo: phon: 0, fuzzy: 0
# Barclayville vs Putu: phon: 0, fuzzy: 0
# Barclayville vs Pynes Town: phon: 25, fuzzy: 18
# Barclayville vs Quardu Boundi: phon: 25, fuzzy: 24
# Barclayville vs Salala: phon: 25, fuzzy: 44
# Barclayville vs Salayea: phon: 25, fuzzy: 53
# Barclayville vs Sam Gbalor: phon: 25, fuzzy: 27
# Barclayville vs Sanniquellie Mahn: phon: 50, fuzzy: 34
# Barclayville vs Sanoyeah: phon: 0, fuzzy: 30
# Barclayville vs Sanquin Dist #1: phon: 25, fuzzy: 15
# Barclayville vs Sanquin Dist #2: phon: 25, fuzzy: 15
# Barclayville vs Sanquin Dist #3: phon: 25, fuzzy: 15
# Barclayville vs Sarbo: phon: 25, fuzzy: 24
# Barclayville vs Seekon: phon: 25, fuzzy: 11
# Barclayville vs Senjeh: phon: 25, fuzzy: 11
# Barclayville vs St. John River City: phon: 25, fuzzy: 13
# Barclayville vs St. Paul River: phon: 25, fuzzy: 31
# Barclayville vs Suakoko: phon: 25, fuzzy: 11
# Barclayville vs Suehn Mecca: phon: 25, fuzzy: 17
# Barclayville vs Tchien: phon: 25, fuzzy: 33
# Barclayville vs Tewor: phon: 25, fuzzy: 12
# Barclayville vs Todee: phon: 0, fuzzy: 12
# Barclayville vs Trenbo: phon: 25, fuzzy: 22
# Barclayville vs Tukpahblee: phon: 25, fuzzy: 27
# Barclayville vs Tuobo: phon: 0, fuzzy: 0
# Barclayville vs Twan River: phon: 25, fuzzy: 27
# Barclayville vs Upper Jloh: phon: 50, fuzzy: 18
# Barclayville vs Vahun: phon: 0, fuzzy: 12
# Barclayville vs Voinjama: phon: 25, fuzzy: 20
# Barclayville vs Wedjah: phon: 25, fuzzy: 11
# Barclayville vs Wee-Gbehyi-Mahn: phon: 25, fuzzy: 15
# Barclayville vs Whojah: phon: 25, fuzzy: 11
# Barclayville vs Wlogba: phon: 25, fuzzy: 22
# Barclayville vs Yarmein: phon: 25, fuzzy: 32
# Barclayville vs Yarpea Mahn: phon: 25, fuzzy: 26
# Barclayville vs Yarwein Mehnsonnoh: phon: 25, fuzzy: 27
# Barclayville vs Yeallequelleh: phon: 50, fuzzy: 40
# Barclayville vs Zarflahn: phon: 50, fuzzy: 40
# Barclayville vs Zoe-Gbao: phon: 25, fuzzy: 10
# Barclayville vs Zorzor: phon: 50, fuzzy: 11
# Barclayville vs Zota: phon: 0, fuzzy: 12
# Barclayville: ('Barclayville', 100)
# Barrobo Farjah vs B'hai: phon: 25, fuzzy: 21
# Barrobo Farjah vs Barclayville: phon: 50, fuzzy: 31
# Barrobo Farjah vs Beawor: phon: 50, fuzzy: 40
# Barrobo Farjah vs Belleh: phon: 25, fuzzy: 20
# Barrobo Farjah vs Bleebo: phon: 50, fuzzy: 30
# Barrobo Farjah vs Bodae: phon: 25, fuzzy: 32
# Barrobo Farjah vs Boe & Quilla: phon: 25, fuzzy: 31
# Barrobo Farjah vs Boinsen: phon: 25, fuzzy: 19
# Barrobo Farjah vs Bokomu: phon: 25, fuzzy: 30
# Barrobo Farjah vs Bokon: phon: 25, fuzzy: 32
# Barrobo Farjah vs Bolloh: phon: 25, fuzzy: 40
# Barrobo Farjah vs Bopolu: phon: 50, fuzzy: 30
# Barrobo Farjah vs Buah: phon: 25, fuzzy: 33
# Barrobo Farjah vs Butaw: phon: 25, fuzzy: 21
# Barrobo Farjah vs Buu-Yao: phon: 25, fuzzy: 29
# Barrobo Farjah vs Careysburg: phon: 50, fuzzy: 33
# Barrobo Farjah vs Cavala: phon: 25, fuzzy: 30
# Barrobo Farjah vs Central Rivercess: phon: 25, fuzzy: 19
# Barrobo Farjah vs Chedepo: phon: 25, fuzzy: 10
# Barrobo Farjah vs Commonwealth: phon: 0, fuzzy: 31
# Barrobo Farjah vs Commonwealth 1: phon: 0, fuzzy: 29
# Barrobo Farjah vs Commonwealth 2: phon: 0, fuzzy: 29
# Barrobo Farjah vs District #1: phon: 25, fuzzy: 16
# Barrobo Farjah vs District #2: phon: 25, fuzzy: 16
# Barrobo Farjah vs District #3: phon: 25, fuzzy: 16
# Barrobo Farjah vs District #4: phon: 25, fuzzy: 16
# Barrobo Farjah vs Doe: phon: 0, fuzzy: 12
# Barrobo Farjah vs Doedain: phon: 0, fuzzy: 19
# Barrobo Farjah vs Dorbor: phon: 50, fuzzy: 40
# Barrobo Farjah vs Dowein: phon: 0, fuzzy: 10
# Barrobo Farjah vs Dugbe River: phon: 25, fuzzy: 24
# Barrobo Farjah vs Dweh: phon: 0, fuzzy: 11
# Barrobo Farjah vs Felo-Jekwi: phon: 0, fuzzy: 8
# Barrobo Farjah vs Fen River: phon: 50, fuzzy: 17
# Barrobo Farjah vs Fenetoe: phon: 0, fuzzy: 10
# Barrobo Farjah vs Firestone: phon: 25, fuzzy: 17
# Barrobo Farjah vs Forpoh: phon: 50, fuzzy: 30
# Barrobo Farjah vs Foya: phon: 0, fuzzy: 22
# Barrobo Farjah vs Fuamah: phon: 0, fuzzy: 40
# Barrobo Farjah vs Garr-Bain: phon: 50, fuzzy: 35
# Barrobo Farjah vs Garraway: phon: 25, fuzzy: 45
# Barrobo Farjah vs Garwula: phon: 25, fuzzy: 29
# Barrobo Farjah vs Gbao: phon: 25, fuzzy: 22
# Barrobo Farjah vs Gbarma: phon: 25, fuzzy: 40
# Barrobo Farjah vs Gbeapo: phon: 50, fuzzy: 20
# Barrobo Farjah vs Gbehlay-Geh: phon: 25, fuzzy: 24
# Barrobo Farjah vs Gbi & Doru: phon: 25, fuzzy: 25
# Barrobo Farjah vs Gboe-Ploe: phon: 50, fuzzy: 17
# Barrobo Farjah vs Gbor: phon: 25, fuzzy: 33
# Barrobo Farjah vs Gee: phon: 0, fuzzy: 0
# Barrobo Farjah vs Gibi: phon: 25, fuzzy: 11
# Barrobo Farjah vs Glaro: phon: 25, fuzzy: 32
# Barrobo Farjah vs Glio-Twarbo: phon: 25, fuzzy: 32
# Barrobo Farjah vs Golakonneh: phon: 0, fuzzy: 25
# Barrobo Farjah vs Gounwolaila: phon: 0, fuzzy: 32
# Barrobo Farjah vs Grand Cess Wedabo: phon: 25, fuzzy: 19
# Barrobo Farjah vs Greater Monrovia: phon: 25, fuzzy: 33
# Barrobo Farjah vs Greenville: phon: 50, fuzzy: 8
# Barrobo Farjah vs Gwelekpoken: phon: 25, fuzzy: 8
# Barrobo Farjah vs Harper: phon: 50, fuzzy: 30
# Barrobo Farjah vs Jaedae: phon: 0, fuzzy: 20
# Barrobo Farjah vs Jeadepo: phon: 25, fuzzy: 19
# Barrobo Farjah vs Jo River: phon: 50, fuzzy: 27
# Barrobo Farjah vs Jorquelleh: phon: 25, fuzzy: 25
# Barrobo Farjah vs Juarzon: phon: 25, fuzzy: 29
# Barrobo Farjah vs Kakata: phon: 0, fuzzy: 30
# Barrobo Farjah vs Karforh: phon: 50, fuzzy: 48
# Barrobo Farjah vs Karluway #1: phon: 25, fuzzy: 24
# Barrobo Farjah vs Karluway #2: phon: 25, fuzzy: 24
# Barrobo Farjah vs Klay: phon: 0, fuzzy: 11
# Barrobo Farjah vs Kokoyah: phon: 0, fuzzy: 38
# Barrobo Farjah vs Kolahun: phon: 0, fuzzy: 29
# Barrobo Farjah vs Kongba: phon: 25, fuzzy: 30
# Barrobo Farjah vs Konobo: phon: 25, fuzzy: 30
# Barrobo Farjah vs Kpaai: phon: 25, fuzzy: 21
# Barrobo Farjah vs Kparblee: phon: 50, fuzzy: 27
# Barrobo Farjah vs Kpayan: phon: 25, fuzzy: 20
# Barrobo Farjah vs Kpi: phon: 25, fuzzy: 0
# Barrobo Farjah vs Kulu Shaw Boe: phon: 25, fuzzy: 15
# Barrobo Farjah vs Leewehpea-Mahn: phon: 25, fuzzy: 21
# Barrobo Farjah vs Lower Jloh: phon: 25, fuzzy: 25
# Barrobo Farjah vs Mambah Kaba: phon: 25, fuzzy: 40
# Barrobo Farjah vs Meinpea-Mahn: phon: 25, fuzzy: 23
# Barrobo Farjah vs Nanee: phon: 0, fuzzy: 11
# Barrobo Farjah vs Neekreen: phon: 25, fuzzy: 9
# Barrobo Farjah vs Norwein: phon: 25, fuzzy: 19
# Barrobo Farjah vs Nrokwia-Wesldow: phon: 25, fuzzy: 21
# Barrobo Farjah vs Nyenawliken: phon: 0, fuzzy: 8
# Barrobo Farjah vs Nyenebo: phon: 25, fuzzy: 19
# Barrobo Farjah vs Nyorken: phon: 25, fuzzy: 19
# Barrobo Farjah vs Owensgrove: phon: 25, fuzzy: 17
# Barrobo Farjah vs Panta: phon: 0, fuzzy: 21
# Barrobo Farjah vs Plahn Nyarn: phon: 0, fuzzy: 32
# Barrobo Farjah vs Pleebo/Sodoken: phon: 25, fuzzy: 14
# Barrobo Farjah vs Porkpa: phon: 50, fuzzy: 30
# Barrobo Farjah vs Potupo: phon: 25, fuzzy: 20
# Barrobo Farjah vs Putu: phon: 0, fuzzy: 0
# Barrobo Farjah vs Pynes Town: phon: 0, fuzzy: 8
# Barrobo Farjah vs Quardu Boundi: phon: 50, fuzzy: 22
# Barrobo Farjah vs Salala: phon: 0, fuzzy: 30
# Barrobo Farjah vs Salayea: phon: 0, fuzzy: 29
# Barrobo Farjah vs Sam Gbalor: phon: 25, fuzzy: 33
# Barrobo Farjah vs Sanniquellie Mahn: phon: 0, fuzzy: 26
# Barrobo Farjah vs Sanoyeah: phon: 0, fuzzy: 36
# Barrobo Farjah vs Sanquin Dist #1: phon: 0, fuzzy: 14
# Barrobo Farjah vs Sanquin Dist #2: phon: 0, fuzzy: 14
# Barrobo Farjah vs Sanquin Dist #3: phon: 0, fuzzy: 14
# Barrobo Farjah vs Sarbo: phon: 50, fuzzy: 42
# Barrobo Farjah vs Seekon: phon: 0, fuzzy: 10
# Barrobo Farjah vs Senjeh: phon: 0, fuzzy: 20
# Barrobo Farjah vs St. John River City: phon: 0, fuzzy: 18
# Barrobo Farjah vs St. Paul River: phon: 25, fuzzy: 21
# Barrobo Farjah vs Suakoko: phon: 0, fuzzy: 29
# Barrobo Farjah vs Suehn Mecca: phon: 0, fuzzy: 16
# Barrobo Farjah vs Tchien: phon: 0, fuzzy: 10
# Barrobo Farjah vs Tewor: phon: 25, fuzzy: 21
# Barrobo Farjah vs Todee: phon: 0, fuzzy: 11
# Barrobo Farjah vs Trenbo: phon: 50, fuzzy: 30
# Barrobo Farjah vs Tukpahblee: phon: 50, fuzzy: 17
# Barrobo Farjah vs Tuobo: phon: 25, fuzzy: 32
# Barrobo Farjah vs Twan River: phon: 50, fuzzy: 25
# Barrobo Farjah vs Upper Jloh: phon: 25, fuzzy: 25
# Barrobo Farjah vs Vahun: phon: 0, fuzzy: 21
# Barrobo Farjah vs Voinjama: phon: 0, fuzzy: 27
# Barrobo Farjah vs Wedjah: phon: 0, fuzzy: 30
# Barrobo Farjah vs Wee-Gbehyi-Mahn: phon: 25, fuzzy: 21
# Barrobo Farjah vs Whojah: phon: 0, fuzzy: 40
# Barrobo Farjah vs Wlogba: phon: 25, fuzzy: 30
# Barrobo Farjah vs Yarmein: phon: 25, fuzzy: 19
# Barrobo Farjah vs Yarpea Mahn: phon: 50, fuzzy: 40
# Barrobo Farjah vs Yarwein Mehnsonnoh: phon: 25, fuzzy: 31
# Barrobo Farjah vs Yeallequelleh: phon: 0, fuzzy: 15
# Barrobo Farjah vs Zarflahn: phon: 50, fuzzy: 36
# Barrobo Farjah vs Zoe-Gbao: phon: 25, fuzzy: 27
# Barrobo Farjah vs Zorzor: phon: 25, fuzzy: 30
# Barrobo Farjah vs Zota: phon: 0, fuzzy: 22
# Barrobo Farjah: ('Karforh', 48)
# Barrobo Whojah vs B'hai: phon: 25, fuzzy: 32
# Barrobo Whojah vs Barclayville: phon: 75, fuzzy: 31
# Barrobo Whojah vs Beawor: phon: 50, fuzzy: 30
# Barrobo Whojah vs Belleh: phon: 25, fuzzy: 20
# Barrobo Whojah vs Bleebo: phon: 50, fuzzy: 30
# Barrobo Whojah vs Bodae: phon: 25, fuzzy: 32
# Barrobo Whojah vs Boe & Quilla: phon: 50, fuzzy: 31
# Barrobo Whojah vs Boinsen: phon: 50, fuzzy: 19
# Barrobo Whojah vs Bokomu: phon: 50, fuzzy: 30
# Barrobo Whojah vs Bokon: phon: 50, fuzzy: 32
# Barrobo Whojah vs Bolloh: phon: 25, fuzzy: 40
# Barrobo Whojah vs Bopolu: phon: 50, fuzzy: 30
# Barrobo Whojah vs Buah: phon: 25, fuzzy: 33
# Barrobo Whojah vs Butaw: phon: 25, fuzzy: 21
# Barrobo Whojah vs Buu-Yao: phon: 25, fuzzy: 29
# Barrobo Whojah vs Careysburg: phon: 50, fuzzy: 25
# Barrobo Whojah vs Cavala: phon: 25, fuzzy: 20
# Barrobo Whojah vs Central Rivercess: phon: 25, fuzzy: 13
# Barrobo Whojah vs Chedepo: phon: 25, fuzzy: 19
# Barrobo Whojah vs Commonwealth: phon: 0, fuzzy: 31
# Barrobo Whojah vs Commonwealth 1: phon: 0, fuzzy: 29
# Barrobo Whojah vs Commonwealth 2: phon: 0, fuzzy: 29
# Barrobo Whojah vs District #1: phon: 25, fuzzy: 16
# Barrobo Whojah vs District #2: phon: 25, fuzzy: 16
# Barrobo Whojah vs District #3: phon: 25, fuzzy: 16
# Barrobo Whojah vs District #4: phon: 25, fuzzy: 16
# Barrobo Whojah vs Doe: phon: 0, fuzzy: 12
# Barrobo Whojah vs Doedain: phon: 0, fuzzy: 19
# Barrobo Whojah vs Dorbor: phon: 50, fuzzy: 30
# Barrobo Whojah vs Dowein: phon: 0, fuzzy: 10
# Barrobo Whojah vs Dugbe River: phon: 25, fuzzy: 16
# Barrobo Whojah vs Dweh: phon: 0, fuzzy: 11
# Barrobo Whojah vs Felo-Jekwi: phon: 25, fuzzy: 8
# Barrobo Whojah vs Fen River: phon: 50, fuzzy: 9
# Barrobo Whojah vs Fenetoe: phon: 0, fuzzy: 10
# Barrobo Whojah vs Firestone: phon: 50, fuzzy: 17
# Barrobo Whojah vs Forpoh: phon: 50, fuzzy: 30
# Barrobo Whojah vs Foya: phon: 0, fuzzy: 22
# Barrobo Whojah vs Fuamah: phon: 0, fuzzy: 30
# Barrobo Whojah vs Garr-Bain: phon: 50, fuzzy: 35
# Barrobo Whojah vs Garraway: phon: 25, fuzzy: 36
# Barrobo Whojah vs Garwula: phon: 25, fuzzy: 29
# Barrobo Whojah vs Gbao: phon: 25, fuzzy: 22
# Barrobo Whojah vs Gbarma: phon: 25, fuzzy: 30
# Barrobo Whojah vs Gbeapo: phon: 25, fuzzy: 20
# Barrobo Whojah vs Gbehlay-Geh: phon: 50, fuzzy: 32
# Barrobo Whojah vs Gbi & Doru: phon: 25, fuzzy: 25
# Barrobo Whojah vs Gboe-Ploe: phon: 25, fuzzy: 26
# Barrobo Whojah vs Gbor: phon: 25, fuzzy: 22
# Barrobo Whojah vs Gee: phon: 0, fuzzy: 0
# Barrobo Whojah vs Gibi: phon: 25, fuzzy: 11
# Barrobo Whojah vs Glaro: phon: 25, fuzzy: 32
# Barrobo Whojah vs Glio-Twarbo: phon: 25, fuzzy: 32
# Barrobo Whojah vs Golakonneh: phon: 25, fuzzy: 25
# Barrobo Whojah vs Gounwolaila: phon: 0, fuzzy: 24
# Barrobo Whojah vs Grand Cess Wedabo: phon: 25, fuzzy: 26
# Barrobo Whojah vs Greater Monrovia: phon: 25, fuzzy: 33
# Barrobo Whojah vs Greenville: phon: 50, fuzzy: 8
# Barrobo Whojah vs Gwelekpoken: phon: 25, fuzzy: 8
# Barrobo Whojah vs Harper: phon: 50, fuzzy: 30
# Barrobo Whojah vs Jaedae: phon: 0, fuzzy: 20
# Barrobo Whojah vs Jeadepo: phon: 25, fuzzy: 19
# Barrobo Whojah vs Jo River: phon: 50, fuzzy: 18
# Barrobo Whojah vs Jorquelleh: phon: 50, fuzzy: 17
# Barrobo Whojah vs Juarzon: phon: 50, fuzzy: 29
# Barrobo Whojah vs Kakata: phon: 25, fuzzy: 20
# Barrobo Whojah vs Karforh: phon: 50, fuzzy: 38
# Barrobo Whojah vs Karluway #1: phon: 25, fuzzy: 24
# Barrobo Whojah vs Karluway #2: phon: 25, fuzzy: 24
# Barrobo Whojah vs Klay: phon: 0, fuzzy: 11
# Barrobo Whojah vs Kokoyah: phon: 25, fuzzy: 38
# Barrobo Whojah vs Kolahun: phon: 0, fuzzy: 29
# Barrobo Whojah vs Kongba: phon: 25, fuzzy: 30
# Barrobo Whojah vs Konobo: phon: 25, fuzzy: 30
# Barrobo Whojah vs Kpaai: phon: 25, fuzzy: 21
# Barrobo Whojah vs Kparblee: phon: 50, fuzzy: 27
# Barrobo Whojah vs Kpayan: phon: 25, fuzzy: 20
# Barrobo Whojah vs Kpi: phon: 25, fuzzy: 0
# Barrobo Whojah vs Kulu Shaw Boe: phon: 25, fuzzy: 22
# Barrobo Whojah vs Leewehpea-Mahn: phon: 25, fuzzy: 21
# Barrobo Whojah vs Lower Jloh: phon: 50, fuzzy: 33
# Barrobo Whojah vs Mambah Kaba: phon: 50, fuzzy: 32
# Barrobo Whojah vs Meinpea-Mahn: phon: 25, fuzzy: 23
# Barrobo Whojah vs Nanee: phon: 0, fuzzy: 11
# Barrobo Whojah vs Neekreen: phon: 25, fuzzy: 9
# Barrobo Whojah vs Norwein: phon: 25, fuzzy: 10
# Barrobo Whojah vs Nrokwia-Wesldow: phon: 50, fuzzy: 28
# Barrobo Whojah vs Nyenawliken: phon: 25, fuzzy: 8
# Barrobo Whojah vs Nyenebo: phon: 25, fuzzy: 19
# Barrobo Whojah vs Nyorken: phon: 50, fuzzy: 10
# Barrobo Whojah vs Owensgrove: phon: 25, fuzzy: 17
# Barrobo Whojah vs Panta: phon: 0, fuzzy: 21
# Barrobo Whojah vs Plahn Nyarn: phon: 0, fuzzy: 24
# Barrobo Whojah vs Pleebo/Sodoken: phon: 50, fuzzy: 21
# Barrobo Whojah vs Porkpa: phon: 50, fuzzy: 20
# Barrobo Whojah vs Potupo: phon: 25, fuzzy: 20
# Barrobo Whojah vs Putu: phon: 0, fuzzy: 0
# Barrobo Whojah vs Pynes Town: phon: 25, fuzzy: 17
# Barrobo Whojah vs Quardu Boundi: phon: 50, fuzzy: 30
# Barrobo Whojah vs Salala: phon: 0, fuzzy: 20
# Barrobo Whojah vs Salayea: phon: 0, fuzzy: 19
# Barrobo Whojah vs Sam Gbalor: phon: 25, fuzzy: 25
# Barrobo Whojah vs Sanniquellie Mahn: phon: 25, fuzzy: 26
# Barrobo Whojah vs Sanoyeah: phon: 0, fuzzy: 36
# Barrobo Whojah vs Sanquin Dist #1: phon: 25, fuzzy: 14
# Barrobo Whojah vs Sanquin Dist #2: phon: 25, fuzzy: 14
# Barrobo Whojah vs Sanquin Dist #3: phon: 25, fuzzy: 14
# Barrobo Whojah vs Sarbo: phon: 50, fuzzy: 42
# Barrobo Whojah vs Seekon: phon: 25, fuzzy: 10
# Barrobo Whojah vs Senjeh: phon: 25, fuzzy: 20
# Barrobo Whojah vs St. John River City: phon: 25, fuzzy: 18
# Barrobo Whojah vs St. Paul River: phon: 25, fuzzy: 14
# Barrobo Whojah vs Suakoko: phon: 25, fuzzy: 29
# Barrobo Whojah vs Suehn Mecca: phon: 25, fuzzy: 16
# Barrobo Whojah vs Tchien: phon: 25, fuzzy: 10
# Barrobo Whojah vs Tewor: phon: 25, fuzzy: 11
# Barrobo Whojah vs Todee: phon: 0, fuzzy: 11
# Barrobo Whojah vs Trenbo: phon: 50, fuzzy: 30
# Barrobo Whojah vs Tukpahblee: phon: 25, fuzzy: 17
# Barrobo Whojah vs Tuobo: phon: 25, fuzzy: 32
# Barrobo Whojah vs Twan River: phon: 50, fuzzy: 17
# Barrobo Whojah vs Upper Jloh: phon: 50, fuzzy: 33
# Barrobo Whojah vs Vahun: phon: 0, fuzzy: 21
# Barrobo Whojah vs Voinjama: phon: 25, fuzzy: 27
# Barrobo Whojah vs Wedjah: phon: 25, fuzzy: 40
# Barrobo Whojah vs Wee-Gbehyi-Mahn: phon: 25, fuzzy: 28
# Barrobo Whojah vs Whojah: phon: 25, fuzzy: 60
# Barrobo Whojah vs Wlogba: phon: 25, fuzzy: 30
# Barrobo Whojah vs Yarmein: phon: 25, fuzzy: 19
# Barrobo Whojah vs Yarpea Mahn: phon: 50, fuzzy: 40
# Barrobo Whojah vs Yarwein Mehnsonnoh: phon: 25, fuzzy: 38
# Barrobo Whojah vs Yeallequelleh: phon: 25, fuzzy: 15
# Barrobo Whojah vs Zarflahn: phon: 50, fuzzy: 36
# Barrobo Whojah vs Zoe-Gbao: phon: 25, fuzzy: 27
# Barrobo Whojah vs Zorzor: phon: 50, fuzzy: 20
# Barrobo Whojah vs Zota: phon: 0, fuzzy: 22
# Barrobo Whojah: ('Barclayville', 75)
# Belleh vs B'hai: phon: 75, fuzzy: 36
# Belleh vs Barclayville: phon: 50, fuzzy: 44
# Belleh vs Beawor: phon: 75, fuzzy: 33
# Belleh vs Belleh: phon: 100, fuzzy: 100
# Belleh vs Bleebo: phon: 75, fuzzy: 50
# Belleh vs Bodae: phon: 75, fuzzy: 36
# Belleh vs Boe & Quilla: phon: 75, fuzzy: 44
# Belleh vs Boinsen: phon: 25, fuzzy: 31
# Belleh vs Bokomu: phon: 50, fuzzy: 17
# Belleh vs Bokon: phon: 50, fuzzy: 18
# Belleh vs Bolloh: phon: 100, fuzzy: 67
# Belleh vs Bopolu: phon: 75, fuzzy: 33
# Belleh vs Buah: phon: 75, fuzzy: 40
# Belleh vs Butaw: phon: 75, fuzzy: 18
# Belleh vs Buu-Yao: phon: 75, fuzzy: 15
# Belleh vs Careysburg: phon: 0, fuzzy: 12
# Belleh vs Cavala: phon: 50, fuzzy: 17
# Belleh vs Central Rivercess: phon: 0, fuzzy: 26
# Belleh vs Chedepo: phon: 25, fuzzy: 31
# Belleh vs Commonwealth: phon: 25, fuzzy: 33
# Belleh vs Commonwealth 1: phon: 25, fuzzy: 30
# Belleh vs Commonwealth 2: phon: 25, fuzzy: 30
# Belleh vs District #1: phon: 0, fuzzy: 0
# Belleh vs District #2: phon: 0, fuzzy: 0
# Belleh vs District #3: phon: 0, fuzzy: 0
# Belleh vs District #4: phon: 0, fuzzy: 0
# Belleh vs Doe: phon: 50, fuzzy: 22
# Belleh vs Doedain: phon: 25, fuzzy: 15
# Belleh vs Dorbor: phon: 0, fuzzy: 0
# Belleh vs Dowein: phon: 50, fuzzy: 17
# Belleh vs Dugbe River: phon: 0, fuzzy: 24
# Belleh vs Dweh: phon: 50, fuzzy: 40
# Belleh vs Felo-Jekwi: phon: 25, fuzzy: 38
# Belleh vs Fen River: phon: 0, fuzzy: 27
# Belleh vs Fenetoe: phon: 25, fuzzy: 31
# Belleh vs Firestone: phon: 0, fuzzy: 27
# Belleh vs Forpoh: phon: 25, fuzzy: 17
# Belleh vs Foya: phon: 50, fuzzy: 0
# Belleh vs Fuamah: phon: 50, fuzzy: 17
# Belleh vs Garr-Bain: phon: 0, fuzzy: 13
# Belleh vs Garraway: phon: 50, fuzzy: 0
# Belleh vs Garwula: phon: 50, fuzzy: 15
# Belleh vs Gbao: phon: 50, fuzzy: 0
# Belleh vs Gbarma: phon: 0, fuzzy: 0
# Belleh vs Gbeapo: phon: 25, fuzzy: 17
# Belleh vs Gbehlay-Geh: phon: 25, fuzzy: 47
# Belleh vs Gbi & Doru: phon: 0, fuzzy: 0
# Belleh vs Gboe-Ploe: phon: 25, fuzzy: 40
# Belleh vs Gbor: phon: 25, fuzzy: 0
# Belleh vs Gee: phon: 50, fuzzy: 44
# Belleh vs Gibi: phon: 50, fuzzy: 0
# Belleh vs Glaro: phon: 50, fuzzy: 18
# Belleh vs Glio-Twarbo: phon: 25, fuzzy: 12
# Belleh vs Golakonneh: phon: 25, fuzzy: 38
# Belleh vs Gounwolaila: phon: 25, fuzzy: 24
# Belleh vs Grand Cess Wedabo: phon: 0, fuzzy: 17
# Belleh vs Greater Monrovia: phon: 0, fuzzy: 18
# Belleh vs Greenville: phon: 0, fuzzy: 50
# Belleh vs Gwelekpoken: phon: 25, fuzzy: 35
# Belleh vs Harper: phon: 0, fuzzy: 17
# Belleh vs Jaedae: phon: 50, fuzzy: 33
# Belleh vs Jeadepo: phon: 25, fuzzy: 31
# Belleh vs Jo River: phon: 0, fuzzy: 14
# Belleh vs Jorquelleh: phon: 25, fuzzy: 62
# Belleh vs Juarzon: phon: 0, fuzzy: 0
# Belleh vs Kakata: phon: 25, fuzzy: 0
# Belleh vs Karforh: phon: 0, fuzzy: 15
# Belleh vs Karluway #1: phon: 50, fuzzy: 12
# Belleh vs Karluway #2: phon: 50, fuzzy: 12
# Belleh vs Klay: phon: 75, fuzzy: 20
# Belleh vs Kokoyah: phon: 50, fuzzy: 15
# Belleh vs Kolahun: phon: 50, fuzzy: 31
# Belleh vs Kongba: phon: 0, fuzzy: 0
# Belleh vs Konobo: phon: 25, fuzzy: 0
# Belleh vs Kpaai: phon: 50, fuzzy: 0
# Belleh vs Kparblee: phon: 0, fuzzy: 29
# Belleh vs Kpayan: phon: 25, fuzzy: 0
# Belleh vs Kpi: phon: 50, fuzzy: 0
# Belleh vs Kulu Shaw Boe: phon: 25, fuzzy: 21
# Belleh vs Leewehpea-Mahn: phon: 0, fuzzy: 30
# Belleh vs Lower Jloh: phon: 25, fuzzy: 38
# Belleh vs Mambah Kaba: phon: 0, fuzzy: 12
# Belleh vs Meinpea-Mahn: phon: 0, fuzzy: 33
# Belleh vs Nanee: phon: 50, fuzzy: 36
# Belleh vs Neekreen: phon: 0, fuzzy: 29
# Belleh vs Norwein: phon: 25, fuzzy: 15
# Belleh vs Nrokwia-Wesldow: phon: 0, fuzzy: 19
# Belleh vs Nyenawliken: phon: 25, fuzzy: 35
# Belleh vs Nyenebo: phon: 25, fuzzy: 31
# Belleh vs Nyorken: phon: 0, fuzzy: 15
# Belleh vs Owensgrove: phon: 0, fuzzy: 25
# Belleh vs Panta: phon: 25, fuzzy: 0
# Belleh vs Plahn Nyarn: phon: 25, fuzzy: 24
# Belleh vs Pleebo/Sodoken: phon: 25, fuzzy: 20
# Belleh vs Porkpa: phon: 0, fuzzy: 0
# Belleh vs Potupo: phon: 25, fuzzy: 0
# Belleh vs Putu: phon: 50, fuzzy: 0
# Belleh vs Pynes Town: phon: 0, fuzzy: 12
# Belleh vs Quardu Boundi: phon: 0, fuzzy: 11
# Belleh vs Salala: phon: 50, fuzzy: 33
# Belleh vs Salayea: phon: 75, fuzzy: 31
# Belleh vs Sam Gbalor: phon: 0, fuzzy: 12
# Belleh vs Sanniquellie Mahn: phon: 25, fuzzy: 43
# Belleh vs Sanoyeah: phon: 50, fuzzy: 29
# Belleh vs Sanquin Dist #1: phon: 0, fuzzy: 0
# Belleh vs Sanquin Dist #2: phon: 0, fuzzy: 0
# Belleh vs Sanquin Dist #3: phon: 0, fuzzy: 0
# Belleh vs Sarbo: phon: 25, fuzzy: 0
# Belleh vs Seekon: phon: 25, fuzzy: 33
# Belleh vs Senjeh: phon: 25, fuzzy: 50
# Belleh vs St. John River City: phon: 0, fuzzy: 8
# Belleh vs St. Paul River: phon: 25, fuzzy: 20
# Belleh vs Suakoko: phon: 25, fuzzy: 0
# Belleh vs Suehn Mecca: phon: 0, fuzzy: 24
# Belleh vs Tchien: phon: 25, fuzzy: 17
# Belleh vs Tewor: phon: 50, fuzzy: 18
# Belleh vs Todee: phon: 50, fuzzy: 36
# Belleh vs Trenbo: phon: 0, fuzzy: 17
# Belleh vs Tukpahblee: phon: 0, fuzzy: 25
# Belleh vs Tuobo: phon: 50, fuzzy: 0
# Belleh vs Twan River: phon: 0, fuzzy: 12
# Belleh vs Upper Jloh: phon: 0, fuzzy: 38
# Belleh vs Vahun: phon: 50, fuzzy: 18
# Belleh vs Voinjama: phon: 0, fuzzy: 0
# Belleh vs Wedjah: phon: 25, fuzzy: 33
# Belleh vs Wee-Gbehyi-Mahn: phon: 0, fuzzy: 29
# Belleh vs Whojah: phon: 50, fuzzy: 17
# Belleh vs Wlogba: phon: 25, fuzzy: 17
# Belleh vs Yarmein: phon: 0, fuzzy: 15
# Belleh vs Yarpea Mahn: phon: 0, fuzzy: 24
# Belleh vs Yarwein Mehnsonnoh: phon: 0, fuzzy: 25
# Belleh vs Yeallequelleh: phon: 25, fuzzy: 53
# Belleh vs Zarflahn: phon: 25, fuzzy: 29
# Belleh vs Zoe-Gbao: phon: 25, fuzzy: 14
# Belleh vs Zorzor: phon: 0, fuzzy: 0
# Belleh vs Zota: phon: 50, fuzzy: 0
# Belleh: ('Belleh', 100)
# Bokomu vs B'hai: phon: 50, fuzzy: 18
# Bokomu vs Barclayville: phon: 50, fuzzy: 11
# Bokomu vs Beawor: phon: 50, fuzzy: 33
# Bokomu vs Belleh: phon: 50, fuzzy: 17
# Bokomu vs Bleebo: phon: 50, fuzzy: 33
# Bokomu vs Bodae: phon: 50, fuzzy: 36
# Bokomu vs Boe & Quilla: phon: 75, fuzzy: 33
# Bokomu vs Boinsen: phon: 75, fuzzy: 31
# Bokomu vs Bokomu: phon: 100, fuzzy: 100
# Bokomu vs Bokon: phon: 100, fuzzy: 73
# Bokomu vs Bolloh: phon: 50, fuzzy: 50
# Bokomu vs Bopolu: phon: 50, fuzzy: 67
# Bokomu vs Buah: phon: 50, fuzzy: 40
# Bokomu vs Butaw: phon: 50, fuzzy: 36
# Bokomu vs Buu-Yao: phon: 50, fuzzy: 31
# Bokomu vs Careysburg: phon: 25, fuzzy: 12
# Bokomu vs Cavala: phon: 25, fuzzy: 0
# Bokomu vs Central Rivercess: phon: 25, fuzzy: 0
# Bokomu vs Chedepo: phon: 25, fuzzy: 15
# Bokomu vs Commonwealth: phon: 25, fuzzy: 22
# Bokomu vs Commonwealth 1: phon: 25, fuzzy: 20
# Bokomu vs Commonwealth 2: phon: 25, fuzzy: 20
# Bokomu vs District #1: phon: 25, fuzzy: 0
# Bokomu vs District #2: phon: 25, fuzzy: 0
# Bokomu vs District #3: phon: 25, fuzzy: 0
# Bokomu vs District #4: phon: 25, fuzzy: 0
# Bokomu vs Doe: phon: 25, fuzzy: 22
# Bokomu vs Doedain: phon: 50, fuzzy: 15
# Bokomu vs Dorbor: phon: 0, fuzzy: 33
# Bokomu vs Dowein: phon: 50, fuzzy: 17
# Bokomu vs Dugbe River: phon: 25, fuzzy: 12
# Bokomu vs Dweh: phon: 25, fuzzy: 0
# Bokomu vs Felo-Jekwi: phon: 25, fuzzy: 25
# Bokomu vs Fen River: phon: 25, fuzzy: 0
# Bokomu vs Fenetoe: phon: 50, fuzzy: 15
# Bokomu vs Firestone: phon: 25, fuzzy: 13
# Bokomu vs Forpoh: phon: 25, fuzzy: 33
# Bokomu vs Foya: phon: 25, fuzzy: 20
# Bokomu vs Fuamah: phon: 50, fuzzy: 17
# Bokomu vs Garr-Bain: phon: 25, fuzzy: 13
# Bokomu vs Garraway: phon: 25, fuzzy: 0
# Bokomu vs Garwula: phon: 25, fuzzy: 15
# Bokomu vs Gbao: phon: 25, fuzzy: 20
# Bokomu vs Gbarma: phon: 25, fuzzy: 17
# Bokomu vs Gbeapo: phon: 25, fuzzy: 17
# Bokomu vs Gbehlay-Geh: phon: 25, fuzzy: 0
# Bokomu vs Gbi & Doru: phon: 0, fuzzy: 25
# Bokomu vs Gboe-Ploe: phon: 0, fuzzy: 27
# Bokomu vs Gbor: phon: 25, fuzzy: 20
# Bokomu vs Gee: phon: 25, fuzzy: 0
# Bokomu vs Gibi: phon: 25, fuzzy: 0
# Bokomu vs Glaro: phon: 25, fuzzy: 18
# Bokomu vs Glio-Twarbo: phon: 0, fuzzy: 24
# Bokomu vs Golakonneh: phon: 50, fuzzy: 38
# Bokomu vs Gounwolaila: phon: 25, fuzzy: 24
# Bokomu vs Grand Cess Wedabo: phon: 25, fuzzy: 9
# Bokomu vs Greater Monrovia: phon: 0, fuzzy: 18
# Bokomu vs Greenville: phon: 25, fuzzy: 0
# Bokomu vs Gwelekpoken: phon: 25, fuzzy: 24
# Bokomu vs Harper: phon: 0, fuzzy: 0
# Bokomu vs Jaedae: phon: 25, fuzzy: 0
# Bokomu vs Jeadepo: phon: 25, fuzzy: 15
# Bokomu vs Jo River: phon: 0, fuzzy: 14
# Bokomu vs Jorquelleh: phon: 25, fuzzy: 25
# Bokomu vs Juarzon: phon: 50, fuzzy: 15
# Bokomu vs Kakata: phon: 50, fuzzy: 17
# Bokomu vs Karforh: phon: 0, fuzzy: 15
# Bokomu vs Karluway #1: phon: 25, fuzzy: 12
# Bokomu vs Karluway #2: phon: 25, fuzzy: 12
# Bokomu vs Klay: phon: 25, fuzzy: 0
# Bokomu vs Kokoyah: phon: 50, fuzzy: 46
# Bokomu vs Kolahun: phon: 50, fuzzy: 31
# Bokomu vs Kongba: phon: 25, fuzzy: 17
# Bokomu vs Konobo: phon: 50, fuzzy: 33
# Bokomu vs Kpaai: phon: 25, fuzzy: 0
# Bokomu vs Kparblee: phon: 0, fuzzy: 0
# Bokomu vs Kpayan: phon: 50, fuzzy: 0
# Bokomu vs Kpi: phon: 25, fuzzy: 0
# Bokomu vs Kulu Shaw Boe: phon: 25, fuzzy: 21
# Bokomu vs Leewehpea-Mahn: phon: 25, fuzzy: 0
# Bokomu vs Lower Jloh: phon: 25, fuzzy: 25
# Bokomu vs Mambah Kaba: phon: 25, fuzzy: 12
# Bokomu vs Meinpea-Mahn: phon: 25, fuzzy: 0
# Bokomu vs Nanee: phon: 50, fuzzy: 0
# Bokomu vs Neekreen: phon: 50, fuzzy: 14
# Bokomu vs Norwein: phon: 50, fuzzy: 15
# Bokomu vs Nrokwia-Wesldow: phon: 25, fuzzy: 29
# Bokomu vs Nyenawliken: phon: 25, fuzzy: 12
# Bokomu vs Nyenebo: phon: 50, fuzzy: 15
# Bokomu vs Nyorken: phon: 50, fuzzy: 31
# Bokomu vs Owensgrove: phon: 25, fuzzy: 12
# Bokomu vs Panta: phon: 50, fuzzy: 0
# Bokomu vs Plahn Nyarn: phon: 25, fuzzy: 0
# Bokomu vs Pleebo/Sodoken: phon: 25, fuzzy: 20
# Bokomu vs Porkpa: phon: 25, fuzzy: 33
# Bokomu vs Potupo: phon: 25, fuzzy: 33
# Bokomu vs Putu: phon: 25, fuzzy: 20
# Bokomu vs Pynes Town: phon: 25, fuzzy: 12
# Bokomu vs Quardu Boundi: phon: 0, fuzzy: 32
# Bokomu vs Salala: phon: 25, fuzzy: 0
# Bokomu vs Salayea: phon: 25, fuzzy: 0
# Bokomu vs Sam Gbalor: phon: 25, fuzzy: 12
# Bokomu vs Sanniquellie Mahn: phon: 25, fuzzy: 9
# Bokomu vs Sanoyeah: phon: 50, fuzzy: 14
# Bokomu vs Sanquin Dist #1: phon: 50, fuzzy: 10
# Bokomu vs Sanquin Dist #2: phon: 50, fuzzy: 10
# Bokomu vs Sanquin Dist #3: phon: 50, fuzzy: 10
# Bokomu vs Sarbo: phon: 25, fuzzy: 18
# Bokomu vs Seekon: phon: 75, fuzzy: 33
# Bokomu vs Senjeh: phon: 50, fuzzy: 0
# Bokomu vs St. John River City: phon: 50, fuzzy: 8
# Bokomu vs St. Paul River: phon: 0, fuzzy: 10
# Bokomu vs Suakoko: phon: 50, fuzzy: 46
# Bokomu vs Suehn Mecca: phon: 25, fuzzy: 12
# Bokomu vs Tchien: phon: 75, fuzzy: 0
# Bokomu vs Tewor: phon: 25, fuzzy: 18
# Bokomu vs Todee: phon: 25, fuzzy: 18
# Bokomu vs Trenbo: phon: 25, fuzzy: 17
# Bokomu vs Tukpahblee: phon: 25, fuzzy: 12
# Bokomu vs Tuobo: phon: 25, fuzzy: 36
# Bokomu vs Twan River: phon: 25, fuzzy: 0
# Bokomu vs Upper Jloh: phon: 25, fuzzy: 12
# Bokomu vs Vahun: phon: 50, fuzzy: 18
# Bokomu vs Voinjama: phon: 50, fuzzy: 29
# Bokomu vs Wedjah: phon: 50, fuzzy: 0
# Bokomu vs Wee-Gbehyi-Mahn: phon: 50, fuzzy: 0
# Bokomu vs Whojah: phon: 50, fuzzy: 17
# Bokomu vs Wlogba: phon: 25, fuzzy: 17
# Bokomu vs Yarmein: phon: 25, fuzzy: 15
# Bokomu vs Yarpea Mahn: phon: 25, fuzzy: 0
# Bokomu vs Yarwein Mehnsonnoh: phon: 25, fuzzy: 17
# Bokomu vs Yeallequelleh: phon: 25, fuzzy: 11
# Bokomu vs Zarflahn: phon: 0, fuzzy: 0
# Bokomu vs Zoe-Gbao: phon: 50, fuzzy: 29
# Bokomu vs Zorzor: phon: 25, fuzzy: 33
# Bokomu vs Zota: phon: 25, fuzzy: 20
# Bokomu: ('Bokomu', 100)
# Bopolu vs B'hai: phon: 50, fuzzy: 18
# Bopolu vs Barclayville: phon: 50, fuzzy: 22
# Bopolu vs Beawor: phon: 50, fuzzy: 33
# Bopolu vs Belleh: phon: 75, fuzzy: 33
# Bopolu vs Bleebo: phon: 75, fuzzy: 33
# Bopolu vs Bodae: phon: 50, fuzzy: 36
# Bopolu vs Boe & Quilla: phon: 75, fuzzy: 33
# Bopolu vs Boinsen: phon: 25, fuzzy: 31
# Bopolu vs Bokomu: phon: 50, fuzzy: 67
# Bopolu vs Bokon: phon: 50, fuzzy: 55
# Bopolu vs Bolloh: phon: 75, fuzzy: 50
# Bopolu vs Bopolu: phon: 100, fuzzy: 100
# Bopolu vs Buah: phon: 50, fuzzy: 40
# Bopolu vs Butaw: phon: 50, fuzzy: 36
# Bopolu vs Buu-Yao: phon: 50, fuzzy: 31
# Bopolu vs Careysburg: phon: 25, fuzzy: 12
# Bopolu vs Cavala: phon: 75, fuzzy: 17
# Bopolu vs Central Rivercess: phon: 0, fuzzy: 9
# Bopolu vs Chedepo: phon: 50, fuzzy: 31
# Bopolu vs Commonwealth: phon: 25, fuzzy: 33
# Bopolu vs Commonwealth 1: phon: 25, fuzzy: 30
# Bopolu vs Commonwealth 2: phon: 25, fuzzy: 30
# Bopolu vs District #1: phon: 0, fuzzy: 0
# Bopolu vs District #2: phon: 0, fuzzy: 0
# Bopolu vs District #3: phon: 0, fuzzy: 0
# Bopolu vs District #4: phon: 0, fuzzy: 0
# Bopolu vs Doe: phon: 25, fuzzy: 22
# Bopolu vs Doedain: phon: 25, fuzzy: 15
# Bopolu vs Dorbor: phon: 25, fuzzy: 33
# Bopolu vs Dowein: phon: 25, fuzzy: 17
# Bopolu vs Dugbe River: phon: 25, fuzzy: 12
# Bopolu vs Dweh: phon: 25, fuzzy: 0
# Bopolu vs Felo-Jekwi: phon: 25, fuzzy: 12
# Bopolu vs Fen River: phon: 25, fuzzy: 0
# Bopolu vs Fenetoe: phon: 25, fuzzy: 15
# Bopolu vs Firestone: phon: 0, fuzzy: 13
# Bopolu vs Forpoh: phon: 50, fuzzy: 50
# Bopolu vs Foya: phon: 25, fuzzy: 20
# Bopolu vs Fuamah: phon: 25, fuzzy: 17
# Bopolu vs Garr-Bain: phon: 25, fuzzy: 13
# Bopolu vs Garraway: phon: 25, fuzzy: 0
# Bopolu vs Garwula: phon: 50, fuzzy: 15
# Bopolu vs Gbao: phon: 50, fuzzy: 20
# Bopolu vs Gbarma: phon: 25, fuzzy: 0
# Bopolu vs Gbeapo: phon: 50, fuzzy: 33
# Bopolu vs Gbehlay-Geh: phon: 50, fuzzy: 12
# Bopolu vs Gbi & Doru: phon: 25, fuzzy: 25
# Bopolu vs Gboe-Ploe: phon: 50, fuzzy: 27
# Bopolu vs Gbor: phon: 50, fuzzy: 20
# Bopolu vs Gee: phon: 25, fuzzy: 0
# Bopolu vs Gibi: phon: 50, fuzzy: 0
# Bopolu vs Glaro: phon: 50, fuzzy: 18
# Bopolu vs Glio-Twarbo: phon: 25, fuzzy: 24
# Bopolu vs Golakonneh: phon: 25, fuzzy: 25
# Bopolu vs Gounwolaila: phon: 25, fuzzy: 35
# Bopolu vs Grand Cess Wedabo: phon: 0, fuzzy: 9
# Bopolu vs Greater Monrovia: phon: 0, fuzzy: 18
# Bopolu vs Greenville: phon: 25, fuzzy: 12
# Bopolu vs Gwelekpoken: phon: 25, fuzzy: 24
# Bopolu vs Harper: phon: 25, fuzzy: 17
# Bopolu vs Jaedae: phon: 25, fuzzy: 0
# Bopolu vs Jeadepo: phon: 50, fuzzy: 31
# Bopolu vs Jo River: phon: 25, fuzzy: 14
# Bopolu vs Jorquelleh: phon: 25, fuzzy: 25
# Bopolu vs Juarzon: phon: 0, fuzzy: 15
# Bopolu vs Kakata: phon: 25, fuzzy: 0
# Bopolu vs Karforh: phon: 25, fuzzy: 15
# Bopolu vs Karluway #1: phon: 50, fuzzy: 24
# Bopolu vs Karluway #2: phon: 50, fuzzy: 24
# Bopolu vs Klay: phon: 50, fuzzy: 20
# Bopolu vs Kokoyah: phon: 25, fuzzy: 31
# Bopolu vs Kolahun: phon: 50, fuzzy: 46
# Bopolu vs Kongba: phon: 25, fuzzy: 17
# Bopolu vs Konobo: phon: 50, fuzzy: 33
# Bopolu vs Kpaai: phon: 50, fuzzy: 18
# Bopolu vs Kparblee: phon: 25, fuzzy: 29
# Bopolu vs Kpayan: phon: 50, fuzzy: 17
# Bopolu vs Kpi: phon: 50, fuzzy: 22
# Bopolu vs Kulu Shaw Boe: phon: 25, fuzzy: 21
# Bopolu vs Leewehpea-Mahn: phon: 25, fuzzy: 10
# Bopolu vs Lower Jloh: phon: 25, fuzzy: 25
# Bopolu vs Mambah Kaba: phon: 25, fuzzy: 0
# Bopolu vs Meinpea-Mahn: phon: 25, fuzzy: 11
# Bopolu vs Nanee: phon: 25, fuzzy: 0
# Bopolu vs Neekreen: phon: 0, fuzzy: 0
# Bopolu vs Norwein: phon: 25, fuzzy: 15
# Bopolu vs Nrokwia-Wesldow: phon: 0, fuzzy: 19
# Bopolu vs Nyenawliken: phon: 25, fuzzy: 12
# Bopolu vs Nyenebo: phon: 50, fuzzy: 15
# Bopolu vs Nyorken: phon: 0, fuzzy: 15
# Bopolu vs Owensgrove: phon: 0, fuzzy: 12
# Bopolu vs Panta: phon: 25, fuzzy: 0
# Bopolu vs Plahn Nyarn: phon: 25, fuzzy: 12
# Bopolu vs Pleebo/Sodoken: phon: 25, fuzzy: 20
# Bopolu vs Porkpa: phon: 25, fuzzy: 33
# Bopolu vs Potupo: phon: 50, fuzzy: 50
# Bopolu vs Putu: phon: 25, fuzzy: 20
# Bopolu vs Pynes Town: phon: 0, fuzzy: 12
# Bopolu vs Quardu Boundi: phon: 25, fuzzy: 32
# Bopolu vs Salala: phon: 50, fuzzy: 17
# Bopolu vs Salayea: phon: 50, fuzzy: 15
# Bopolu vs Sam Gbalor: phon: 25, fuzzy: 12
# Bopolu vs Sanniquellie Mahn: phon: 25, fuzzy: 9
# Bopolu vs Sanoyeah: phon: 25, fuzzy: 14
# Bopolu vs Sanquin Dist #1: phon: 0, fuzzy: 10
# Bopolu vs Sanquin Dist #2: phon: 0, fuzzy: 10
# Bopolu vs Sanquin Dist #3: phon: 0, fuzzy: 10
# Bopolu vs Sarbo: phon: 50, fuzzy: 18
# Bopolu vs Seekon: phon: 25, fuzzy: 17
# Bopolu vs Senjeh: phon: 25, fuzzy: 0
# Bopolu vs St. John River City: phon: 0, fuzzy: 8
# Bopolu vs St. Paul River: phon: 50, fuzzy: 10
# Bopolu vs Suakoko: phon: 25, fuzzy: 31
# Bopolu vs Suehn Mecca: phon: 0, fuzzy: 12
# Bopolu vs Tchien: phon: 25, fuzzy: 0
# Bopolu vs Tewor: phon: 25, fuzzy: 18
# Bopolu vs Todee: phon: 25, fuzzy: 18
# Bopolu vs Trenbo: phon: 25, fuzzy: 17
# Bopolu vs Tukpahblee: phon: 25, fuzzy: 25
# Bopolu vs Tuobo: phon: 50, fuzzy: 36
# Bopolu vs Twan River: phon: 25, fuzzy: 0
# Bopolu vs Upper Jloh: phon: 25, fuzzy: 25
# Bopolu vs Vahun: phon: 25, fuzzy: 18
# Bopolu vs Voinjama: phon: 0, fuzzy: 14
# Bopolu vs Wedjah: phon: 25, fuzzy: 0
# Bopolu vs Wee-Gbehyi-Mahn: phon: 25, fuzzy: 0
# Bopolu vs Whojah: phon: 25, fuzzy: 17
# Bopolu vs Wlogba: phon: 25, fuzzy: 17
# Bopolu vs Yarmein: phon: 0, fuzzy: 0
# Bopolu vs Yarpea Mahn: phon: 25, fuzzy: 12
# Bopolu vs Yarwein Mehnsonnoh: phon: 0, fuzzy: 17
# Bopolu vs Yeallequelleh: phon: 25, fuzzy: 21
# Bopolu vs Zarflahn: phon: 50, fuzzy: 14
# Bopolu vs Zoe-Gbao: phon: 50, fuzzy: 29
# Bopolu vs Zorzor: phon: 0, fuzzy: 33
# Bopolu vs Zota: phon: 25, fuzzy: 20
# Bopolu: ('Bopolu', 100)
# Buah vs B'hai: phon: 100, fuzzy: 44
# Buah vs Barclayville: phon: 25, fuzzy: 25
# Buah vs Beawor: phon: 75, fuzzy: 40
# Buah vs Belleh: phon: 75, fuzzy: 40
# Buah vs Bleebo: phon: 50, fuzzy: 20
# Buah vs Bodae: phon: 75, fuzzy: 44
# Buah vs Boe & Quilla: phon: 50, fuzzy: 38
# Buah vs Boinsen: phon: 25, fuzzy: 18
# Buah vs Bokomu: phon: 50, fuzzy: 40
# Buah vs Bokon: phon: 50, fuzzy: 22
# Buah vs Bolloh: phon: 75, fuzzy: 40
# Buah vs Bopolu: phon: 50, fuzzy: 40
# Buah vs Buah: phon: 100, fuzzy: 100
# Buah vs Butaw: phon: 75, fuzzy: 67
# Buah vs Buu-Yao: phon: 100, fuzzy: 55
# Buah vs Careysburg: phon: 0, fuzzy: 14
# Buah vs Cavala: phon: 25, fuzzy: 20
# Buah vs Central Rivercess: phon: 0, fuzzy: 10
# Buah vs Chedepo: phon: 25, fuzzy: 18
# Buah vs Commonwealth: phon: 0, fuzzy: 25
# Buah vs Commonwealth 1: phon: 0, fuzzy: 22
# Buah vs Commonwealth 2: phon: 0, fuzzy: 22
# Buah vs District #1: phon: 0, fuzzy: 0
# Buah vs District #2: phon: 0, fuzzy: 0
# Buah vs District #3: phon: 0, fuzzy: 0
# Buah vs District #4: phon: 0, fuzzy: 0
# Buah vs Doe: phon: 75, fuzzy: 0
# Buah vs Doedain: phon: 25, fuzzy: 18
# Buah vs Dorbor: phon: 0, fuzzy: 0
# Buah vs Dowein: phon: 50, fuzzy: 0
# Buah vs Dugbe River: phon: 0, fuzzy: 13
# Buah vs Dweh: phon: 75, fuzzy: 25
# Buah vs Felo-Jekwi: phon: 0, fuzzy: 0
# Buah vs Fen River: phon: 0, fuzzy: 0
# Buah vs Fenetoe: phon: 25, fuzzy: 0
# Buah vs Firestone: phon: 0, fuzzy: 0
# Buah vs Forpoh: phon: 25, fuzzy: 20
# Buah vs Foya: phon: 75, fuzzy: 25
# Buah vs Fuamah: phon: 50, fuzzy: 60
# Buah vs Garr-Bain: phon: 0, fuzzy: 31
# Buah vs Garraway: phon: 50, fuzzy: 17
# Buah vs Garwula: phon: 25, fuzzy: 36
# Buah vs Gbao: phon: 50, fuzzy: 25
# Buah vs Gbarma: phon: 0, fuzzy: 20
# Buah vs Gbeapo: phon: 25, fuzzy: 20
# Buah vs Gbehlay-Geh: phon: 0, fuzzy: 27
# Buah vs Gbi & Doru: phon: 0, fuzzy: 14
# Buah vs Gboe-Ploe: phon: 0, fuzzy: 0
# Buah vs Gbor: phon: 25, fuzzy: 0
# Buah vs Gee: phon: 75, fuzzy: 0
# Buah vs Gibi: phon: 50, fuzzy: 0
# Buah vs Glaro: phon: 25, fuzzy: 22
# Buah vs Glio-Twarbo: phon: 0, fuzzy: 13
# Buah vs Golakonneh: phon: 0, fuzzy: 29
# Buah vs Gounwolaila: phon: 0, fuzzy: 27
# Buah vs Grand Cess Wedabo: phon: 0, fuzzy: 10
# Buah vs Greater Monrovia: phon: 0, fuzzy: 10
# Buah vs Greenville: phon: 0, fuzzy: 0
# Buah vs Gwelekpoken: phon: 0, fuzzy: 0
# Buah vs Harper: phon: 0, fuzzy: 20
# Buah vs Jaedae: phon: 50, fuzzy: 20
# Buah vs Jeadepo: phon: 25, fuzzy: 18
# Buah vs Jo River: phon: 0, fuzzy: 0
# Buah vs Jorquelleh: phon: 0, fuzzy: 29
# Buah vs Juarzon: phon: 0, fuzzy: 36
# Buah vs Kakata: phon: 25, fuzzy: 20
# Buah vs Karforh: phon: 0, fuzzy: 36
# Buah vs Karluway #1: phon: 25, fuzzy: 27
# Buah vs Karluway #2: phon: 25, fuzzy: 27
# Buah vs Klay: phon: 50, fuzzy: 25
# Buah vs Kokoyah: phon: 50, fuzzy: 36
# Buah vs Kolahun: phon: 25, fuzzy: 36
# Buah vs Kongba: phon: 0, fuzzy: 20
# Buah vs Konobo: phon: 25, fuzzy: 0
# Buah vs Kpaai: phon: 50, fuzzy: 22
# Buah vs Kparblee: phon: 0, fuzzy: 17
# Buah vs Kpayan: phon: 25, fuzzy: 20
# Buah vs Kpi: phon: 50, fuzzy: 0
# Buah vs Kulu Shaw Boe: phon: 0, fuzzy: 24
# Buah vs Leewehpea-Mahn: phon: 0, fuzzy: 22
# Buah vs Lower Jloh: phon: 0, fuzzy: 14
# Buah vs Mambah Kaba: phon: 0, fuzzy: 27
# Buah vs Meinpea-Mahn: phon: 0, fuzzy: 25
# Buah vs Nanee: phon: 50, fuzzy: 22
# Buah vs Neekreen: phon: 0, fuzzy: 0
# Buah vs Norwein: phon: 25, fuzzy: 0
# Buah vs Nrokwia-Wesldow: phon: 0, fuzzy: 11
# Buah vs Nyenawliken: phon: 0, fuzzy: 13
# Buah vs Nyenebo: phon: 25, fuzzy: 0
# Buah vs Nyorken: phon: 0, fuzzy: 0
# Buah vs Owensgrove: phon: 0, fuzzy: 0
# Buah vs Panta: phon: 25, fuzzy: 22
# Buah vs Plahn Nyarn: phon: 0, fuzzy: 27
# Buah vs Pleebo/Sodoken: phon: 0, fuzzy: 0
# Buah vs Porkpa: phon: 0, fuzzy: 20
# Buah vs Potupo: phon: 25, fuzzy: 20
# Buah vs Putu: phon: 50, fuzzy: 25
# Buah vs Pynes Town: phon: 0, fuzzy: 0
# Buah vs Quardu Boundi: phon: 0, fuzzy: 24
# Buah vs Salala: phon: 25, fuzzy: 20
# Buah vs Salayea: phon: 50, fuzzy: 18
# Buah vs Sam Gbalor: phon: 0, fuzzy: 14
# Buah vs Sanniquellie Mahn: phon: 0, fuzzy: 29
# Buah vs Sanoyeah: phon: 50, fuzzy: 33
# Buah vs Sanquin Dist #1: phon: 0, fuzzy: 11
# Buah vs Sanquin Dist #2: phon: 0, fuzzy: 11
# Buah vs Sanquin Dist #3: phon: 0, fuzzy: 11
# Buah vs Sarbo: phon: 25, fuzzy: 22
# Buah vs Seekon: phon: 25, fuzzy: 0
# Buah vs Senjeh: phon: 25, fuzzy: 20
# Buah vs St. John River City: phon: 0, fuzzy: 9
# Buah vs St. Paul River: phon: 0, fuzzy: 11
# Buah vs Suakoko: phon: 25, fuzzy: 36
# Buah vs Suehn Mecca: phon: 0, fuzzy: 27
# Buah vs Tchien: phon: 25, fuzzy: 20
# Buah vs Tewor: phon: 50, fuzzy: 0
# Buah vs Todee: phon: 50, fuzzy: 0
# Buah vs Trenbo: phon: 0, fuzzy: 0
# Buah vs Tukpahblee: phon: 0, fuzzy: 43
# Buah vs Tuobo: phon: 50, fuzzy: 22
# Buah vs Twan River: phon: 0, fuzzy: 14
# Buah vs Upper Jloh: phon: 0, fuzzy: 14
# Buah vs Vahun: phon: 50, fuzzy: 44
# Buah vs Voinjama: phon: 0, fuzzy: 17
# Buah vs Wedjah: phon: 25, fuzzy: 40
# Buah vs Wee-Gbehyi-Mahn: phon: 0, fuzzy: 21
# Buah vs Whojah: phon: 50, fuzzy: 40
# Buah vs Wlogba: phon: 0, fuzzy: 20
# Buah vs Yarmein: phon: 0, fuzzy: 18
# Buah vs Yarpea Mahn: phon: 0, fuzzy: 27
# Buah vs Yarwein Mehnsonnoh: phon: 0, fuzzy: 18
# Buah vs Yeallequelleh: phon: 0, fuzzy: 24
# Buah vs Zarflahn: phon: 0, fuzzy: 33
# Buah vs Zoe-Gbao: phon: 25, fuzzy: 17
# Buah vs Zorzor: phon: 0, fuzzy: 0
# Buah vs Zota: phon: 50, fuzzy: 25
# Buah: ("B'hai", 100)
# Buchanan vs B'hai: phon: 25, fuzzy: 46
# Buchanan vs Barclayville: phon: 50, fuzzy: 30
# Buchanan vs Beawor: phon: 25, fuzzy: 29
# Buchanan vs Belleh: phon: 25, fuzzy: 29
# Buchanan vs Bleebo: phon: 25, fuzzy: 14
# Buchanan vs Bodae: phon: 25, fuzzy: 31
# Buchanan vs Boe & Quilla: phon: 50, fuzzy: 30
# Buchanan vs Boinsen: phon: 75, fuzzy: 40
# Buchanan vs Bokomu: phon: 75, fuzzy: 29
# Buchanan vs Bokon: phon: 75, fuzzy: 31
# Buchanan vs Bolloh: phon: 25, fuzzy: 29
# Buchanan vs Bopolu: phon: 25, fuzzy: 29
# Buchanan vs Buah: phon: 25, fuzzy: 50
# Buchanan vs Butaw: phon: 25, fuzzy: 46
# Buchanan vs Buu-Yao: phon: 25, fuzzy: 40
# Buchanan vs Careysburg: phon: 25, fuzzy: 11
# Buchanan vs Cavala: phon: 0, fuzzy: 29
# Buchanan vs Central Rivercess: phon: 25, fuzzy: 16
# Buchanan vs Chedepo: phon: 0, fuzzy: 13
# Buchanan vs Commonwealth: phon: 50, fuzzy: 20
# Buchanan vs Commonwealth 1: phon: 50, fuzzy: 18
# Buchanan vs Commonwealth 2: phon: 50, fuzzy: 18
# Buchanan vs District #1: phon: 25, fuzzy: 11
# Buchanan vs District #2: phon: 25, fuzzy: 11
# Buchanan vs District #3: phon: 25, fuzzy: 11
# Buchanan vs District #4: phon: 25, fuzzy: 11
# Buchanan vs Doe: phon: 0, fuzzy: 0
# Buchanan vs Doedain: phon: 25, fuzzy: 27
# Buchanan vs Dorbor: phon: 0, fuzzy: 0
# Buchanan vs Dowein: phon: 25, fuzzy: 14
# Buchanan vs Dugbe River: phon: 25, fuzzy: 11
# Buchanan vs Dweh: phon: 0, fuzzy: 17
# Buchanan vs Felo-Jekwi: phon: 25, fuzzy: 0
# Buchanan vs Fen River: phon: 25, fuzzy: 12
# Buchanan vs Fenetoe: phon: 25, fuzzy: 13
# Buchanan vs Firestone: phon: 25, fuzzy: 12
# Buchanan vs Forpoh: phon: 0, fuzzy: 14
# Buchanan vs Foya: phon: 0, fuzzy: 17
# Buchanan vs Fuamah: phon: 25, fuzzy: 43
# ...
# Zoe-Geh vs Boinsen: phon: 25, fuzzy: 29
# Zoe-Geh vs Bokomu: phon: 50, fuzzy: 15
# Zoe-Geh vs Bokon: phon: 50, fuzzy: 17
# Zoe-Geh vs Bolloh: phon: 50, fuzzy: 31
# Zoe-Geh vs Bopolu: phon: 25, fuzzy: 15
# Zoe-Geh vs Buah: phon: 50, fuzzy: 18
# Zoe-Geh vs Butaw: phon: 50, fuzzy: 0
# Zoe-Geh vs Buu-Yao: phon: 50, fuzzy: 14
# Zoe-Geh vs Careysburg: phon: 25, fuzzy: 12
# Zoe-Geh vs Cavala: phon: 25, fuzzy: 0
# Zoe-Geh vs Central Rivercess: phon: 0, fuzzy: 17
# Zoe-Geh vs Chedepo: phon: 25, fuzzy: 29
# Zoe-Geh vs Commonwealth: phon: 0, fuzzy: 32
# Zoe-Geh vs Commonwealth 1: phon: 0, fuzzy: 29
# Zoe-Geh vs Commonwealth 2: phon: 0, fuzzy: 29
# Zoe-Geh vs District #1: phon: 25, fuzzy: 0
# Zoe-Geh vs District #2: phon: 25, fuzzy: 0
# Zoe-Geh vs District #3: phon: 25, fuzzy: 0
# Zoe-Geh vs District #4: phon: 25, fuzzy: 0
# Zoe-Geh vs Doe: phon: 50, fuzzy: 40
# Zoe-Geh vs Doedain: phon: 25, fuzzy: 29
# Zoe-Geh vs Dorbor: phon: 0, fuzzy: 15
# Zoe-Geh vs Dowein: phon: 50, fuzzy: 31
# Zoe-Geh vs Dugbe River: phon: 25, fuzzy: 22
# Zoe-Geh vs Dweh: phon: 50, fuzzy: 36
# Zoe-Geh vs Felo-Jekwi: phon: 25, fuzzy: 35
# Zoe-Geh vs Fen River: phon: 0, fuzzy: 25
# Zoe-Geh vs Fenetoe: phon: 25, fuzzy: 29
# Zoe-Geh vs Firestone: phon: 25, fuzzy: 25
# Zoe-Geh vs Forpoh: phon: 25, fuzzy: 31
# Zoe-Geh vs Foya: phon: 50, fuzzy: 18
# Zoe-Geh vs Fuamah: phon: 50, fuzzy: 15
# Zoe-Geh vs Garr-Bain: phon: 0, fuzzy: 12
# Zoe-Geh vs Garraway: phon: 50, fuzzy: 13
# Zoe-Geh vs Garwula: phon: 25, fuzzy: 14
# Zoe-Geh vs Gbao: phon: 50, fuzzy: 18
# Zoe-Geh vs Gbarma: phon: 0, fuzzy: 15
# Zoe-Geh vs Gbeapo: phon: 25, fuzzy: 31
# Zoe-Geh vs Gbehlay-Geh: phon: 25, fuzzy: 56
# Zoe-Geh vs Gbi & Doru: phon: 0, fuzzy: 12
# Zoe-Geh vs Gboe-Ploe: phon: 0, fuzzy: 50
# Zoe-Geh vs Gbor: phon: 25, fuzzy: 18
# Zoe-Geh vs Gee: phon: 50, fuzzy: 40
# Zoe-Geh vs Gibi: phon: 50, fuzzy: 18
# Zoe-Geh vs Glaro: phon: 25, fuzzy: 17
# Zoe-Geh vs Glio-Twarbo: phon: 0, fuzzy: 22
# Zoe-Geh vs Golakonneh: phon: 25, fuzzy: 35
# Zoe-Geh vs Gounwolaila: phon: 0, fuzzy: 11
# Zoe-Geh vs Grand Cess Wedabo: phon: 0, fuzzy: 17
# Zoe-Geh vs Greater Monrovia: phon: 0, fuzzy: 17
# Zoe-Geh vs Greenville: phon: 0, fuzzy: 24
# Zoe-Geh vs Gwelekpoken: phon: 25, fuzzy: 22
# Zoe-Geh vs Harper: phon: 0, fuzzy: 15
# Zoe-Geh vs Jaedae: phon: 50, fuzzy: 31
# Zoe-Geh vs Jeadepo: phon: 25, fuzzy: 29
# Zoe-Geh vs Jo River: phon: 0, fuzzy: 27
# Zoe-Geh vs Jorquelleh: phon: 25, fuzzy: 47
# Zoe-Geh vs Juarzon: phon: 25, fuzzy: 14
# Zoe-Geh vs Kakata: phon: 50, fuzzy: 0
# Zoe-Geh vs Karforh: phon: 0, fuzzy: 29
# Zoe-Geh vs Karluway #1: phon: 25, fuzzy: 0
# Zoe-Geh vs Karluway #2: phon: 25, fuzzy: 0
# Zoe-Geh vs Klay: phon: 50, fuzzy: 0
# Zoe-Geh vs Kokoyah: phon: 75, fuzzy: 29
# Zoe-Geh vs Kolahun: phon: 25, fuzzy: 29
# Zoe-Geh vs Kongba: phon: 25, fuzzy: 15
# Zoe-Geh vs Konobo: phon: 25, fuzzy: 15
# Zoe-Geh vs Kpaai: phon: 50, fuzzy: 0
# Zoe-Geh vs Kparblee: phon: 0, fuzzy: 27
# Zoe-Geh vs Kpayan: phon: 25, fuzzy: 0
# Zoe-Geh vs Kpi: phon: 50, fuzzy: 0
# Zoe-Geh vs Kulu Shaw Boe: phon: 25, fuzzy: 20
# Zoe-Geh vs Leewehpea-Mahn: phon: 0, fuzzy: 29
# Zoe-Geh vs Lower Jloh: phon: 25, fuzzy: 35
# Zoe-Geh vs Mambah Kaba: phon: 25, fuzzy: 11
# Zoe-Geh vs Meinpea-Mahn: phon: 0, fuzzy: 32
# Zoe-Geh vs Nanee: phon: 50, fuzzy: 33
# Zoe-Geh vs Neekreen: phon: 25, fuzzy: 27
# Zoe-Geh vs Norwein: phon: 25, fuzzy: 29
# Zoe-Geh vs Nrokwia-Wesldow: phon: 25, fuzzy: 27
# Zoe-Geh vs Nyenawliken: phon: 25, fuzzy: 22
# Zoe-Geh vs Nyenebo: phon: 25, fuzzy: 29
# Zoe-Geh vs Nyorken: phon: 25, fuzzy: 29
# Zoe-Geh vs Owensgrove: phon: 25, fuzzy: 24
# Zoe-Geh vs Panta: phon: 25, fuzzy: 0
# Zoe-Geh vs Plahn Nyarn: phon: 0, fuzzy: 11
# Zoe-Geh vs Pleebo/Sodoken: phon: 25, fuzzy: 19
# Zoe-Geh vs Porkpa: phon: 25, fuzzy: 15
# Zoe-Geh vs Potupo: phon: 25, fuzzy: 15
# Zoe-Geh vs Putu: phon: 50, fuzzy: 0
# Zoe-Geh vs Pynes Town: phon: 25, fuzzy: 12
# Zoe-Geh vs Quardu Boundi: phon: 0, fuzzy: 10
# Zoe-Geh vs Salala: phon: 25, fuzzy: 0
# Zoe-Geh vs Salayea: phon: 50, fuzzy: 14
# Zoe-Geh vs Sam Gbalor: phon: 25, fuzzy: 12
# Zoe-Geh vs Sanniquellie Mahn: phon: 25, fuzzy: 25
# Zoe-Geh vs Sanoyeah: phon: 50, fuzzy: 40
# Zoe-Geh vs Sanquin Dist #1: phon: 25, fuzzy: 0
# Zoe-Geh vs Sanquin Dist #2: phon: 25, fuzzy: 0
# Zoe-Geh vs Sanquin Dist #3: phon: 25, fuzzy: 0
# Zoe-Geh vs Sarbo: phon: 25, fuzzy: 17
# Zoe-Geh vs Seekon: phon: 50, fuzzy: 31
# Zoe-Geh vs Senjeh: phon: 50, fuzzy: 46
# Zoe-Geh vs St. John River City: phon: 25, fuzzy: 15
# Zoe-Geh vs St. Paul River: phon: 0, fuzzy: 10
# Zoe-Geh vs Suakoko: phon: 50, fuzzy: 14
# Zoe-Geh vs Suehn Mecca: phon: 25, fuzzy: 22
# Zoe-Geh vs Tchien: phon: 50, fuzzy: 15
# Zoe-Geh vs Tewor: phon: 50, fuzzy: 17
# Zoe-Geh vs Todee: phon: 50, fuzzy: 50
# Zoe-Geh vs Trenbo: phon: 0, fuzzy: 15
# Zoe-Geh vs Tukpahblee: phon: 25, fuzzy: 24
# Zoe-Geh vs Tuobo: phon: 50, fuzzy: 17
# Zoe-Geh vs Twan River: phon: 0, fuzzy: 12
# Zoe-Geh vs Upper Jloh: phon: 25, fuzzy: 24
# Zoe-Geh vs Vahun: phon: 50, fuzzy: 17
# Zoe-Geh vs Voinjama: phon: 25, fuzzy: 13
# Zoe-Geh vs Wedjah: phon: 50, fuzzy: 31
# Zoe-Geh vs Wee-Gbehyi-Mahn: phon: 25, fuzzy: 45
# Zoe-Geh vs Whojah: phon: 75, fuzzy: 31
# Zoe-Geh vs Wlogba: phon: 25, fuzzy: 15
# Zoe-Geh vs Yarmein: phon: 0, fuzzy: 14
# Zoe-Geh vs Yarpea Mahn: phon: 0, fuzzy: 22
# Zoe-Geh vs Yarwein Mehnsonnoh: phon: 0, fuzzy: 24
# Zoe-Geh vs Yeallequelleh: phon: 25, fuzzy: 30
# Zoe-Geh vs Zarflahn: phon: 25, fuzzy: 27
# Zoe-Geh vs Zoe-Gbao: phon: 75, fuzzy: 67
# Zoe-Geh vs Zorzor: phon: 50, fuzzy: 31
# Zoe-Geh vs Zota: phon: 75, fuzzy: 36
# Zoe-Geh: ('Kokoyah', 75)
# Zorzor vs B'hai: phon: 0, fuzzy: 0
# Zorzor vs Barclayville: phon: 50, fuzzy: 11
# Zorzor vs Beawor: phon: 25, fuzzy: 33
# Zorzor vs Belleh: phon: 0, fuzzy: 0
# Zorzor vs Bleebo: phon: 0, fuzzy: 17
# Zorzor vs Bodae: phon: 0, fuzzy: 18
# Zorzor vs Boe & Quilla: phon: 25, fuzzy: 11
# Zorzor vs Boinsen: phon: 25, fuzzy: 15
# Zorzor vs Bokomu: phon: 25, fuzzy: 33
# Zorzor vs Bokon: phon: 25, fuzzy: 36
# Zorzor vs Bolloh: phon: 0, fuzzy: 33
# Zorzor vs Bopolu: phon: 0, fuzzy: 33
# Zorzor vs Buah: phon: 0, fuzzy: 0
# Zorzor vs Butaw: phon: 0, fuzzy: 0
# Zorzor vs Buu-Yao: phon: 0, fuzzy: 15
# Zorzor vs Careysburg: phon: 50, fuzzy: 25
# Zorzor vs Cavala: phon: 0, fuzzy: 0
# Zorzor vs Central Rivercess: phon: 25, fuzzy: 17
# Zorzor vs Chedepo: phon: 0, fuzzy: 15
# Zorzor vs Commonwealth: phon: 0, fuzzy: 22
# Zorzor vs Commonwealth 1: phon: 0, fuzzy: 20
# Zorzor vs Commonwealth 2: phon: 0, fuzzy: 20
# Zorzor vs District #1: phon: 50, fuzzy: 12
# Zorzor vs District #2: phon: 50, fuzzy: 12
# Zorzor vs District #3: phon: 50, fuzzy: 12
# Zorzor vs District #4: phon: 50, fuzzy: 12
# Zorzor vs Doe: phon: 0, fuzzy: 22
# Zorzor vs Doedain: phon: 0, fuzzy: 15
# Zorzor vs Dorbor: phon: 50, fuzzy: 67
# Zorzor vs Dowein: phon: 0, fuzzy: 17
# Zorzor vs Dugbe River: phon: 50, fuzzy: 12
# Zorzor vs Dweh: phon: 0, fuzzy: 0
# Zorzor vs Felo-Jekwi: phon: 25, fuzzy: 12
# Zorzor vs Fen River: phon: 25, fuzzy: 13
# Zorzor vs Fenetoe: phon: 0, fuzzy: 15
# Zorzor vs Firestone: phon: 50, fuzzy: 27
# Zorzor vs Forpoh: phon: 25, fuzzy: 50
# Zorzor vs Foya: phon: 0, fuzzy: 20
# Zorzor vs Fuamah: phon: 0, fuzzy: 0
# Zorzor vs Garr-Bain: phon: 25, fuzzy: 27
# Zorzor vs Garraway: phon: 25, fuzzy: 29
# Zorzor vs Garwula: phon: 25, fuzzy: 15
# Zorzor vs Gbao: phon: 0, fuzzy: 20
# Zorzor vs Gbarma: phon: 25, fuzzy: 17
# Zorzor vs Gbeapo: phon: 0, fuzzy: 17
# Zorzor vs Gbehlay-Geh: phon: 25, fuzzy: 0
# Zorzor vs Gbi & Doru: phon: 25, fuzzy: 25
# Zorzor vs Gboe-Ploe: phon: 0, fuzzy: 27
# Zorzor vs Gbor: phon: 25, fuzzy: 40
# Zorzor vs Gee: phon: 0, fuzzy: 0
# Zorzor vs Gibi: phon: 0, fuzzy: 0
# Zorzor vs Glaro: phon: 25, fuzzy: 36
# Zorzor vs Glio-Twarbo: phon: 25, fuzzy: 35
# Zorzor vs Golakonneh: phon: 25, fuzzy: 25
# Zorzor vs Gounwolaila: phon: 0, fuzzy: 24
# Zorzor vs Grand Cess Wedabo: phon: 25, fuzzy: 17
# Zorzor vs Greater Monrovia: phon: 50, fuzzy: 27
# Zorzor vs Greenville: phon: 25, fuzzy: 12
# Zorzor vs Gwelekpoken: phon: 25, fuzzy: 12
# Zorzor vs Harper: phon: 50, fuzzy: 33
# Zorzor vs Jaedae: phon: 0, fuzzy: 0
# Zorzor vs Jeadepo: phon: 0, fuzzy: 15
# Zorzor vs Jo River: phon: 50, fuzzy: 29
# Zorzor vs Jorquelleh: phon: 50, fuzzy: 25
# Zorzor vs Juarzon: phon: 50, fuzzy: 46
# Zorzor vs Kakata: phon: 25, fuzzy: 0
# Zorzor vs Karforh: phon: 50, fuzzy: 46
# Zorzor vs Karluway #1: phon: 25, fuzzy: 12
# Zorzor vs Karluway #2: phon: 25, fuzzy: 12
# Zorzor vs Klay: phon: 0, fuzzy: 0
# Zorzor vs Kokoyah: phon: 25, fuzzy: 31
# Zorzor vs Kolahun: phon: 0, fuzzy: 15
# Zorzor vs Kongba: phon: 25, fuzzy: 17
# Zorzor vs Konobo: phon: 0, fuzzy: 33
# Zorzor vs Kpaai: phon: 0, fuzzy: 0
# Zorzor vs Kparblee: phon: 25, fuzzy: 14
# Zorzor vs Kpayan: phon: 0, fuzzy: 0
# Zorzor vs Kpi: phon: 0, fuzzy: 0
# Zorzor vs Kulu Shaw Boe: phon: 25, fuzzy: 11
# Zorzor vs Leewehpea-Mahn: phon: 0, fuzzy: 0
# Zorzor vs Lower Jloh: phon: 50, fuzzy: 38
# Zorzor vs Mambah Kaba: phon: 25, fuzzy: 0
# Zorzor vs Meinpea-Mahn: phon: 0, fuzzy: 0
# Zorzor vs Nanee: phon: 0, fuzzy: 0
# Zorzor vs Neekreen: phon: 50, fuzzy: 14
# Zorzor vs Norwein: phon: 25, fuzzy: 31
# Zorzor vs Nrokwia-Wesldow: phon: 50, fuzzy: 19
# Zorzor vs Nyenawliken: phon: 25, fuzzy: 0
# Zorzor vs Nyenebo: phon: 0, fuzzy: 15
# Zorzor vs Nyorken: phon: 50, fuzzy: 31
# Zorzor vs Owensgrove: phon: 50, fuzzy: 25
# Zorzor vs Panta: phon: 0, fuzzy: 0
# Zorzor vs Plahn Nyarn: phon: 0, fuzzy: 12
# Zorzor vs Pleebo/Sodoken: phon: 25, fuzzy: 20
# Zorzor vs Porkpa: phon: 50, fuzzy: 33
# Zorzor vs Potupo: phon: 0, fuzzy: 33
# Zorzor vs Putu: phon: 0, fuzzy: 0
# Zorzor vs Pynes Town: phon: 25, fuzzy: 12
# Zorzor vs Quardu Boundi: phon: 25, fuzzy: 21
# Zorzor vs Salala: phon: 0, fuzzy: 0
# Zorzor vs Salayea: phon: 0, fuzzy: 0
# Zorzor vs Sam Gbalor: phon: 25, fuzzy: 25
# Zorzor vs Sanniquellie Mahn: phon: 25, fuzzy: 0
# Zorzor vs Sanoyeah: phon: 0, fuzzy: 14
# Zorzor vs Sanquin Dist #1: phon: 25, fuzzy: 0
# Zorzor vs Sanquin Dist #2: phon: 25, fuzzy: 0
# Zorzor vs Sanquin Dist #3: phon: 25, fuzzy: 0
# Zorzor vs Sarbo: phon: 25, fuzzy: 36
# Zorzor vs Seekon: phon: 25, fuzzy: 17
# Zorzor vs Senjeh: phon: 25, fuzzy: 0
# Zorzor vs St. John River City: phon: 25, fuzzy: 16
# Zorzor vs St. Paul River: phon: 0, fuzzy: 10
# Zorzor vs Suakoko: phon: 25, fuzzy: 31
# Zorzor vs Suehn Mecca: phon: 25, fuzzy: 0
# Zorzor vs Tchien: phon: 25, fuzzy: 0
# Zorzor vs Tewor: phon: 25, fuzzy: 36
# Zorzor vs Todee: phon: 0, fuzzy: 18
# Zorzor vs Trenbo: phon: 25, fuzzy: 33
# Zorzor vs Tukpahblee: phon: 25, fuzzy: 0
# Zorzor vs Tuobo: phon: 0, fuzzy: 36
# Zorzor vs Twan River: phon: 25, fuzzy: 12
# Zorzor vs Upper Jloh: phon: 50, fuzzy: 25
# Zorzor vs Vahun: phon: 0, fuzzy: 0
# Zorzor vs Voinjama: phon: 25, fuzzy: 14
# Zorzor vs Wedjah: phon: 25, fuzzy: 0
# Zorzor vs Wee-Gbehyi-Mahn: phon: 25, fuzzy: 0
# Zorzor vs Whojah: phon: 25, fuzzy: 17
# Zorzor vs Wlogba: phon: 25, fuzzy: 17
# Zorzor vs Yarmein: phon: 25, fuzzy: 15
# Zorzor vs Yarpea Mahn: phon: 25, fuzzy: 12
# Zorzor vs Yarwein Mehnsonnoh: phon: 25, fuzzy: 17
# Zorzor vs Yeallequelleh: phon: 25, fuzzy: 0
# Zorzor vs Zarflahn: phon: 50, fuzzy: 29
# Zorzor vs Zoe-Gbao: phon: 50, fuzzy: 43
# Zorzor vs Zorzor: phon: 100, fuzzy: 100
# Zorzor vs Zota: phon: 25, fuzzy: 40
# Zorzor: ('Zorzor', 100)
# Zota vs B'hai: phon: 50, fuzzy: 22
# Zota vs Barclayville: phon: 0, fuzzy: 12
# Zota vs Beawor: phon: 50, fuzzy: 20
# Zota vs Belleh: phon: 50, fuzzy: 0
# Zota vs Bleebo: phon: 25, fuzzy: 20
# Zota vs Bodae: phon: 75, fuzzy: 44
# Zota vs Boe & Quilla: phon: 25, fuzzy: 25
# Zota vs Boinsen: phon: 0, fuzzy: 18
# Zota vs Bokomu: phon: 25, fuzzy: 20
# Zota vs Bokon: phon: 25, fuzzy: 22
# Zota vs Bolloh: phon: 50, fuzzy: 20
# Zota vs Bopolu: phon: 25, fuzzy: 20
# Zota vs Buah: phon: 50, fuzzy: 25
# Zota vs Butaw: phon: 75, fuzzy: 44
# Zota vs Buu-Yao: phon: 50, fuzzy: 18
# Zota vs Careysburg: phon: 0, fuzzy: 14
# Zota vs Cavala: phon: 25, fuzzy: 20
# Zota vs Central Rivercess: phon: 25, fuzzy: 19
# Zota vs Chedepo: phon: 50, fuzzy: 18
# Zota vs Commonwealth: phon: 0, fuzzy: 25
# Zota vs Commonwealth 1: phon: 0, fuzzy: 22
# Zota vs Commonwealth 2: phon: 0, fuzzy: 22
# Zota vs District #1: phon: 25, fuzzy: 13
# Zota vs District #2: phon: 25, fuzzy: 13
# Zota vs District #3: phon: 25, fuzzy: 13
# Zota vs District #4: phon: 25, fuzzy: 13
# Zota vs Doe: phon: 50, fuzzy: 29
# Zota vs Doedain: phon: 50, fuzzy: 36
# Zota vs Dorbor: phon: 0, fuzzy: 20
# Zota vs Dowein: phon: 50, fuzzy: 20
# Zota vs Dugbe River: phon: 0, fuzzy: 0
# Zota vs Dweh: phon: 50, fuzzy: 0
# Zota vs Felo-Jekwi: phon: 0, fuzzy: 14
# Zota vs Fen River: phon: 0, fuzzy: 0
# Zota vs Fenetoe: phon: 50, fuzzy: 18
# Zota vs Firestone: phon: 25, fuzzy: 15
# Zota vs Forpoh: phon: 25, fuzzy: 20
# Zota vs Foya: phon: 50, fuzzy: 50
# Zota vs Fuamah: phon: 50, fuzzy: 20
# Zota vs Garr-Bain: phon: 0, fuzzy: 15
# Zota vs Garraway: phon: 50, fuzzy: 17
# Zota vs Garwula: phon: 25, fuzzy: 18
# Zota vs Gbao: phon: 50, fuzzy: 25
# Zota vs Gbarma: phon: 0, fuzzy: 20
# Zota vs Gbeapo: phon: 25, fuzzy: 20
# Zota vs Gbehlay-Geh: phon: 0, fuzzy: 13
# Zota vs Gbi & Doru: phon: 25, fuzzy: 14
# Zota vs Gboe-Ploe: phon: 0, fuzzy: 15
# Zota vs Gbor: phon: 25, fuzzy: 25
# Zota vs Gee: phon: 50, fuzzy: 0
# Zota vs Gibi: phon: 50, fuzzy: 0
# Zota vs Glaro: phon: 25, fuzzy: 22
# Zota vs Glio-Twarbo: phon: 25, fuzzy: 27
# Zota vs Golakonneh: phon: 0, fuzzy: 29
# Zota vs Gounwolaila: phon: 0, fuzzy: 27
# Zota vs Grand Cess Wedabo: phon: 25, fuzzy: 10
# Zota vs Greater Monrovia: phon: 25, fuzzy: 20
# Zota vs Greenville: phon: 0, fuzzy: 0
# Zota vs Gwelekpoken: phon: 0, fuzzy: 13
# Zota vs Harper: phon: 0, fuzzy: 20
# Zota vs Jaedae: phon: 75, fuzzy: 20
# Zota vs Jeadepo: phon: 50, fuzzy: 18
# Zota vs Jo River: phon: 0, fuzzy: 17
# Zota vs Jorquelleh: phon: 0, fuzzy: 14
# Zota vs Juarzon: phon: 0, fuzzy: 18
# Zota vs Kakata: phon: 50, fuzzy: 40
# Zota vs Karforh: phon: 0, fuzzy: 18
# Zota vs Karluway #1: phon: 25, fuzzy: 13
# Zota vs Karluway #2: phon: 25, fuzzy: 13
# Zota vs Klay: phon: 50, fuzzy: 25
# Zota vs Kokoyah: phon: 50, fuzzy: 36
# Zota vs Kolahun: phon: 25, fuzzy: 36
# Zota vs Kongba: phon: 0, fuzzy: 40
# Zota vs Konobo: phon: 25, fuzzy: 20
# Zota vs Kpaai: phon: 50, fuzzy: 22
# Zota vs Kparblee: phon: 0, fuzzy: 17
# Zota vs Kpayan: phon: 25, fuzzy: 20
# Zota vs Kpi: phon: 50, fuzzy: 0
# Zota vs Kulu Shaw Boe: phon: 0, fuzzy: 12
# Zota vs Leewehpea-Mahn: phon: 0, fuzzy: 11
# Zota vs Lower Jloh: phon: 0, fuzzy: 14
# Zota vs Mambah Kaba: phon: 0, fuzzy: 13
# Zota vs Meinpea-Mahn: phon: 0, fuzzy: 12
# Zota vs Nanee: phon: 50, fuzzy: 22
# Zota vs Neekreen: phon: 0, fuzzy: 0
# Zota vs Norwein: phon: 25, fuzzy: 18
# Zota vs Nrokwia-Wesldow: phon: 0, fuzzy: 21
# Zota vs Nyenawliken: phon: 0, fuzzy: 13
# Zota vs Nyenebo: phon: 25, fuzzy: 18
# Zota vs Nyorken: phon: 0, fuzzy: 18
# Zota vs Owensgrove: phon: 0, fuzzy: 14
# Zota vs Panta: phon: 50, fuzzy: 44
# Zota vs Plahn Nyarn: phon: 0, fuzzy: 13
# Zota vs Pleebo/Sodoken: phon: 0, fuzzy: 11
# Zota vs Porkpa: phon: 0, fuzzy: 40
# Zota vs Potupo: phon: 50, fuzzy: 40
# Zota vs Putu: phon: 75, fuzzy: 25
# Zota vs Pynes Town: phon: 25, fuzzy: 14
# Zota vs Quardu Boundi: phon: 25, fuzzy: 12
# Zota vs Salala: phon: 25, fuzzy: 20
# Zota vs Salayea: phon: 50, fuzzy: 18
# Zota vs Sam Gbalor: phon: 0, fuzzy: 14
# Zota vs Sanniquellie Mahn: phon: 0, fuzzy: 10
# Zota vs Sanoyeah: phon: 50, fuzzy: 33
# Zota vs Sanquin Dist #1: phon: 0, fuzzy: 11
# Zota vs Sanquin Dist #2: phon: 0, fuzzy: 11
# Zota vs Sanquin Dist #3: phon: 0, fuzzy: 11
# Zota vs Sarbo: phon: 25, fuzzy: 22
# Zota vs Seekon: phon: 25, fuzzy: 20
# Zota vs Senjeh: phon: 25, fuzzy: 0
# Zota vs St. John River City: phon: 25, fuzzy: 17
# Zota vs St. Paul River: phon: 25, fuzzy: 22
# Zota vs Suakoko: phon: 25, fuzzy: 18
# Zota vs Suehn Mecca: phon: 0, fuzzy: 13
# Zota vs Tchien: phon: 25, fuzzy: 0
# Zota vs Tewor: phon: 50, fuzzy: 22
# Zota vs Todee: phon: 75, fuzzy: 22
# Zota vs Trenbo: phon: 0, fuzzy: 20
# Zota vs Tukpahblee: phon: 0, fuzzy: 14
# Zota vs Tuobo: phon: 50, fuzzy: 22
# Zota vs Twan River: phon: 0, fuzzy: 14
# Zota vs Upper Jloh: phon: 0, fuzzy: 14
# Zota vs Vahun: phon: 50, fuzzy: 22
# Zota vs Voinjama: phon: 0, fuzzy: 33
# Zota vs Wedjah: phon: 50, fuzzy: 20
# Zota vs Wee-Gbehyi-Mahn: phon: 0, fuzzy: 11
# Zota vs Whojah: phon: 50, fuzzy: 40
# Zota vs Wlogba: phon: 0, fuzzy: 40
# Zota vs Yarmein: phon: 0, fuzzy: 18
# Zota vs Yarpea Mahn: phon: 0, fuzzy: 13
# Zota vs Yarwein Mehnsonnoh: phon: 0, fuzzy: 9
# Zota vs Yeallequelleh: phon: 0, fuzzy: 12
# Zota vs Zarflahn: phon: 25, fuzzy: 33
# Zota vs Zoe-Gbao: phon: 50, fuzzy: 50
# Zota vs Zorzor: phon: 25, fuzzy: 40
# Zota vs Zota: phon: 100, fuzzy: 100
# Zota: ('Zota', 100)

# %%
matches_pct = (len(table_adm2_matches) / len(level3_list))
'{:.2f}%'.format(matches_pct*100)
# old val was 77.42%
# Out:
# '80.65%'

# %% [markdown]
# ### Match orgunitlevel2 to Geob Adm 1

# %%
master_table.loc[:, "orgunitlevel2_edit"] = master_table.orgunitlevel2

# %%
remove_words(master_table, "orgunitlevel2_edit", [" District"])
remove_words(geob1, "shapeName", [" City Council", " District Council", " Municipal Council", "Region"])

# %%
master_table.loc[master_table.orgunitlevel2_edit == "Chattogram", "orgunitlevel2_edit"] = "Chittagong"

# %%
level2_list = list(master_table.orgunitlevel2_edit.unique())
level2_list.sort()
geob1_list = list(geob1.shapeName)
geob1_list.sort()

# %%
for letter in ascii_uppercase:
    level2_sublist = [name for name in level2_list if name[0]==letter]
    geob1_sublist = [name for name in geob1_list if name[0]==letter]
    if len(level2_sublist)>0:
        print("Master list level 2")
        print("\t"+str(level2_sublist))
    if len(geob1_sublist) > 0:
        print("Geoboundaries adm1")
        print("\t"+str(geob1_sublist))
    print("\n")
# Out:
# Master list level 2
# 	['Bomi', 'Bong']
# Geoboundaries adm1
# 	['Bomi', 'Bong']
#
#
#
#
#
#
#
#
#
#
# Master list level 2
# 	['Gbarpolu', 'Grand Bassa', 'Grand Cape Mount', 'Grand Gedeh', 'Grand Kru']
# Geoboundaries adm1
# 	['Gbarpolu', 'Grand Bassa', 'Grand Cape Mount', 'Grand Gedeh', 'Grand Kru']
#
#
#
#
#
#
#
#
#
#
# Master list level 2
# 	['Lofa']
# Geoboundaries adm1
# 	['Lofa']
#
#
# Master list level 2
# 	['Margibi', 'Maryland', 'Montserrado']
# Geoboundaries adm1
# 	['Margibi', 'Maryland', 'Montserrado']
#
#
# Master list level 2
# 	['Nimba']
# Geoboundaries adm1
# 	['Nimba']
#
#
#
#
#
#
#
#
# Master list level 2
# 	['River Gee', 'Rivercess']
# Geoboundaries adm1
# 	['River Gee', 'Rivercess']
#
#
# Master list level 2
# 	['Sinoe']
# Geoboundaries adm1
# 	['Sinoe']

# %%
# List for dicts for easy dataframe creation
dict_list = []

for name in level2_list:
    
    # Use our method to find best match, we can set a threshold here
    match = match_name(name, geob1_list, 30)

    # New dict for storing data
    dict_ = {}
    dict_.update({"name_level2" : name})
    dict_.update({"name_geob1" : match[0]})
    dict_.update({"score" : match[1]})
    dict_list.append(dict_)

table_adm1 = pd.DataFrame(dict_list)
table_adm1_matches = table_adm1[table_adm1.score >= 80]

# %%
matches_pct = (len(table_adm1_matches) / len(level2_list))
'{:.2f}%'.format(matches_pct*100)
# Out:
# '100.00%'

# %% [markdown]
# Loop through each row in master table, and add new attribute names (adm3 and adm2), if the names produced matches in the lookup tables

# %%
master_table_copy = master_table.copy()

# %%
for idx, row in master_table_copy.iterrows():
    
    # if row.orgunitlevel4_edit in list(table_adm3_matches.name_level4):
    #
    #     match = table_adm3_matches.loc[table_adm3_matches.name_level4==row.orgunitlevel4_edit, "name_geob3"].iloc[0]
    #     master_table_copy.loc[idx, 'adm3'] = match
        
    if row.orgunitlevel3_edit in list(table_adm2_matches.name_level3):
        
        match = table_adm2_matches.loc[table_adm2_matches.name_level3==row.orgunitlevel3_edit, "name_geob2"].iloc[0]
        master_table_copy.loc[idx, 'adm2'] = match
        
    if row.orgunitlevel2_edit in list(table_adm1_matches.name_level2):
        
        match = table_adm1_matches.loc[table_adm1_matches.name_level2==row.orgunitlevel2_edit, "name_geob1"].iloc[0]
        master_table_copy.loc[idx, 'adm1'] = match

# %%
master_table_copy.adm2.isna().sum()
# Out:
# 293

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[62], line 1
# ----> 1 master_table_copy.adm3.isna().sum()
#
# File ~/opt/anaconda3/envs/health/lib/python3.11/site-packages/pandas/core/generic.py:5902, in NDFrame.__getattr__(self, name)
#    5895 if (
#    5896     name not in self._internal_names_set
#    5897     and name not in self._metadata
#    5898     and name not in self._accessors
#    5899     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5900 ):
#    5901     return self[name]
# -> 5902 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'adm3'

# %%
master_table_copy.adm1.isna().sum()
# Out:
# 0

# %%
master_table_copy.head(2)
# Out:
#    index orgunitlevel1 orgunitlevel2         orgunitlevel3  \
# 0      0       Liberia         Sinoe     Tarjuwon District
# 1      4       Liberia       Margibi  Mambah-Kaba District
#
#           orgunitlevel4 organisationunitid  organisationunitname  \
# 0    Gbason Town Clinic        DAmhVvbzEl6    Gbason Town Clinic
# 1  14 Military Hospital        oUPdjvJABX7  14 Military Hospital
#
#   organisationunitcode organisationunitdescription orgunitlevel3_edit  \
# 0               LR5GZ3                         NaN           Tarjuwon
# 1               LR0GW8                         NaN        Mambah-Kaba
#
#   orgunitlevel2_edit     adm1         adm2
# 0              Sinoe    Sinoe          NaN
# 1            Margibi  Margibi  Mambah Kaba

# %% [markdown]
# # Match to locations from alternative sources based on facility name
#
#
# ## Health Sites IO
# Import Health Sites from HealthSites.io
# Health sites come in both a node and a way shapefile. You need to import both to get all the sites.
# In QGIS, I created centroids from the ways then merged it with the points.

# %%
nodes_io = gpd.read_file(os.path.join(input_dir, "healthsitesio", "BGD", "merged_BGD_healthsites.shp"))

# %%
nodes_io = nodes_io.loc[~nodes_io.name.isna()].copy()

# %%
nodes_io['name'] = nodes_io['name'].str.lower()

# %%
words_to_remove = ['community', 'clinic', 'centre', 'center', 'hospital', 'health', 'government']

# %%
nodes_io.loc[:, "is_point"] = nodes_io.apply(lambda x: type(x.geometry)==Point, axis=1)

# %%
len(nodes_io.loc[~nodes_io.is_point])
# Out:
# 0

# %%
len(nodes_io.loc[nodes_io.geometry.is_valid])==len(nodes_io)
# Out:
# True

# %%
records = master_table_copy.copy()
records['NAME'] = records['orgunitlevel6'].str.lower()

# %%
remove_words(nodes_io, 'name', words_to_remove)
remove_words(records, 'NAME', words_to_remove)

# %%
records['geocoding_method'] = "None"

# %%
for idx, row in tqdm(records.iterrows()):
    
    # Check if there is another entry with location
    match, score = match_name(row.NAME, list(nodes_io['name']), 80)
#     match, score = match_name(row.name_concat, list(nodes_io.name_concat), 85)
    
    if score > 0:
        print(row.NAME, match)
        matching_row = nodes_io.loc[nodes_io['name']==match].copy()
        res = matching_row.iloc[0]
        
        if not pd.isna(row.adm3):
            adm3 = geob3.loc[geob3['shapeName'] == row['adm3']].copy()
            if adm3.contains(res.geometry).values[0] == True:
                records.loc[idx, "longitude"] = res.geometry.x
                records.loc[idx, "latitude"] = res.geometry.y
                records.loc[idx, "geocoding_method"] = "Location from Health Sites IO and within admin 3"
                
        if not pd.isna(row.adm2):
            adm2 = geob2.loc[geob2['shapeName'] == row['adm2']].copy()
            if adm2.contains(res.geometry).values[0] == True:            
                records.loc[idx, "longitude"] = res.geometry.x
                records.loc[idx, "latitude"] = res.geometry.y
                records.loc[idx, "geocoding_method"] = "Location from Health Sites IO and within admin 2"
                
        if not pd.isna(row.adm1):
            adm1 = geob1.loc[geob1['shapeName'] == row['adm1']].copy()
            if adm1.contains(res.geometry).values[0] == True:            
                records.loc[idx, "longitude"] = res.geometry.x
                records.loc[idx, "latitude"] = res.geometry.y
                records.loc[idx, "geocoding_method"] = "Location from Health Sites IO and within admin 1"
# Out:
# 21it [00:00, 63.34it/s]
# bathi para bothipara
# 70it [00:01, 67.22it/s]
# kumrakhali khuriakhali
# 91it [00:01, 65.77it/s]
# taltali taltoli
# 119it [00:01, 63.38it/s]
# kalipur khalishpur
# kathaltoli taltoli
# taluker charduani taluker char duyani
# 147it [00:02, 65.31it/s]
# kandirpara kandapara
# 259it [00:03, 64.75it/s]
# puranpara puratan  para
# 315it [00:04, 65.61it/s]
# shripur sharifpur
# 343it [00:05, 66.25it/s]
# kashimpur kashipur
# 427it [00:06, 66.22it/s]
# baghmara bagmara
# dhani dhania
# 511it [00:07, 62.88it/s]
# dalal bazar kalia bazar
# 602it [00:09, 64.01it/s]
# chandpur achanpur
# 679it [00:10, 66.84it/s]
# amirbuniya amorbunia
# 700it [00:10, 65.33it/s]
# tetulbaria tetul bariya
# 749it [00:11, 64.75it/s]
# rajapur razapur
# 777it [00:11, 65.76it/s]
# chandpur achanpur
# 805it [00:12, 65.33it/s]
# gabbunia gabbunia
# 819it [00:12, 66.29it/s]
# pankhali pankhali
# 840it [00:12, 66.72it/s]
# gandadula gondadula
# 924it [00:14, 67.14it/s]
# jamura jamuna
# 1009it [00:15, 68.61it/s]
# north nali north bengal
# 1066it [00:16, 68.25it/s]
# ramchandrapur ramchandrapur
# 1080it [00:16, 66.53it/s]
# bainkhali pankhali
# kundapara kandapara
# 1123it [00:16, 68.34it/s]
# alinagar ali asgar
# 1165it [00:17, 64.00it/s]
# antapara kandapara
# 1186it [00:17, 63.89it/s]
# rajapur razapur
# haripur sharifpur
# 1256it [00:18, 64.21it/s]
# ramcandrapur ramchandrapur
# satgao atgao
# 1298it [00:19, 64.70it/s]
# kancanpur achanpur
# kancanpur achanpur
# 1319it [00:19, 64.17it/s]
# dhansara dhansagor
# 1347it [00:20, 64.43it/s]
# kamalapur kamolpur
# jamuna jamuna
# 1382it [00:20, 63.33it/s]
# bangara bagmara
# 1557it [00:23, 62.40it/s]
# kamalapur kamolpur
# 1571it [00:23, 62.07it/s]
# haripur sharifpur
# 1614it [00:24, 66.36it/s]
# khaguriya khajuria
# taltali taltoli
# 1656it [00:25, 68.41it/s]
# kalipur khalishpur
# 1719it [00:26, 67.83it/s]
# bagar bagmara
# 1768it [00:26, 66.84it/s]
# kalipur khalishpur
# bagmara bagmara
# 2097it [00:31, 70.18it/s]
# raja para raj pharma
# 2129it [00:31, 69.80it/s]
# sorkar para sorkar pharma
# 2233it [00:33, 70.22it/s]
# mohanagor mohanagar
# 2281it [00:34, 68.22it/s]
# sikder para sikder pharmacy
# maz para az pharma
# sagor para sagor pharmacy
# 2302it [00:34, 67.05it/s]
# shikdar para shikdar pharmacy
# mamunpara mamun pharma
# notun bazar botul bazar
# 2426it [00:36, 66.65it/s]
# kutupalong kutupalong
# coat bazar chowrata bazar
# harispur sharifpur
# 2463it [00:36, 68.08it/s]
# arifpur sharifpur
# 2477it [00:36, 67.27it/s]
# deush desh
# 2500it [00:37, 68.30it/s]
# haripur sharifpur
# 2514it [00:37, 64.89it/s]
# rajapur razapur
# 2577it [00:38, 63.27it/s]
# ramchandra pur ramchandrapur
# bashanta bashna
# 2598it [00:38, 65.68it/s]
# chandupur achanpur
# 2627it [00:39, 67.90it/s]
# kalir bazar kalia bazar
# kamalpur kamolpur
# 2648it [00:39, 65.96it/s]
# gharipur sharifpur
# kamalpur kamolpur
# krisnapur ramkrishnapur
# 2663it [00:39, 66.40it/s]
# sharippur sharifpur
# chowdhuri para chowdhury pharmacy
# lakshipur kashipur
# 2742it [00:41, 62.42it/s]
# sharifpur sharifpur
# 2820it [00:42, 65.23it/s]
# kurakhal khuriakhali
# 2834it [00:42, 66.02it/s]
# chainpur achanpur
# 2848it [00:42, 59.72it/s]
# kasimpur kashipur
# 2896it [00:43, 64.19it/s]
# rajapur razapur
# 2917it [00:43, 64.28it/s]
# kasipur kashipur
# rashidpur kashipur
# chandipur achanpur
# 2945it [00:44, 62.94it/s]
# west ramchandrapur ramchandrapur
# 2973it [00:44, 62.74it/s]
# pubali public
# 2994it [00:45, 63.58it/s]
# khajuriya khajuria
# dhalia dighalia
# 3051it [00:45, 67.75it/s]
# sujapur ujalpur
# 3112it [00:46, 57.78it/s]
# angapara kandapara
# 3192it [00:48, 57.62it/s]
# khaguriya khajuria
# 3325it [00:50, 62.94it/s]
# rajapur razapur
# 3367it [00:51, 63.97it/s]
# palla pallabi
# 3416it [00:51, 62.26it/s]
# abdul latif haji abdul latif
# 3486it [00:52, 63.20it/s]
# ramchandrapur ramchandrapur
# sujapur ujalpur
# 3507it [00:53, 66.44it/s]
# ramkusnapur ramkrishnapur
# 3521it [00:53, 64.76it/s]
# chandpur achanpur
# khajuriya khajuria
# 3542it [00:53, 65.00it/s]
# hazi abdul latif haji abdul latif
# 3563it [00:54, 67.14it/s]
# hatgao atgao
# 3599it [00:54, 65.98it/s]
# balukhali balukhali msf
# 3620it [00:54, 63.08it/s]
# bijoy para joypara
# 3648it [00:55, 63.07it/s]
# chowdhury para chowdhury pharmacy
# 3669it [00:55, 64.25it/s]
# rasel rasel
# sonai sonali
# 3692it [00:56, 67.45it/s]
# kamalchari katmachar
# 3714it [00:56, 67.75it/s]
# chandra para chandpur pharma
# 3736it [00:56, 66.98it/s]
# palli pallabi
# royail royal
# 3924it [00:59, 67.48it/s]
# chandani shandhani
# 4043it [01:01, 64.07it/s]
# ramchandrapur ramchandrapur
# 4064it [01:01, 63.37it/s]
# jamuna jamuna
# 4099it [01:02, 63.09it/s]
# sarkar para sarkar pharmacy
# 4113it [01:02, 62.34it/s]
# kandapara kandapara
# rashidpur kashipur
# 4127it [01:02, 63.74it/s]
# ramchandrapur ramchandrapur
# 4332it [01:05, 69.14it/s]
# ulpur ujalpur
# 4354it [01:06, 68.91it/s]
# orakandi tarakandi
# 4369it [01:06, 67.34it/s]
# uttarpar uttara
# dighaliya dighalia
# 4398it [01:06, 66.97it/s]
# rajapur razapur
# 4447it [01:07, 64.40it/s]
# toparkandi tarakandi
# kamalapur kamolpur
# 4481it [01:07, 58.93it/s]
# tukarkandi tarakandi
# alinagar ali asgar
# 4516it [01:08, 63.46it/s]
# kamalpur kamolpur
# chandpur achanpur
# 4646it [01:10, 69.59it/s]
# kurikhai khuriakhali
# 4669it [01:10, 67.61it/s]
# kalapara kandapara
# vatgaon atgao
# 4697it [01:11, 64.78it/s]
# chanpur achanpur
# kanchanpur achanpur
# achhanpur achanpur
# 4746it [01:11, 65.60it/s]
# tarakandi tarakandi
# 4788it [01:12, 65.99it/s]
# auliyarchar chuliyar char
# 4861it [01:13, 64.75it/s]
# aruakandi tarakandi
# 4890it [01:14, 60.40it/s]
# kharakandi tarakandi
# 4926it [01:14, 64.15it/s]
# jainta janata
# 4947it [01:15, 64.73it/s]
# beradanga bajerdanga
# 5085it [01:17, 66.67it/s]
# dattar char datiyar char
# 5113it [01:17, 64.16it/s]
# kharia khajuria
# 5141it [01:17, 63.06it/s]
# kathaltoli taltoli
# 5204it [01:18, 65.31it/s]
# sarifpur sharifpur
# 5341it [01:20, 69.27it/s]
# charbelab care lab
# 5363it [01:21, 69.09it/s]
# chartarakandi tarakandi
# krishnapur ramkrishnapur
# 5436it [01:22, 65.90it/s]
# islampara islam pharma
# 5473it [01:22, 67.16it/s]
# chanpur achanpur
# pagla bazar kalia bazar
# 5494it [01:23, 65.06it/s]
# kacharikandi kamarkandi
# kandapara kandapara
# luchanpur achanpur
# 5551it [01:23, 67.86it/s]
# beradanga bajerdanga
# 5603it [01:24, 68.72it/s]
# jaykrishnapur ramkrishnapur
# 5655it [01:25, 67.87it/s]
# rajapur razapur
# chandani shandhani
# bagmara bagmara
# 5710it [01:26, 68.02it/s]
# dhanoi dhania
# bepari bazar beanibazar
# 5758it [01:26, 68.33it/s]
# taltola taltoli
# kashipur kashipur
# 5966it [01:29, 69.61it/s]
# kamanna amana
# 5996it [01:30, 69.19it/s]
# fulbari fulbari
# 6074it [01:31, 67.95it/s]
# sonaliya sonali
# mohan nagar mohanagar
# 6183it [01:33, 70.29it/s]
# khandapara kandapara
# 6207it [01:33, 69.65it/s]
# abdullaha para abdullah pharmacy
# 6230it [01:33, 68.67it/s]
# khalispur khalishpur
# karapara kandapara
# rajapur razapur
# 6403it [01:36, 69.12it/s]
# bogi -sarankhola bogi shoronkhola
# 6426it [01:36, 69.17it/s]
# faridpur -alamdanga faridpur al madina
# 6550it [01:38, 69.10it/s]
# kota ekota
# purakhali pankhali
# 6613it [01:39, 69.76it/s]
# ramkrsnpur ramkrishnapur
# 6634it [01:39, 69.19it/s]
# kamlapur kamolpur
# 6662it [01:40, 68.61it/s]
# fulbari fulbari
# 6698it [01:40, 67.99it/s]
# baysha bashna
# palla pallabi
# 6737it [01:41, 69.35it/s]
# kariyakhali khuriakhali
# 6760it [01:41, 68.50it/s]
# kasipur kashipur
# noyali noyani
# 6808it [01:42, 69.13it/s]
# putakhali pankhali
# rajapur razapur
# bagacra bagmara
# 6822it [01:42, 66.95it/s]
# chandpur achanpur
# harispur sharifpur
# 6853it [01:42, 69.13it/s]
# ramcandrpur ramchandrapur
# 6869it [01:43, 69.06it/s]
# khajura khajuria
# fulbari fulbari
# 6912it [01:43, 64.54it/s]
# fulbari fulbari
# ramcandrapur ramchandrapur
# 6940it [01:44, 64.05it/s]
# natima enatia
# 6982it [01:44, 64.01it/s]
# ramcandrapur ramchandrapur
# aruyakandi tarakandi
# 7012it [01:45, 57.75it/s]
# adhar manik adhar manick
# khejuriya khajuria
# khona khatail khona khatail
# pankhali pankhali
# pankhali hoglabuniya pankhali hogolabuniya
# 7035it [01:45, 64.29it/s]
# chak kamini basiya north kamini basiya
# 7122it [01:46, 66.33it/s]
# nayani noyani
# katamarchar katmachar
# 7174it [01:47, 64.71it/s]
# bagmara bagmara
# 7243it [01:48, 68.91it/s]
# kamalpur kamolpur
# 7275it [01:49, 67.97it/s]
# komolapur kamolpur
# fulbar fulbari
# 7298it [01:49, 68.83it/s]
# kancanpur achanpur
# 7314it [01:49, 68.88it/s]
# rajapur razapur
# komarkandi kamarkandi
# 7335it [01:49, 65.99it/s]
# rajapur razapur
# 7356it [01:50, 67.45it/s]
# kancanpur achanpur
# 7386it [01:50, 68.65it/s]
# fulbaria fulbari
# 7441it [01:51, 68.05it/s]
# harekrishnapur ramkrishnapur
# palla pallabi
# 7567it [01:53, 68.23it/s]
# urashi mourashi
# sarifpur sharifpur
# 7718it [01:55, 68.79it/s]
# jalalabad jalalabad eye
# dhandiya dhania
# 7741it [01:55, 68.49it/s]
# sonatala sonatola
# 7845it [01:57, 69.50it/s]
# dhandiya dhania
# 7874it [01:57, 64.09it/s]
# kasipur kashipur
# 7903it [01:58, 67.15it/s]
# mather char mother care
# 7967it [01:59, 69.42it/s]
# marakandi tarakandi
# 7999it [01:59, 69.45it/s]
# chandpur achanpur
# 8042it [02:00, 66.58it/s]
# godashimla nagda shimla
# kandarpara kandapara
# 8070it [02:00, 67.57it/s]
# tarta para tartila pharma
# 8085it [02:00, 68.09it/s]
# velamari ezlamari
# 8115it [02:01, 67.37it/s]
# tarakandi tarakandi
# haripur sharifpur
# 8138it [02:01, 68.75it/s]
# krishnapur ramkrishnapur
# 8153it [02:01, 68.34it/s]
# mohadan madan
# tarakandi tarakandi
# 8184it [02:02, 68.33it/s]
# chanpura achanpur
# 8223it [02:02, 69.09it/s]
# bagpara bagmara
# 8245it [02:03, 68.78it/s]
# chandpur achanpur
# 8285it [02:03, 69.58it/s]
# krishnapur ramkrishnapur
# 8357it [02:04, 69.29it/s]
# konapara konachipara
# md. mazharul islam md khayrul islam
# 8386it [02:05, 67.15it/s]
# khandakpara kandapara
# swadeshi sadesh
# 8433it [02:05, 66.66it/s]
# balihata baliaghata
# hariyakhali khuriakhali
# rambhadrapur ramchandrapur
# 8447it [02:06, 66.27it/s]
# khajuliya khajuria
# kashimpur kashipur
# 8462it [02:06, 66.55it/s]
# dighalgao dighalia
# birashi biash
# tarakandi tarakandi
# 8484it [02:06, 67.58it/s]
# kaidapara kandapara
# 8562it [02:07, 63.41it/s]
# haripur sharifpur
# 8583it [02:08, 65.44it/s]
# sutarkandi tarakandi
# 8606it [02:08, 67.80it/s]
# haripur sharifpur
# 8637it [02:08, 68.28it/s]
# ramchandrapur ramchandrapur
# 8748it [02:10, 69.82it/s]
# krishnapur ramkrishnapur
# 8779it [02:10, 67.82it/s]
# haripur sharifpur
# kandapara kandapara
# krishnapur ramkrishnapur
# 8795it [02:11, 68.13it/s]
# kashipur kashipur
# 8850it [02:11, 67.29it/s]
# khashipur kashipur
# kamalpur kamolpur
# komolpur kamolpur
# 8879it [02:12, 66.31it/s]
# kanchanpur achanpur
# kashimpur kashipur
# 8925it [02:13, 68.76it/s]
# tarakanda tarakandi
# 8948it [02:13, 68.16it/s]
# bausha bashna
# krishnapur ramkrishnapur
# kalapara kandapara
# 8979it [02:13, 68.46it/s]
# balughata baliaghata
# 9049it [02:14, 69.15it/s]
# krishnapur ramkrishnapur
# 9072it [02:15, 68.97it/s]
# kharia khajuria
# 9152it [02:16, 69.93it/s]
# ramkrsnapur ramkrishnapur
# 9436it [02:20, 69.36it/s]
# mulbari fulbari
# 9498it [02:21, 68.61it/s]
# harispur sharifpur
# alinagar ali asgar
# 9527it [02:21, 68.84it/s]
# horipur horihorpur
# 9565it [02:22, 69.17it/s]
# kamalpur kamolpur
# 9629it [02:23, 64.78it/s]
# kancapara kandapara
# kaytahar katmachar
# haripur sharifpur
# 9715it [02:24, 69.59it/s]
# kamalpur kamolpur
# 9779it [02:25, 69.43it/s]
# neuta neta
# 9802it [02:25, 69.15it/s]
# fukbari fulbari
# 9825it [02:26, 68.79it/s]
# haripur sharifpur
# 9865it [02:26, 69.49it/s]
# ghatkair halt kair
# 9889it [02:27, 69.17it/s]
# jamuni jamuna
# 9921it [02:27, 63.57it/s]
# kanyapara kandapara
# dhansa dhania
# 9935it [02:27, 62.22it/s]
# haripur sharifpur
# rajapur razapur
# 10002it [02:28, 68.48it/s]
# jalalabad jalalabad eye
# 10017it [02:29, 66.70it/s]
# bagmari bagmara
# haripur sharifpur
# 10121it [02:30, 66.62it/s]
# chandpur achanpur
# 10191it [02:31, 68.97it/s]
# arkandi tarakandi
# 10214it [02:31, 67.85it/s]
# soyair soair
# 10243it [02:32, 68.43it/s]
# ramchandrapur ramchandrapur
# 10273it [02:32, 68.71it/s]
# bhuiyan para bhuiayan pharmacy
# 10288it [02:32, 68.74it/s]
# madarbariya mandarbaia
# 10334it [02:33, 67.84it/s]
# balughata baliaghata
# kamalpur kamolpur
# arkandi tarakandi
# 10349it [02:33, 67.30it/s]
# saraikandi tarakandi
# 10438it [02:35, 69.07it/s]
# huikhali khuriakhali
# 10499it [02:36, 68.49it/s]
# khalispur khalishpur
# 10579it [02:37, 69.86it/s]
# kasimpur kashipur
# 10594it [02:37, 69.32it/s]
# krishnapur ramkrishnapur
# 10608it [02:37, 64.15it/s]
# alokchatra jalchatra
# 10692it [02:38, 64.97it/s]
# sadhanpur achanpur
# haripur sharifpur
# 10714it [02:39, 66.49it/s]
# sorkar para sorkar pharma
# 10765it [02:39, 68.97it/s]
# chandpur achanpur
# 10877it [02:41, 69.09it/s]
# tarakandi tarakandi
# 10989it [02:43, 66.30it/s]
# gur pipul gurpipul
# 11032it [02:43, 67.33it/s]
# amdanga amana
# 11062it [02:44, 68.70it/s]
# bagmara bagmara
# 11102it [02:44, 69.18it/s]
# fulbari fulbari
# 11125it [02:45, 69.10it/s]
# harekrishnapur ramkrishnapur
# 11162it [02:45, 69.02it/s]
# atgaon atgao
# krishnapur ramkrishnapur
# 11184it [02:46, 67.15it/s]
# chandipur achanpur
# rajapur razapur
# 11226it [02:46, 64.87it/s]
# kashimpur kashipur
# nashipur kashipur
# 11275it [02:47, 65.68it/s]
# rashidpur kashipur
# 11309it [02:48, 58.59it/s]
# ramchandrapur ramchandrapur
# 11337it [02:48, 63.19it/s]
# kalir bazar kalia bazar
# haripur sharifpur
# 11393it [02:49, 65.36it/s]
# bara ramchandrapur ramchandrapur
# 11422it [02:49, 66.00it/s]
# fulbari fulbari
# 11437it [02:49, 65.96it/s]
# radhakrishnapur ramkrishnapur
# mandalpara kandapara
# beradanga bajerdanga
# 11467it [02:50, 67.82it/s]
# lakshipur kashipur
# 11537it [02:51, 69.64it/s]
# chandipur achanpur
# 11591it [02:52, 68.68it/s]
# konapara konachipara
# 11782it [02:54, 69.83it/s]
# kashipur kashipur
# 11797it [02:55, 69.46it/s]
# poromali poroma
# 11861it [02:56, 69.96it/s]
# ajmata mamata
# 11909it [02:56, 68.59it/s]
# miyar char datiyar char
# churiyar char chuliyar char
# 11924it [02:56, 66.33it/s]
# kenachi para konachipara
# 12035it [02:58, 66.48it/s]
# doyani noyani
# 12065it [02:59, 68.29it/s]
# chandrapur ramchandrapur
# 12103it [02:59, 67.77it/s]
# karim bazar kalia bazar
# kashipur kashipur
# 12117it [02:59, 67.18it/s]
# khaura khajuria
# 12217it [03:01, 68.24it/s]
# khaturiya khajuria
# 12300it [03:02, 69.25it/s]
# beradanga bajerdanga
# 12347it [03:03, 69.51it/s]
# lakhanpur achanpur
# 12368it [03:03, 68.64it/s]
# lakshipur kashipur
# 12404it [03:04, 67.58it/s]
# fulbari fulbari
# 12426it [03:04, 68.24it/s]
# kacharipara konachipara
# 12522it [03:05, 70.03it/s]
# lalchandpur achanpur
# 12538it [03:05, 69.62it/s]
# chandipur achanpur
# 12593it [03:06, 68.56it/s]
# kashimpur kashipur
# lat krishnapur ramkrishnapur
# 12608it [03:06, 68.80it/s]
# lalchandrapur ramchandrapur
# 12666it [03:07, 63.86it/s]
# kashipur kashipur
# 12680it [03:08, 63.84it/s]
# chandipur achanpur
# haripur sharifpur
# kashimpur kashipur
# 12735it [03:08, 69.13it/s]
# radhakrishnapur ramkrishnapur
# 12886it [03:10, 69.69it/s]
# chandipur achanpur
# lakshipur kashipur
# 12915it [03:11, 68.56it/s]
# araji krishnapur ramkrishnapur
# 12952it [03:11, 67.80it/s]
# manika anika
# amrita samorita
# 12988it [03:12, 65.12it/s]
# fulbari fulbari
# nayani noyani
# 13030it [03:13, 65.69it/s]
# chandpur achanpur
# 13058it [03:13, 64.98it/s]
# krisnapur ramkrishnapur
# fulbaria fulbari
# 13072it [03:13, 60.82it/s]
# krishnapur ramkrishnapur
# kamalpur kamolpur
# 13196it [03:15, 67.34it/s]
# ramcandrapur ramchandrapur
# alinagar ali asgar
# 13242it [03:16, 68.79it/s]
# atgao atgao
# 13290it [03:17, 69.60it/s]
# kamalpur kamolpur
# 13305it [03:17, 69.10it/s]
# rajapur razapur
# 13431it [03:19, 65.25it/s]
# kandapara kandapara
# 13452it [03:19, 65.23it/s]
# matgaon atgao
# 13474it [03:19, 67.70it/s]
# bhurakhali khuriakhali
# 13488it [03:20, 65.65it/s]
# ahsanpur achanpur
# chanpur achanpur
# 13510it [03:20, 63.59it/s]
# achanpur achanpur
# srihail srihile
# chanpur achanpur
# 13549it [03:20, 68.63it/s]
# sohala shapla
# baliyaghat baliaghata
# 13595it [03:21, 69.43it/s]
# rashidpur kashipur
# 13686it [03:22, 69.01it/s]
# khardapara kandapara
# 13808it [03:24, 66.91it/s]
# kamalpur kamolpur
# balsna bashna
# 13812it [03:24, 67.44it/s]

# %%
report_geocoding(records)
# Out:
# <style type="text/css">
# </style>
# <table id="T_fce2a_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >count</th>
#       <th class="col_heading level0 col1" >pct</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >geocoding_method</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fce2a_level0_row0" class="row_heading level0 row0" >Location from Health Sites IO and within admin 1</th>
#       <td id="T_fce2a_row0_col0" class="data row0 col0" >80</td>
#       <td id="T_fce2a_row0_col1" class="data row0 col1" >0.6%</td>
#     </tr>
#     <tr>
#       <th id="T_fce2a_level0_row1" class="row_heading level0 row1" >Location from Health Sites IO and within admin 2</th>
#       <td id="T_fce2a_row1_col0" class="data row1 col0" >5</td>
#       <td id="T_fce2a_row1_col1" class="data row1 col1" >0.0%</td>
#     </tr>
#     <tr>
#       <th id="T_fce2a_level0_row2" class="row_heading level0 row2" >None</th>
#       <td id="T_fce2a_row2_col0" class="data row2 col0" >13727</td>
#       <td id="T_fce2a_row2_col1" class="data row2 col1" >99.4%</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Health Sites IO using orgunitlevel 5 name

# %%
records['NAME5'] = records['orgunitlevel5'].str.lower()

# %%
remove_words(records, 'NAME5', words_to_remove)

# %%
for idx, row in tqdm(records.iterrows()):
    
    if row.geocoding_method == "None":
    
        # Check if there is another entry with location
        match, score = match_name(row.NAME5, list(nodes_io['name']), 80)
    #     match, score = match_name(row.name_concat, list(nodes_io.name_concat), 85)

        if score > 0:
            print(row.NAME, match)
            matching_row = nodes_io.loc[nodes_io['name']==match].copy()
            res = matching_row.iloc[0]

            if not pd.isna(row.adm3):
                adm3 = geob3.loc[geob3['shapeName'] == row['adm3']].copy()
                if adm3.contains(res.geometry).values[0] == True:
                    records.loc[idx, "longitude"] = res.geometry.x
                    records.loc[idx, "latitude"] = res.geometry.y
                    records.loc[idx, "geocoding_method"] = "Location from Health Sites IO and within admin 3"

            if not pd.isna(row.adm2):
                adm2 = geob2.loc[geob2['shapeName'] == row['adm2']].copy()
                if adm2.contains(res.geometry).values[0] == True:            
                    records.loc[idx, "longitude"] = res.geometry.x
                    records.loc[idx, "latitude"] = res.geometry.y
                    records.loc[idx, "geocoding_method"] = "Location from Health Sites IO and within admin 2"

            if not pd.isna(row.adm1):
                adm1 = geob1.loc[geob1['shapeName'] == row['adm1']].copy()
                if adm1.contains(res.geometry).values[0] == True:            
                    records.loc[idx, "longitude"] = res.geometry.x
                    records.loc[idx, "latitude"] = res.geometry.y
                    records.loc[idx, "geocoding_method"] = "Location from Health Sites IO and within admin 1"
# Out:
# 129it [00:01, 70.14it/s]
# mothertali achanpur
# shatkar achanpur
# 248it [00:03, 65.56it/s]
# khantakhali achanpur
# majid hang achanpur
# raypura achanpur
# talukder hat achanpur
# 269it [00:03, 62.13it/s]
# chahutpur kashipur
# isakathi kashipur
# kaladama kashipur
# magarpara kashipur
# sarsi kashipur
# 329it [00:04, 65.73it/s]
# ajimpur adhar manick
# bhanga adhar manick
# ektarhat adhar manick
# char khakkata achanpur
# freedom fighter mostofakamal achanpur
# kashimpur achanpur
# khontakhali achanpur
# 424it [00:06, 68.42it/s]
# hajrihat ali asgar
# mautupi ali asgar
# 440it [00:06, 69.51it/s]
# nabipur dhania
# 454it [00:06, 61.09it/s]
# char sultani razapur
# janta bazar razapur
# shantir hat razapur
# south rajapur razapur
# 525it [00:07, 65.77it/s]
# azad mia barir achanpur
# nurnobi dofadar barir achanpur
# zaher maolana barir achanpur
# 625it [00:09, 62.40it/s]
# araliya achanpur
# balia kandi achanpur
# daiyarpar achanpur
# gosher howla achanpur
# kazi kandi achanpur
# south keyamullah achanpur
# 646it [00:09, 62.96it/s]
# balighona k.s.n memorial ramchandrapur
# bermahal ramchandrapur
# shaorakati ramchandrapur
# varukati ramchandrapur
# 718it [00:10, 65.80it/s]
# angharia razapur
# barabakpur razapur
# dakhsin rajapur razapur
# pashim fuluher razapur
# 757it [00:11, 65.98it/s]
# baher char konachipara
# garipar konachipara
# jay banglar konachipara
# karkhana konachipara
# 787it [00:11, 63.45it/s]
# aowliapur bazzar rangopaldi
# char borhan rangopaldi
# uttar rongopaldi rangopaldi
# 856it [00:12, 48.10it/s]
# londa pankhali
# nishanbariya pankhali
# pachjuniya pankhali
# 916it [00:14, 51.37it/s]
# akhoibaria  - patuakhali sadar kamolpur
# char mysadi kamolpur
# purbarrbhayala kamolpur
# south dharandi kamolpur
# west vhaila kamolpur
# 1210it [00:19, 52.12it/s]
# holapara -ashuganj sharifpur
# sharifpur -ashuganj sharifpur
# 1434it [00:23, 58.58it/s]
# aliyara sharifpur
# naraha sharifpur
# 1766it [00:28, 56.72it/s]
# gunagore khalishpur
# kalipur khalishpur
# palegrem khalishpur
# 1778it [00:29, 56.38it/s]
# paschim sadhanpur achanpur
# 1829it [00:29, 51.22it/s]
# dakshin gashbaria kashipur
# dakshin hasimpur kashipur
# gachbariya kashipur
# uttar hasimpur kashipur
# baharm para joypara
# uttar joyara kulal para joypara
# 1968it [00:32, 54.32it/s]
# badiya khali katmachar
# baman sondar katmachar
# cutachara katmachar
# fenapuri katmachar
# purba khairchara katmachar
# 1999it [00:32, 56.27it/s]
# bathuya asia
# jan box kamrunnesa asia
# jarina-mafzal asia
# 2114it [00:34, 55.88it/s]
# hajee sayed sirajul hauqe nova pharma
# latifa sufiya nova pharma
# musa sheth nova pharma
# samidar koyang nova pharma
# 2156it [00:35, 57.76it/s]
# modho harisapur noyapara sharifpur
# 2182it [00:35, 54.89it/s]
# dakshin carati chargat
# dip carati chargat
# tulatali chargat
# uttar brammondenga chargat
# 2268it [00:37, 58.99it/s]
# hari khola khuriakhali
# kutubdia para khuriakhali
# modhom medha kahipiya khuriakhali
# uttar fulchari khuriakhali
# 2304it [00:37, 66.74it/s]
# faraji para jalalabad eye
# 2431it [00:39, 67.25it/s]
# gobindapur radda
# krsanpur radda
# pilgiri radda
# 2466it [00:40, 60.43it/s]
# kampabas rahman pharmacy
# mahalaksipur rahman pharmacy
# naighar rahman pharmacy
# 2515it [00:41, 63.91it/s]
# bareshbar razapur
# charanal  - burichang razapur
# pachora razapur
# rajapur razapur
# 2649it [00:43, 59.89it/s]
# bhallav pur kalia bazar
# krisnapur kalia bazar
# olipur kalia bazar
# raicong kalia bazar
# saktala kalia bazar
# sayedpur kalia bazar
# 2760it [00:45, 55.43it/s]
# mamisshor  - laksham uttara
# poliya  - laksham uttara
# 2841it [00:46, 59.04it/s]
# b.chapitala ramchandrapur
# 2890it [00:47, 58.53it/s]
# kalachanderkandi kamarkandi
# masimpur kamarkandi
# rajapur kamarkandi
# tetuiya rampur kamarkandi
# yousufpur kamarkandi
# 2938it [00:48, 50.12it/s]
# drappur ramchandrapur
# hasangani ramchandrapur
# kerniya ramchandrapur
# jangalia  - daganbhuiya razapur
# joynarayanpur  - daganbhuiya razapur
# west ramchandrapur razapur
# 2958it [00:48, 54.88it/s]
# alipur dighalia
# boro dhaliya dighalia
# choto dhaliya dighalia
# daulatpur dighalia
# 3055it [00:50, 57.67it/s]
# baghaicharimukh dighalia
# 3183it [00:52, 60.62it/s]
# hasan delar bari kalia bazar
# jabed ulya hawladar bari kalia bazar
# serajul haq presidents bari kalia bazar
# wali ullah miah bari kalia bazar
# khaguriya dighalia
# purbo daghali dighalia
# purbo jamirtali dighalia
# 3203it [00:52, 56.94it/s]
# dakshin mandari mandarbaia
# gondabbapur mandarbaia
# md nagar khamar bari mandarbaia
# ratanpur bhuyan bari mandarbaia
# 3269it [00:53, 51.12it/s]
# chondipur . ramganj achanpur
# masimpur . ramganj achanpur
# north hazipur . ramganj achanpur
# jaypura achanpur
# sapali para achanpur
# sekhpura achanpur
# 3323it [00:55, 46.65it/s]
# anantapur kashipur
# ekalaspur bazer kashipur
# jayakrsnapur kashipur
# kamdebpur kashipur
# lal miah sashab bari kashipur
# murad master kashipur
# 3356it [00:55, 60.31it/s]
# babu nagar sharifpur
# sonapur sharifpur
# 3642it [01:00, 66.07it/s]
# fakirachara  - jurachari madan
# jamerchari madan
# panchari mukh  -jurachari madan
# 3693it [01:00, 62.20it/s]
# kaindamukh balukhali msf
# 3762it [01:01, 62.01it/s]
# charrup joypara
# 3909it [01:04, 60.34it/s]
# north bahirdiya achanpur
# 4023it [01:06, 65.73it/s]
# dofa puratan  para
# 4037it [01:06, 62.74it/s]
# char dori krishnapur ramkrishnapur
# east kandi ramkrishnapur
# ramchandrapur ramkrishnapur
# shouldubi ramkrishnapur
# 4071it [01:06, 50.80it/s]
# dhanonjoykhali  gazipur sadar kashipur
# dhirarsrom  gazipur sadar kashipur
# enayetapur kashipur
# latifpur kashipur
# sarpaitali kashipur
# vabanipur  gazipur sadar kashipur
# 4124it [01:07, 58.47it/s]
# bakchala fulbari
# jathaliya fulbari
# montola fulbari
# nabirboho fulbari
# ramchandrapur fulbari
# shamsul-shanti - kaliakair fulbari
# 4184it [01:08, 57.31it/s]
# chandun - kapasia achanpur
# defuliya achanpur
# maishadamna achanpur
# nalgaon achanpur
# 4291it [01:10, 58.46it/s]
# chargobra  - gopalganj sadar gobra
# ghonapara  - gopalgonj sadar gobra
# gobra  - gopalganj sadar gobra
# chardalaitala - gopalganj sadar jalalabad eye
# madla  - gopalganj sadar jalalabad eye
# tatulia jalalabad eye
# tetulia  - gopalganj sadar jalalabad eye
# 4325it [01:11, 55.16it/s]
# beleypara  - gopalganj sadar ujalpur
# ulpur ujalpur
# gopalpur  - gopalganj sadar rafi
# manikdah  - gopalganj sadar rafi
# 4353it [01:11, 61.59it/s]
# khagrabaria  - kasiani tarakandi
# maizkandi  - kashiani tarakandi
# orakandi tarakandi
# 4431it [01:12, 59.08it/s]
# bejra - mukshedpur kandapara
# 4617it [01:15, 62.58it/s]
# chandpur madhyapara achanpur
# chariya achanpur
# mandolbhog - katiadi achanpur
# nimakpurura achanpur
# 4780it [01:18, 57.18it/s]
# char lakshmipur ali asgar
# raghunandi ali asgar
# 4815it [01:19, 64.54it/s]
# east raghurampur chuliyar char
# mridhabarimor chuliyar char
# 4964it [01:21, 64.18it/s]
# kushiar char achanpur
# bahirchor ramkrishnapur
# ishakhabad ramkrishnapur
# prof. dr. md. lutfor rahman khan - harirampur ramkrishnapur
# 4978it [01:21, 58.62it/s]
# banparil -manikganj sadar shakti pharma
# gopalkhali  - manikganj sadar. shakti pharma
# salponandapur - manikganj sadar shakti pharma
# barahir char ramkrishnapur
# char krishnapur ramkrishnapur
# char mokompur ramkrishnapur
# 4991it [01:21, 52.76it/s]
# rajibpur ramkrishnapur
# 5009it [01:22, 53.05it/s]
# angutia dighalia
# 5463it [01:29, 52.51it/s]
# char kalikapur achanpur
# majherchar achanpur
# 5654it [01:32, 60.27it/s]
# chandani shandhani
# harindhara shandhani
# joukura  - rajbari sadar shandhani
# 5699it [01:33, 61.18it/s]
# ramchandrapur  - bhedarganj ramchandrapur
# 5761it [01:34, 56.53it/s]
# chandrapur - shariatpur sadar ramchandrapur
# gajipur ramchandrapur
# kamatmai tarakandi
# monai chhaiyalkandi tarakandi
# 5803it [01:35, 63.29it/s]
# kanchanpur east pauli achanpur
# kanchanpur kajipara achanpur
# kanchanpur karmakarpara achanpur
# 5959it [01:37, 53.19it/s]
# baishkail nagda shimla
# banamali nagda shimla
# saidpur nagda shimla
# 6116it [01:40, 54.62it/s]
# bhatshala mamudnagar
# gopalpur mamudnagar
# kalamaid mamudnagar
# mirzapur mamudnagar
# sudampara mamudnagar
# 6208it [01:41, 60.24it/s]
# parbohuli mamudnagar
# saratoil  - tangail sadar mamudnagar
# 6322it [01:43, 63.35it/s]
# kachubuniya -mongla sundarban
# n bastali -mongla sundarban
# 6378it [01:44, 65.27it/s]
# karhubuniya -morrelganj ramchandrapur
# 6399it [01:44, 62.43it/s]
# chandpur -rampal ujalpur
# gobindrapur -rampal ujalpur
# kadamadi -rampal ujalpur
# ujalkur -rampal ujalpur
# bandaghata -sarankhola dhansagor
# nalbunia sarderbari -sarankhola dhansagor
# 6413it [01:45, 60.24it/s]
# rajapur bazer -sarankhola dhansagor
# zadab master bari -sarankhola dhansagor
# 6448it [01:45, 64.24it/s]
# pach komlapur -alamdanga khalishpur
# parkula -alamdanga khalishpur
# sree rampur -alamdanga khalishpur
# 6658it [01:49, 65.89it/s]
# daherpara kashipur
# dakatia kashipur
# daulatdihi kashipur
# khojarhat kashipur
# saymnagar kashipur
# 6819it [01:51, 62.58it/s]
# chandpur achanpur
# daribunni achanpur
# hamirhati achanpur
# 6854it [01:52, 55.59it/s]
# canduyali madhumati
# corkol madhumati
# dagdugi bazer madhumati
# 6918it [01:53, 61.36it/s]
# ajampur razapur
# alampur razapur
# ramcandrapur razapur
# 6939it [01:53, 61.12it/s]
# mandartala enatia
# noyani para enatia
# 6967it [01:53, 59.05it/s]
# berbari fulbari
# kajipara fulbari
# 6995it [01:54, 61.98it/s]
# khalsibuniya baliaghata
# mailmara  - batiaghata baliaghata
# usha  - batiaghata baliaghata
# 7038it [01:54, 61.58it/s]
# deyara kohinoor dighalia
# farmayeshkhana dighalia
# panigati dighalia
# sugondhi dighalia
# 7261it [01:58, 62.74it/s]
# char sonatala ramkrishnapur
# dhaki para ramkrishnapur
# krofatnagar ramkrishnapur
# mohammadpur ramkrishnapur
# morarchar ramkrishnapur
# 7290it [01:58, 63.87it/s]
# gobra chandpur achanpur
# kanchonpur achanpur
# kusholeebasa achanpur
# mirpur achanpur
# 7327it [01:59, 61.43it/s]
# boro ailchara jalchatra
# khordd ailchara jalchatra
# 7455it [02:01, 64.36it/s]
# gabarnada razapur
# nauvanga razapur
# 7525it [02:02, 62.34it/s]
# hinda -gangni tetul bariya
# north vorat -gangni tetul bariya
# saharatala -gangni tetul bariya
# kalyanpur -gangni tetul bariya
# 7597it [02:03, 65.14it/s]
# kumri pohim -lohagara dighalia
# kumri purbapara dighalia
# lutiya dighalia
# basupatti -lohagara kashipur
# 7674it [02:04, 62.90it/s]
# gadaipur khajuria
# parisamari khajuria
# rautara khajuria
# tuardanga  - assasuni khajuria
# 7688it [02:04, 60.15it/s]
# bakara sonali
# baliapur  - assasuni sonali
# godara sonali
# sarappur sonali
# 7815it [02:06, 60.72it/s]
# bansipur sharifpur
# gumantali sharifpur
# hasarcak sharifpur
# isbaripur sharifpur
# sirtala sharifpur
# 7850it [02:07, 64.71it/s]
# dhandiya dhania
# manikhar dhania
# panchpara  - tala dhania
# 7899it [02:08, 64.44it/s]
# khamargedra  - bakshiganj dhania
# lauchapara dhania
# satanipara dhania
# 8029it [02:10, 56.00it/s]
# chandpur (ramnagar) kashipur
# pakulya kashipur
# senguya kashipur
# shekhpara kashipur
# bera pathalia sharifpur
# godashimla sharifpur
# 8041it [02:10, 54.02it/s]
# ronrampur chaurasta sharifpur
# shitalkursha sharifpur
# shyampur sharifpur
# sreerampur sharifpur
# 8152it [02:12, 66.96it/s]
# bangram madan
# banshbari madan
# korgram madan
# shengua madan
# 8262it [02:14, 52.87it/s]
# andariya para atimkhana fulbari
# chaudar fulbari
# chhankanda fulbari
# ichail fulbari
# jorbariya akter sarkar bari fulbari
# jorbariya lahuripara fulbari
# kalakanda  - fulbaria fulbari
# 8388it [02:15, 61.61it/s]
# choto dashpara achanpur
# west maijpara achanpur
# bausa sadesh
# north itakhola sadesh
# swadeshi sadesh
# 8452it [02:17, 59.41it/s]
# banbangla kashipur
# mohanpur kashipur
# shuhila kashipur
# tanmahishtara kashipur
# 8613it [02:19, 52.11it/s]
# chorbahadurpur ramchandrapur
# chorniyamat madhyapara ramchandrapur
# khariyapara ramchandrapur
# michkipara ramchandrapur
# rambhadrapur bazar ramchandrapur
# 8634it [02:20, 60.95it/s]
# dhakirkanda tarakandi
# gopalpur tarakandi
# madhupur tarakandi
# 8697it [02:21, 59.27it/s]
# bhartoshi sonali
# mallikpur sunai sonali
# mansurpur sonali
# 8829it [02:22, 64.84it/s]
# nazirpur ramkrishnapur
# rabaya jabber ramkrishnapur
# 8844it [02:23, 62.32it/s]
# kapasatiya madan
# kuliyati madan
# madan dakkin para  - madan madan
# 8915it [02:24, 63.48it/s]
# echulia bazar khalishpur
# pabai khalishpur
# pratappur khalishpur
# 9135it [02:27, 64.37it/s]
# karnapur razapur
# meghagacha razapur
# 9305it [02:30, 61.01it/s]
# chagaldhara fulbari
# domkandi -  -sariakandi fulbari
# harina -sariakandi fulbari
# pacpirtala -sariakandi fulbari
# bibirpara kamolpur
# haorakhali kamolpur
# rauhadaha -sariakandi kamolpur
# sultanara kamolpur
# 9327it [02:30, 62.68it/s]
# antarpara tarakandi
# dighalkandi -sariakandi tarakandi
# gosaibari tarakandi
# partitparal -sariakandi tarakandi
# 9362it [02:31, 65.08it/s]
# jhazor - sherpur kamarkandi
# parvabanipur   -sherpur kamarkandi
# suvogacha kamarkandi
# 9447it [02:32, 63.79it/s]
# ariya caknandana sonatola
# chamargacha sonatola
# kamarpara sonatola
# ranirpara sonatola
# adatala dalli
# mayamari dalli
# piragachi dalli
# 9504it [02:33, 66.71it/s]
# alinagar ali asgar
# bahamari  - gomastapur ali asgar
# 9706it [02:36, 64.18it/s]
# birnagar baliaghata
# khasbaguri baliaghata
# mahabatpur baliaghata
# naoda baliaghata
# sulatanpur baliaghata
# 9785it [02:37, 63.93it/s]
# boro shibpur achanpur
# nanais achanpur
# sahapur achanpur
# 9813it [02:37, 64.50it/s]
# debipur khajuria
# jaipur khajuria
# khord kalana khajuria
# ranail khajuria
# 9888it [02:38, 68.87it/s]
# ganjoyar achanpur
# ilasabari achanpur
# simuliya achanpur
# 9954it [02:39, 66.99it/s]
# cakgabindpur ramkrishnapur
# kismat gabindapur ramkrishnapur
# kutailhat ramkrishnapur
# 9997it [02:40, 67.02it/s]
# enayetpur kashipur
# trimohani kashipur
# 10079it [02:41, 66.86it/s]
# dastannagar baliaghata
# durgapur baliaghata
# jogendranagar baliaghata
# 10158it [02:42, 60.36it/s]
# korer gram khajuria
# sadhanagar khajuria
# basila - natore sadar mamudnagar
# bhattopara -natore sadar mamudnagar
# rajapur kamardiar  - natore sadar mamudnagar
# 10267it [02:44, 63.40it/s]
# baktarpur  - bera puran varanga
# kallanpur  - bera puran varanga
# ragunathpur  - bera puran varanga
# 10309it [02:45, 62.19it/s]
# agshoail -chatmohor sharifpur
# charoikol -chatmohor sharifpur
# dhulauri -chatmohor sharifpur
# jhakra - chatmohor sharifpur
# 10540it [02:48, 55.96it/s]
# anupampur chargat
# barabariya chargat
# kakramari chargat
# mungli  - charghat chargat
# 10645it [02:50, 62.18it/s]
# berpara sharifpur
# char majhirdia - paba sharifpur
# harupur sharifpur
# sonaikandi sharifpur
# 10680it [02:50, 59.05it/s]
# bilamariya joypara
# choto senvag joypara
# dhopapara -puthia joypara
# jiupara joypara
# madhukhali joypara
# 10742it [02:51, 52.86it/s]
# aguria razapur
# dattabari razapur
# maijhail razapur
# rajapur dakshin razapur
# rajapur uttar razapur
# randhunibari razapur
# subarnasara razapur
# 11049it [02:56, 61.34it/s]
# alidaha ramkrishnapur
# khordoshimla ramkrishnapur
# nandokusha ramkrishnapur
# 11158it [02:58, 52.18it/s]
# amtali ujalpur
# jagdal ujalpur
# maakriya ujalpur
# shitalai ujalpur
# atgaon atgao
# bandhugaon atgao
# baragaon atgao
# mollapara atgao
# 11239it [02:59, 67.30it/s]
# janatamor kamolpur
# jayrampur kamolpur
# kalikapur sundarban
# khoshalpur sundarban
# 11254it [03:00, 65.09it/s]
# uttar shibpur sundarban
# uttar sundarban sundarban
# 11303it [03:00, 57.05it/s]
# noyabad ramchandrapur
# pormeshpur ramchandrapur
# ramchandrapur ramchandrapur
# 11363it [03:01, 54.51it/s]
# barakona achanpur
# chakla achanpur
# jahanabad madrasa achanpur
# 11411it [03:02, 58.67it/s]
# chandiya konachipara
# hosenpur konachipara
# ketakirhat konachipara
# samitteer bazar -fulchhari konachipara
# 11439it [03:03, 62.31it/s]
# koraibari  - gaibandha sadar kamarkandi
# 11459it [03:03, 50.90it/s]
# bara durgapur ramchandrapur
# gardighi -gaibandha sadar ramchandrapur
# jagatray gopalpur ramchandrapur
# sonarpara ramchandrapur
# bishnupur saha pharmacy
# lakshipur saha pharmacy
# nandina saha pharmacy
# shibpur saha pharmacy
# 11472it [03:03, 48.84it/s]
# bamon kuri -gobindganj fulbari
# digolee fulbari -gobindganj fulbari
# kunjo maloncha -gobindganj fulbari
# roghunathpur -gobindganj fulbari
# shakpala -gobindganj fulbari
# 11661it [03:06, 60.35it/s]
# madarer vati achanpur
# north sicha achanpur
# south chandipur achanpur
# south sicha achanpur
# 11675it [03:07, 62.00it/s]
# char madari para - sunadarganj sharifpur
# charitabari sharifpur
# para saduya sharifpur
# 11766it [03:08, 57.61it/s]
# chandrakhana fulbari
# jotakrisha hari fulbari
# kuthichandrakhana fulbari
# panimachhkuti fulbari
# rasmela  - phulbari fulbari
# ajoyatari kashipur
# dakshin anantapur kashipur
# kashipur kashipur
# 11778it [03:08, 51.70it/s]
# madhya anantapur kashipur
# shyampur kashipur
# 11920it [03:10, 65.53it/s]
# dubala bari  - raumari roumari
# fulbari -rowmari roumari
# ijalmari roumari
# kanda para  - raumari roumari
# ratanpur roumari
# 12060it [03:13, 65.06it/s]
# chandrapur ramchandrapur
# latabar ramchandrapur
# north balapara ramchandrapur
# satirpar ramchandrapur
# 12808it [03:23, 67.83it/s]
# mashangaon sharifpur
# torra sharifpur
# 12844it [03:24, 65.60it/s]
# a. chandan chahat kashipur
# jagdal kashipur kashipur
# kashipur jhabortola kashipur
# 12970it [03:26, 66.84it/s]
# mondori  -baniachong mandarbaia
# uttar sangor  -baniachong mandarbaia
# 13097it [03:28, 61.86it/s]
# bodordi bashna
# dakshingram bashna
# daserkuna bashna
# ahmedpur dighalia
# baderayghar dighalia
# galimpur  - nobigonj dighalia
# radhapur dighalia
# 13174it [03:29, 61.20it/s]
# chitlia - kamalganj ali asgar
# kamudpur ali asgar
# srinathpur ali asgar
# 13231it [03:30, 63.36it/s]
# dattagram sharifpur
# telibil -kulaura sharifpur
# 13252it [03:30, 60.67it/s]
# dakshin baranti kamolpur
# trailoksya bijay kamolpur
# daudpur  - moulvi bazar sadar khalishpur
# gurarai khalishpur
# lamuya khalishpur
# 13582it [03:35, 66.34it/s]
# brahmangram botul bazar
# jayforpur botul bazar
# mutiargaon  - balaganj botul bazar
# 13603it [03:35, 64.62it/s]
# kargram ali asgar
# uttarbagh - beanibazar ali asgar
# kasba beanibazar
# 13681it [03:36, 60.02it/s]
# dora fulbari
# kayasthgram fulbari
# rafipur fulbari
# tikarpara fulbari
# 13772it [03:38, 65.24it/s]
# bagerkhola  - dakhin surma kalia bazar
# khajakhalu  - dakshin surma kalia bazar
# kalaruka -sylhet sadar jalalabad eye
# 13812it [03:38, 63.11it/s]

# %%
report_geocoding(records)
# Out:
# <style type="text/css">
# </style>
# <table id="T_b2bf9_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >count</th>
#       <th class="col_heading level0 col1" >pct</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >geocoding_method</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b2bf9_level0_row0" class="row_heading level0 row0" >Location from Health Sites IO and within admin 1</th>
#       <td id="T_b2bf9_row0_col0" class="data row0 col0" >207</td>
#       <td id="T_b2bf9_row0_col1" class="data row0 col1" >1.5%</td>
#     </tr>
#     <tr>
#       <th id="T_b2bf9_level0_row1" class="row_heading level0 row1" >Location from Health Sites IO and within admin 2</th>
#       <td id="T_b2bf9_row1_col0" class="data row1 col0" >7</td>
#       <td id="T_b2bf9_row1_col1" class="data row1 col1" >0.1%</td>
#     </tr>
#     <tr>
#       <th id="T_b2bf9_level0_row2" class="row_heading level0 row2" >None</th>
#       <td id="T_b2bf9_row2_col0" class="data row2 col0" >13598</td>
#       <td id="T_b2bf9_row2_col1" class="data row2 col1" >98.5%</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # Geocoding with APIs

# %%
dotenv_path = find_dotenv()
load_dotenv(dotenv_path)
bing_key = os.environ.get("bing_key")
google_key = os.environ.get("google_key")

# %%
geolocator_osm = Nominatim(user_agent="health-equity")
geolocator_bing = Bing(api_key=bing_key)
geolocator_google = GoogleV3(api_key=google_key)

# %% [markdown]
# ## Facility name and admin 3 names

# %% [markdown]
# Geocode based on facility name (orgunitlevel5) + admin 3 name.
# Check to make sure result falls within admin 3 polygon.

# %%
records_subset = records.loc[records.geocoding_method=="None"].copy()
# only include trying to geocode rows that have an admin name that is matched to the Geoboundaries file
records_subset = records_subset.loc[~records_subset.adm3.isna()].copy()

# %%
len(records_subset)
# Out:
# 4541

# %%
records_subset.head(2)
# Out:
#     orgunitlevel1 orgunitlevel2 orgunitlevel3 orgunitlevel4  orgunitlevel5  \
# 12     Bangladesh     Barishal       Barguna        Amtali   ATHARAGASHIA
# 552    Bangladesh     Barishal      Barishal      Wazirpur     BARA KOTHA
#
#        orgunitlevel6 orgunitlevel4_edit orgunitlevel3_edit orgunitlevel2_edit  \
# 12   Purbo Sonakhli              Amtali            Barguna           Barishal
# 552       Malikanda            Wazirpur           Barishal           Barishal
#
#          adm3     adm2     adm1            NAME geocoding_method  longitude  \
# 12     Amtali  Barguna  Barisal  purbo sonakhli             None        NaN
# 552  Wazirpur  Barisal  Barisal       malikanda             None        NaN
#
#      latitude         NAME5
# 12        NaN  atharagashia
# 552       NaN    bara kotha

# %%
for idx, row in tqdm(records_subset.iterrows()):
    
    adm3 = geob3.loc[geob3['shapeName'] == row['adm3']].copy()
    run_geocoding(idx, row, records, adm3, ['NAME', 'adm3'], 'bd')
# Out:
# 4541it [39:39,  1.91it/s]

# %%
report_geocoding(records)
# Out:
# <style type="text/css">
# </style>
# <table id="T_1a379_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >count</th>
#       <th class="col_heading level0 col1" >pct</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >geocoding_method</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1a379_level0_row0" class="row_heading level0 row0" >Location from Health Sites IO and within admin 1</th>
#       <td id="T_1a379_row0_col0" class="data row0 col0" >207</td>
#       <td id="T_1a379_row0_col1" class="data row0 col1" >1.5%</td>
#     </tr>
#     <tr>
#       <th id="T_1a379_level0_row1" class="row_heading level0 row1" >Location from Health Sites IO and within admin 2</th>
#       <td id="T_1a379_row1_col0" class="data row1 col0" >7</td>
#       <td id="T_1a379_row1_col1" class="data row1 col1" >0.1%</td>
#     </tr>
#     <tr>
#       <th id="T_1a379_level0_row2" class="row_heading level0 row2" >NAME and adm3 query Bing</th>
#       <td id="T_1a379_row2_col0" class="data row2 col0" >6797</td>
#       <td id="T_1a379_row2_col1" class="data row2 col1" >49.2%</td>
#     </tr>
#     <tr>
#       <th id="T_1a379_level0_row3" class="row_heading level0 row3" >NAME and adm3 query Google</th>
#       <td id="T_1a379_row3_col0" class="data row3 col0" >5288</td>
#       <td id="T_1a379_row3_col1" class="data row3 col1" >38.3%</td>
#     </tr>
#     <tr>
#       <th id="T_1a379_level0_row4" class="row_heading level0 row4" >NAME and adm3 query OSM</th>
#       <td id="T_1a379_row4_col0" class="data row4 col0" >335</td>
#       <td id="T_1a379_row4_col1" class="data row4 col1" >2.4%</td>
#     </tr>
#     <tr>
#       <th id="T_1a379_level0_row5" class="row_heading level0 row5" >None</th>
#       <td id="T_1a379_row5_col0" class="data row5 col0" >1178</td>
#       <td id="T_1a379_row5_col1" class="data row5 col1" >8.5%</td>
#     </tr>
#   </tbody>
# </table>

# %%
records_subset = records.loc[records.geocoding_method=="None"].copy()
records_subset = records_subset.loc[~records_subset.adm3.isna()].copy()
records_subset = records_subset.loc[~records_subset.adm2.isna()].copy()

# %%
len(records_subset)
# Out:
# 671

# %% [markdown]
# ## Facility name and admin 2 names

# %% [markdown]
# Geocode based on facility name (orgunitlevel5) + admin 2 name.
# Check to make sure result falls within admin 3 polygon.

# %%
for idx, row in tqdm(records_subset.iterrows()):
    
    adm3 = geob3.loc[geob3['shapeName'] == row['adm3']].copy()
    run_geocoding(idx, row, records, adm3, ['NAME', 'adm2'], 'bd')
# Out:
# 671it [05:57,  1.88it/s]

# %%
report_geocoding(records)
# Out:
# <style type="text/css">
# </style>
# <table id="T_d3976_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >count</th>
#       <th class="col_heading level0 col1" >pct</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >geocoding_method</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d3976_level0_row0" class="row_heading level0 row0" >Location from Health Sites IO and within admin 1</th>
#       <td id="T_d3976_row0_col0" class="data row0 col0" >207</td>
#       <td id="T_d3976_row0_col1" class="data row0 col1" >1.5%</td>
#     </tr>
#     <tr>
#       <th id="T_d3976_level0_row1" class="row_heading level0 row1" >Location from Health Sites IO and within admin 2</th>
#       <td id="T_d3976_row1_col0" class="data row1 col0" >7</td>
#       <td id="T_d3976_row1_col1" class="data row1 col1" >0.1%</td>
#     </tr>
#     <tr>
#       <th id="T_d3976_level0_row2" class="row_heading level0 row2" >NAME and adm2 query Bing</th>
#       <td id="T_d3976_row2_col0" class="data row2 col0" >81</td>
#       <td id="T_d3976_row2_col1" class="data row2 col1" >0.6%</td>
#     </tr>
#     <tr>
#       <th id="T_d3976_level0_row3" class="row_heading level0 row3" >NAME and adm2 query Google</th>
#       <td id="T_d3976_row3_col0" class="data row3 col0" >66</td>
#       <td id="T_d3976_row3_col1" class="data row3 col1" >0.5%</td>
#     </tr>
#     <tr>
#       <th id="T_d3976_level0_row4" class="row_heading level0 row4" >NAME and adm2 query OSM</th>
#       <td id="T_d3976_row4_col0" class="data row4 col0" >4</td>
#       <td id="T_d3976_row4_col1" class="data row4 col1" >0.0%</td>
#     </tr>
#     <tr>
#       <th id="T_d3976_level0_row5" class="row_heading level0 row5" >NAME and adm3 query Bing</th>
#       <td id="T_d3976_row5_col0" class="data row5 col0" >6797</td>
#       <td id="T_d3976_row5_col1" class="data row5 col1" >49.2%</td>
#     </tr>
#     <tr>
#       <th id="T_d3976_level0_row6" class="row_heading level0 row6" >NAME and adm3 query Google</th>
#       <td id="T_d3976_row6_col0" class="data row6 col0" >5288</td>
#       <td id="T_d3976_row6_col1" class="data row6 col1" >38.3%</td>
#     </tr>
#     <tr>
#       <th id="T_d3976_level0_row7" class="row_heading level0 row7" >NAME and adm3 query OSM</th>
#       <td id="T_d3976_row7_col0" class="data row7 col0" >335</td>
#       <td id="T_d3976_row7_col1" class="data row7 col1" >2.4%</td>
#     </tr>
#     <tr>
#       <th id="T_d3976_level0_row8" class="row_heading level0 row8" >None</th>
#       <td id="T_d3976_row8_col0" class="data row8 col0" >1027</td>
#       <td id="T_d3976_row8_col1" class="data row8 col1" >7.4%</td>
#     </tr>
#   </tbody>
# </table>

# %%
records_subset = records.loc[records.geocoding_method=="None"].copy()
records_subset = records_subset.loc[~records_subset.adm3.isna()].copy()
records_subset = records_subset.loc[~records_subset.adm1.isna()].copy()

# %% [markdown]
# ## Facility name and admin 1 names

# %%
for idx, row in tqdm(records_subset.iterrows()):
    
    adm3 = geob3.loc[geob3['shapeName'] == row['adm3']].copy()
    run_geocoding(idx, row, records, adm3, ['NAME', 'adm1'], 'bd')
# Out:
# 532it [04:46,  1.86it/s]

# %%
report_geocoding(records)
# Out:
# <style type="text/css">
# </style>
# <table id="T_bb423_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >count</th>
#       <th class="col_heading level0 col1" >pct</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >geocoding_method</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bb423_level0_row0" class="row_heading level0 row0" >Location from Health Sites IO and within admin 1</th>
#       <td id="T_bb423_row0_col0" class="data row0 col0" >207</td>
#       <td id="T_bb423_row0_col1" class="data row0 col1" >1.5%</td>
#     </tr>
#     <tr>
#       <th id="T_bb423_level0_row1" class="row_heading level0 row1" >Location from Health Sites IO and within admin 2</th>
#       <td id="T_bb423_row1_col0" class="data row1 col0" >7</td>
#       <td id="T_bb423_row1_col1" class="data row1 col1" >0.1%</td>
#     </tr>
#     <tr>
#       <th id="T_bb423_level0_row2" class="row_heading level0 row2" >NAME and adm1 query Bing</th>
#       <td id="T_bb423_row2_col0" class="data row2 col0" >2</td>
#       <td id="T_bb423_row2_col1" class="data row2 col1" >0.0%</td>
#     </tr>
#     <tr>
#       <th id="T_bb423_level0_row3" class="row_heading level0 row3" >NAME and adm1 query Google</th>
#       <td id="T_bb423_row3_col0" class="data row3 col0" >3</td>
#       <td id="T_bb423_row3_col1" class="data row3 col1" >0.0%</td>
#     </tr>
#     <tr>
#       <th id="T_bb423_level0_row4" class="row_heading level0 row4" >NAME and adm2 query Bing</th>
#       <td id="T_bb423_row4_col0" class="data row4 col0" >81</td>
#       <td id="T_bb423_row4_col1" class="data row4 col1" >0.6%</td>
#     </tr>
#     <tr>
#       <th id="T_bb423_level0_row5" class="row_heading level0 row5" >NAME and adm2 query Google</th>
#       <td id="T_bb423_row5_col0" class="data row5 col0" >66</td>
#       <td id="T_bb423_row5_col1" class="data row5 col1" >0.5%</td>
#     </tr>
#     <tr>
#       <th id="T_bb423_level0_row6" class="row_heading level0 row6" >NAME and adm2 query OSM</th>
#       <td id="T_bb423_row6_col0" class="data row6 col0" >4</td>
#       <td id="T_bb423_row6_col1" class="data row6 col1" >0.0%</td>
#     </tr>
#     <tr>
#       <th id="T_bb423_level0_row7" class="row_heading level0 row7" >NAME and adm3 query Bing</th>
#       <td id="T_bb423_row7_col0" class="data row7 col0" >6797</td>
#       <td id="T_bb423_row7_col1" class="data row7 col1" >49.2%</td>
#     </tr>
#     <tr>
#       <th id="T_bb423_level0_row8" class="row_heading level0 row8" >NAME and adm3 query Google</th>
#       <td id="T_bb423_row8_col0" class="data row8 col0" >5288</td>
#       <td id="T_bb423_row8_col1" class="data row8 col1" >38.3%</td>
#     </tr>
#     <tr>
#       <th id="T_bb423_level0_row9" class="row_heading level0 row9" >NAME and adm3 query OSM</th>
#       <td id="T_bb423_row9_col0" class="data row9 col0" >335</td>
#       <td id="T_bb423_row9_col1" class="data row9 col1" >2.4%</td>
#     </tr>
#     <tr>
#       <th id="T_bb423_level0_row10" class="row_heading level0 row10" >None</th>
#       <td id="T_bb423_row10_col0" class="data row10 col0" >1022</td>
#       <td id="T_bb423_row10_col1" class="data row10 col1" >7.4%</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Orgunitlevel5 names

# %% [markdown]
# Geocode based on orgunitlevel 5 name.
# Check to make sure result falls within admin 3 polygon.

# %%
records_subset = records.loc[records.geocoding_method=="None"].copy()
records_subset = records_subset.loc[~records_subset.adm3.isna()].copy()

# %%
orglev5_df = records_subset[['orgunitlevel5', 'NAME5', 'adm3', 'orgunitlevel1']].drop_duplicates().copy()

# %%
len(orglev5_df)
# Out:
# 366

# %%
for idx, row in tqdm(orglev5_df.iterrows()):
    
    adm3 = geob3.loc[geob3['shapeName'] == row['adm3']].copy()
    run_geocoding(idx, row, orglev5_df, adm3, ['NAME5', 'adm3'], 'bd')
# Out:
# 17it [00:09,  1.79it/s]

# %%
orglev5_df.geocoding_method.value_counts()
# Out:
# NAME5 and adm3 query Google    187
# None                            79
# NAME5 and adm3 query OSM        71
# NAME5 and adm3 query Bing       29
# Name: geocoding_method, dtype: int64

# %%
for idx, row in tqdm(records_subset.iterrows()):
    
    orglev5_geocoded = orglev5_df.loc[orglev5_df['NAME5']==row['NAME5']].iloc[0]    
    records.loc[idx, "longitude"] = orglev5_geocoded.longitude
    records.loc[idx, "latitude"] = orglev5_geocoded.latitude
    records.loc[idx, "geocoding_method"] = orglev5_geocoded.geocoding_method
# Out:
# 527it [00:00, 737.45it/s]

# %%
report_geocoding(records)
# Out:
# <style type="text/css">
# </style>
# <table id="T_abba2_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >count</th>
#       <th class="col_heading level0 col1" >pct</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >geocoding_method</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_abba2_level0_row0" class="row_heading level0 row0" >Location from Health Sites IO and within admin 1</th>
#       <td id="T_abba2_row0_col0" class="data row0 col0" >207</td>
#       <td id="T_abba2_row0_col1" class="data row0 col1" >1.5%</td>
#     </tr>
#     <tr>
#       <th id="T_abba2_level0_row1" class="row_heading level0 row1" >Location from Health Sites IO and within admin 2</th>
#       <td id="T_abba2_row1_col0" class="data row1 col0" >7</td>
#       <td id="T_abba2_row1_col1" class="data row1 col1" >0.1%</td>
#     </tr>
#     <tr>
#       <th id="T_abba2_level0_row2" class="row_heading level0 row2" >NAME and adm1 query Bing</th>
#       <td id="T_abba2_row2_col0" class="data row2 col0" >2</td>
#       <td id="T_abba2_row2_col1" class="data row2 col1" >0.0%</td>
#     </tr>
#     <tr>
#       <th id="T_abba2_level0_row3" class="row_heading level0 row3" >NAME and adm1 query Google</th>
#       <td id="T_abba2_row3_col0" class="data row3 col0" >3</td>
#       <td id="T_abba2_row3_col1" class="data row3 col1" >0.0%</td>
#     </tr>
#     <tr>
#       <th id="T_abba2_level0_row4" class="row_heading level0 row4" >NAME and adm2 query Bing</th>
#       <td id="T_abba2_row4_col0" class="data row4 col0" >81</td>
#       <td id="T_abba2_row4_col1" class="data row4 col1" >0.6%</td>
#     </tr>
#     <tr>
#       <th id="T_abba2_level0_row5" class="row_heading level0 row5" >NAME and adm2 query Google</th>
#       <td id="T_abba2_row5_col0" class="data row5 col0" >66</td>
#       <td id="T_abba2_row5_col1" class="data row5 col1" >0.5%</td>
#     </tr>
#     <tr>
#       <th id="T_abba2_level0_row6" class="row_heading level0 row6" >NAME and adm2 query OSM</th>
#       <td id="T_abba2_row6_col0" class="data row6 col0" >4</td>
#       <td id="T_abba2_row6_col1" class="data row6 col1" >0.0%</td>
#     </tr>
#     <tr>
#       <th id="T_abba2_level0_row7" class="row_heading level0 row7" >NAME and adm3 query Bing</th>
#       <td id="T_abba2_row7_col0" class="data row7 col0" >6797</td>
#       <td id="T_abba2_row7_col1" class="data row7 col1" >49.2%</td>
#     </tr>
#     <tr>
#       <th id="T_abba2_level0_row8" class="row_heading level0 row8" >NAME and adm3 query Google</th>
#       <td id="T_abba2_row8_col0" class="data row8 col0" >5288</td>
#       <td id="T_abba2_row8_col1" class="data row8 col1" >38.3%</td>
#     </tr>
#     <tr>
#       <th id="T_abba2_level0_row9" class="row_heading level0 row9" >NAME and adm3 query OSM</th>
#       <td id="T_abba2_row9_col0" class="data row9 col0" >335</td>
#       <td id="T_abba2_row9_col1" class="data row9 col1" >2.4%</td>
#     </tr>
#     <tr>
#       <th id="T_abba2_level0_row10" class="row_heading level0 row10" >NAME5 and adm3 query Bing</th>
#       <td id="T_abba2_row10_col0" class="data row10 col0" >31</td>
#       <td id="T_abba2_row10_col1" class="data row10 col1" >0.2%</td>
#     </tr>
#     <tr>
#       <th id="T_abba2_level0_row11" class="row_heading level0 row11" >NAME5 and adm3 query Google</th>
#       <td id="T_abba2_row11_col0" class="data row11 col0" >234</td>
#       <td id="T_abba2_row11_col1" class="data row11 col1" >1.7%</td>
#     </tr>
#     <tr>
#       <th id="T_abba2_level0_row12" class="row_heading level0 row12" >NAME5 and adm3 query OSM</th>
#       <td id="T_abba2_row12_col0" class="data row12 col0" >92</td>
#       <td id="T_abba2_row12_col1" class="data row12 col1" >0.7%</td>
#     </tr>
#     <tr>
#       <th id="T_abba2_level0_row13" class="row_heading level0 row13" >None</th>
#       <td id="T_abba2_row13_col0" class="data row13 col0" >665</td>
#       <td id="T_abba2_row13_col1" class="data row13 col1" >4.8%</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Orgunitlevel4 names

# %%
records_subset = records.loc[records.geocoding_method=="None"].copy()
records_subset = records_subset.loc[~records_subset.adm3.isna()].copy()

# %%
len(records_subset)
# Out:
# 170

# %%
orglev4_df = records_subset[['orgunitlevel4', 'adm3', 'orgunitlevel1']].drop_duplicates().copy()

# %%
len(orglev4_df)
# Out:
# 18

# %%
for idx, row in tqdm(orglev4_df.iterrows()):
    
    adm3 = geob3.loc[geob3['shapeName'] == row['adm3']].copy()
    run_geocoding(idx, row, orglev4_df, adm3, ['orgunitlevel4'], 'bd')
# Out:
# 18it [00:12,  1.45it/s]

# %%
for idx, row in tqdm(orglev4_df.iterrows()):
    
    adm3 = geob3.loc[geob3['shapeName'] == row['adm3']].copy()
    if row.geocoding_method=="None":
        cent = adm3.geometry.representative_point().iloc[0]
        orglev4_df.loc[idx, "longitude"] = cent.x
        orglev4_df.loc[idx, "latitude"] = cent.y
        orglev4_df.loc[idx, "geocoding_method"] = "District centroid"
# Out:
# 18it [00:00, 526.89it/s]

# %%
orglev4_df.geocoding_method
# Out:
# 1662        orgunitlevel4 query OSM
# 2277              District centroid
# 8308              District centroid
# 10337    orgunitlevel4 query Google
# 10879             District centroid
# 11092             District centroid
# 11204    orgunitlevel4 query Google
# 11672    orgunitlevel4 query Google
# 11990    orgunitlevel4 query Google
# 13211       orgunitlevel4 query OSM
# 14249    orgunitlevel4 query Google
# 15254       orgunitlevel4 query OSM
# 15364       orgunitlevel4 query OSM
# 15705    orgunitlevel4 query Google
# 16909    orgunitlevel4 query Google
# 17586             District centroid
# 18013    orgunitlevel4 query Google
# 19263    orgunitlevel4 query Google
# Name: geocoding_method, dtype: object

# %%
for idx, row in tqdm(records_subset.iterrows()):
    
    orglev4_geocoded = orglev4_df.loc[orglev4_df['orgunitlevel4']==row['orgunitlevel4']].iloc[0]    
    records.loc[idx, "longitude"] = orglev4_geocoded.longitude
    records.loc[idx, "latitude"] = orglev4_geocoded.latitude
    records.loc[idx, "geocoding_method"] = orglev4_geocoded.geocoding_method
# Out:
# 170it [00:00, 711.41it/s]

# %% [markdown]
# ## Admin 3  and admin 2 names

# %%
records_subset = records.loc[records.geocoding_method=="None"].copy()
records_subset = records_subset.loc[~records_subset.adm2.isna()].copy()

# %%
len(records_subset)
# Out:
# 399

# %% [markdown]
# Geocode based on admin 3 name and admin 2 name.
# Check to make sure result falls within admin 2 polygon.

# %%
orglev4_df = records_subset[['orgunitlevel4', 'orgunitlevel4_edit', 'adm2', 'orgunitlevel1']].drop_duplicates().copy()

# %%
len(orglev4_df)
# Out:
# 12

# %%
for idx, row in tqdm(orglev4_df.iterrows()):
    
    adm2 = geob2.loc[geob2['shapeName'] == row['adm2']].copy()
    run_geocoding(idx, row, orglev4_df, adm2, ['orgunitlevel4', 'adm2'], 'bd')
# Out:
# 12it [00:06,  1.98it/s]

# %%
for idx, row in tqdm(records_subset.iterrows()):
    
    orglev4_geocoded = orglev4_df.loc[orglev4_df['orgunitlevel4']==row['orgunitlevel4']].iloc[0]    
    records.loc[idx, "longitude"] = orglev4_geocoded.longitude
    records.loc[idx, "latitude"] = orglev4_geocoded.latitude
    records.loc[idx, "geocoding_method"] = orglev4_geocoded.geocoding_method
# Out:
# 399it [00:00, 749.65it/s]

# %%
report_geocoding(records)
# Out:
# <style type="text/css">
# </style>
# <table id="T_cacd1_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >count</th>
#       <th class="col_heading level0 col1" >pct</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >geocoding_method</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cacd1_level0_row0" class="row_heading level0 row0" >District centroid</th>
#       <td id="T_cacd1_row0_col0" class="data row0 col0" >83</td>
#       <td id="T_cacd1_row0_col1" class="data row0 col1" >0.6%</td>
#     </tr>
#     <tr>
#       <th id="T_cacd1_level0_row1" class="row_heading level0 row1" >Location from Health Sites IO and within admin 1</th>
#       <td id="T_cacd1_row1_col0" class="data row1 col0" >207</td>
#       <td id="T_cacd1_row1_col1" class="data row1 col1" >1.5%</td>
#     </tr>
#     <tr>
#       <th id="T_cacd1_level0_row2" class="row_heading level0 row2" >Location from Health Sites IO and within admin 2</th>
#       <td id="T_cacd1_row2_col0" class="data row2 col0" >7</td>
#       <td id="T_cacd1_row2_col1" class="data row2 col1" >0.1%</td>
#     </tr>
#     <tr>
#       <th id="T_cacd1_level0_row3" class="row_heading level0 row3" >NAME and adm1 query Bing</th>
#       <td id="T_cacd1_row3_col0" class="data row3 col0" >2</td>
#       <td id="T_cacd1_row3_col1" class="data row3 col1" >0.0%</td>
#     </tr>
#     <tr>
#       <th id="T_cacd1_level0_row4" class="row_heading level0 row4" >NAME and adm1 query Google</th>
#       <td id="T_cacd1_row4_col0" class="data row4 col0" >3</td>
#       <td id="T_cacd1_row4_col1" class="data row4 col1" >0.0%</td>
#     </tr>
#     <tr>
#       <th id="T_cacd1_level0_row5" class="row_heading level0 row5" >NAME and adm2 query Bing</th>
#       <td id="T_cacd1_row5_col0" class="data row5 col0" >81</td>
#       <td id="T_cacd1_row5_col1" class="data row5 col1" >0.6%</td>
#     </tr>
#     <tr>
#       <th id="T_cacd1_level0_row6" class="row_heading level0 row6" >NAME and adm2 query Google</th>
#       <td id="T_cacd1_row6_col0" class="data row6 col0" >66</td>
#       <td id="T_cacd1_row6_col1" class="data row6 col1" >0.5%</td>
#     </tr>
#     <tr>
#       <th id="T_cacd1_level0_row7" class="row_heading level0 row7" >NAME and adm2 query OSM</th>
#       <td id="T_cacd1_row7_col0" class="data row7 col0" >4</td>
#       <td id="T_cacd1_row7_col1" class="data row7 col1" >0.0%</td>
#     </tr>
#     <tr>
#       <th id="T_cacd1_level0_row8" class="row_heading level0 row8" >NAME and adm3 query Bing</th>
#       <td id="T_cacd1_row8_col0" class="data row8 col0" >6797</td>
#       <td id="T_cacd1_row8_col1" class="data row8 col1" >49.2%</td>
#     </tr>
#     <tr>
#       <th id="T_cacd1_level0_row9" class="row_heading level0 row9" >NAME and adm3 query Google</th>
#       <td id="T_cacd1_row9_col0" class="data row9 col0" >5288</td>
#       <td id="T_cacd1_row9_col1" class="data row9 col1" >38.3%</td>
#     </tr>
#     <tr>
#       <th id="T_cacd1_level0_row10" class="row_heading level0 row10" >NAME and adm3 query OSM</th>
#       <td id="T_cacd1_row10_col0" class="data row10 col0" >335</td>
#       <td id="T_cacd1_row10_col1" class="data row10 col1" >2.4%</td>
#     </tr>
#     <tr>
#       <th id="T_cacd1_level0_row11" class="row_heading level0 row11" >NAME5 and adm3 query Bing</th>
#       <td id="T_cacd1_row11_col0" class="data row11 col0" >31</td>
#       <td id="T_cacd1_row11_col1" class="data row11 col1" >0.2%</td>
#     </tr>
#     <tr>
#       <th id="T_cacd1_level0_row12" class="row_heading level0 row12" >NAME5 and adm3 query Google</th>
#       <td id="T_cacd1_row12_col0" class="data row12 col0" >234</td>
#       <td id="T_cacd1_row12_col1" class="data row12 col1" >1.7%</td>
#     </tr>
#     <tr>
#       <th id="T_cacd1_level0_row13" class="row_heading level0 row13" >NAME5 and adm3 query OSM</th>
#       <td id="T_cacd1_row13_col0" class="data row13 col0" >92</td>
#       <td id="T_cacd1_row13_col1" class="data row13 col1" >0.7%</td>
#     </tr>
#     <tr>
#       <th id="T_cacd1_level0_row14" class="row_heading level0 row14" >None</th>
#       <td id="T_cacd1_row14_col0" class="data row14 col0" >96</td>
#       <td id="T_cacd1_row14_col1" class="data row14 col1" >0.7%</td>
#     </tr>
#     <tr>
#       <th id="T_cacd1_level0_row15" class="row_heading level0 row15" >orgunitlevel4 and adm2 query Bing</th>
#       <td id="T_cacd1_row15_col0" class="data row15 col0" >160</td>
#       <td id="T_cacd1_row15_col1" class="data row15 col1" >1.2%</td>
#     </tr>
#     <tr>
#       <th id="T_cacd1_level0_row16" class="row_heading level0 row16" >orgunitlevel4 and adm2 query Google</th>
#       <td id="T_cacd1_row16_col0" class="data row16 col0" >46</td>
#       <td id="T_cacd1_row16_col1" class="data row16 col1" >0.3%</td>
#     </tr>
#     <tr>
#       <th id="T_cacd1_level0_row17" class="row_heading level0 row17" >orgunitlevel4 and adm2 query OSM</th>
#       <td id="T_cacd1_row17_col0" class="data row17 col0" >193</td>
#       <td id="T_cacd1_row17_col1" class="data row17 col1" >1.4%</td>
#     </tr>
#     <tr>
#       <th id="T_cacd1_level0_row18" class="row_heading level0 row18" >orgunitlevel4 query Google</th>
#       <td id="T_cacd1_row18_col0" class="data row18 col0" >78</td>
#       <td id="T_cacd1_row18_col1" class="data row18 col1" >0.6%</td>
#     </tr>
#     <tr>
#       <th id="T_cacd1_level0_row19" class="row_heading level0 row19" >orgunitlevel4 query OSM</th>
#       <td id="T_cacd1_row19_col0" class="data row19 col0" >9</td>
#       <td id="T_cacd1_row19_col1" class="data row19 col1" >0.1%</td>
#     </tr>
#   </tbody>
# </table>

# %%
records_subset = records.loc[records.geocoding_method=="None"].copy()
records_subset = records_subset.loc[~records_subset.adm1.isna()].copy()

# %%
len(records_subset)
# Out:
# 96

# %% [markdown]
# ## Admin 3  and admin 1 names

# %%
orglev4_df = records_subset[['orgunitlevel4', 'orgunitlevel4_edit', 'adm1', 'orgunitlevel1']].drop_duplicates().copy()

# %%
for idx, row in tqdm(orglev4_df.iterrows()):
    
    adm1 = geob1.loc[geob1['shapeName'] == row['adm1']].copy()
    run_geocoding(idx, row, orglev4_df, adm1, ['orgunitlevel4', 'adm1'], 'bd')
# Out:
# 2it [00:00,  2.14it/s]

# %%
for idx, row in tqdm(records_subset.iterrows()):
    
    orglev4_geocoded = orglev4_df.loc[orglev4_df['orgunitlevel4']==row['orgunitlevel4']].iloc[0]    
    records.loc[idx, "longitude"] = orglev4_geocoded.longitude
    records.loc[idx, "latitude"] = orglev4_geocoded.latitude
    records.loc[idx, "geocoding_method"] = orglev4_geocoded.geocoding_method
# Out:
# 96it [00:00, 746.91it/s]

# %%
report_geocoding(records)
# Out:
# <style type="text/css">
# </style>
# <table id="T_6438f_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >count</th>
#       <th class="col_heading level0 col1" >pct</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >geocoding_method</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6438f_level0_row0" class="row_heading level0 row0" >District centroid</th>
#       <td id="T_6438f_row0_col0" class="data row0 col0" >83</td>
#       <td id="T_6438f_row0_col1" class="data row0 col1" >0.6%</td>
#     </tr>
#     <tr>
#       <th id="T_6438f_level0_row1" class="row_heading level0 row1" >Location from Health Sites IO and within admin 1</th>
#       <td id="T_6438f_row1_col0" class="data row1 col0" >207</td>
#       <td id="T_6438f_row1_col1" class="data row1 col1" >1.5%</td>
#     </tr>
#     <tr>
#       <th id="T_6438f_level0_row2" class="row_heading level0 row2" >Location from Health Sites IO and within admin 2</th>
#       <td id="T_6438f_row2_col0" class="data row2 col0" >7</td>
#       <td id="T_6438f_row2_col1" class="data row2 col1" >0.1%</td>
#     </tr>
#     <tr>
#       <th id="T_6438f_level0_row3" class="row_heading level0 row3" >NAME and adm1 query Bing</th>
#       <td id="T_6438f_row3_col0" class="data row3 col0" >2</td>
#       <td id="T_6438f_row3_col1" class="data row3 col1" >0.0%</td>
#     </tr>
#     <tr>
#       <th id="T_6438f_level0_row4" class="row_heading level0 row4" >NAME and adm1 query Google</th>
#       <td id="T_6438f_row4_col0" class="data row4 col0" >3</td>
#       <td id="T_6438f_row4_col1" class="data row4 col1" >0.0%</td>
#     </tr>
#     <tr>
#       <th id="T_6438f_level0_row5" class="row_heading level0 row5" >NAME and adm2 query Bing</th>
#       <td id="T_6438f_row5_col0" class="data row5 col0" >81</td>
#       <td id="T_6438f_row5_col1" class="data row5 col1" >0.6%</td>
#     </tr>
#     <tr>
#       <th id="T_6438f_level0_row6" class="row_heading level0 row6" >NAME and adm2 query Google</th>
#       <td id="T_6438f_row6_col0" class="data row6 col0" >66</td>
#       <td id="T_6438f_row6_col1" class="data row6 col1" >0.5%</td>
#     </tr>
#     <tr>
#       <th id="T_6438f_level0_row7" class="row_heading level0 row7" >NAME and adm2 query OSM</th>
#       <td id="T_6438f_row7_col0" class="data row7 col0" >4</td>
#       <td id="T_6438f_row7_col1" class="data row7 col1" >0.0%</td>
#     </tr>
#     <tr>
#       <th id="T_6438f_level0_row8" class="row_heading level0 row8" >NAME and adm3 query Bing</th>
#       <td id="T_6438f_row8_col0" class="data row8 col0" >6797</td>
#       <td id="T_6438f_row8_col1" class="data row8 col1" >49.2%</td>
#     </tr>
#     <tr>
#       <th id="T_6438f_level0_row9" class="row_heading level0 row9" >NAME and adm3 query Google</th>
#       <td id="T_6438f_row9_col0" class="data row9 col0" >5288</td>
#       <td id="T_6438f_row9_col1" class="data row9 col1" >38.3%</td>
#     </tr>
#     <tr>
#       <th id="T_6438f_level0_row10" class="row_heading level0 row10" >NAME and adm3 query OSM</th>
#       <td id="T_6438f_row10_col0" class="data row10 col0" >335</td>
#       <td id="T_6438f_row10_col1" class="data row10 col1" >2.4%</td>
#     </tr>
#     <tr>
#       <th id="T_6438f_level0_row11" class="row_heading level0 row11" >NAME5 and adm3 query Bing</th>
#       <td id="T_6438f_row11_col0" class="data row11 col0" >31</td>
#       <td id="T_6438f_row11_col1" class="data row11 col1" >0.2%</td>
#     </tr>
#     <tr>
#       <th id="T_6438f_level0_row12" class="row_heading level0 row12" >NAME5 and adm3 query Google</th>
#       <td id="T_6438f_row12_col0" class="data row12 col0" >234</td>
#       <td id="T_6438f_row12_col1" class="data row12 col1" >1.7%</td>
#     </tr>
#     <tr>
#       <th id="T_6438f_level0_row13" class="row_heading level0 row13" >NAME5 and adm3 query OSM</th>
#       <td id="T_6438f_row13_col0" class="data row13 col0" >92</td>
#       <td id="T_6438f_row13_col1" class="data row13 col1" >0.7%</td>
#     </tr>
#     <tr>
#       <th id="T_6438f_level0_row14" class="row_heading level0 row14" >orgunitlevel4 and adm1 query Bing</th>
#       <td id="T_6438f_row14_col0" class="data row14 col0" >36</td>
#       <td id="T_6438f_row14_col1" class="data row14 col1" >0.3%</td>
#     </tr>
#     <tr>
#       <th id="T_6438f_level0_row15" class="row_heading level0 row15" >orgunitlevel4 and adm1 query OSM</th>
#       <td id="T_6438f_row15_col0" class="data row15 col0" >60</td>
#       <td id="T_6438f_row15_col1" class="data row15 col1" >0.4%</td>
#     </tr>
#     <tr>
#       <th id="T_6438f_level0_row16" class="row_heading level0 row16" >orgunitlevel4 and adm2 query Bing</th>
#       <td id="T_6438f_row16_col0" class="data row16 col0" >160</td>
#       <td id="T_6438f_row16_col1" class="data row16 col1" >1.2%</td>
#     </tr>
#     <tr>
#       <th id="T_6438f_level0_row17" class="row_heading level0 row17" >orgunitlevel4 and adm2 query Google</th>
#       <td id="T_6438f_row17_col0" class="data row17 col0" >46</td>
#       <td id="T_6438f_row17_col1" class="data row17 col1" >0.3%</td>
#     </tr>
#     <tr>
#       <th id="T_6438f_level0_row18" class="row_heading level0 row18" >orgunitlevel4 and adm2 query OSM</th>
#       <td id="T_6438f_row18_col0" class="data row18 col0" >193</td>
#       <td id="T_6438f_row18_col1" class="data row18 col1" >1.4%</td>
#     </tr>
#     <tr>
#       <th id="T_6438f_level0_row19" class="row_heading level0 row19" >orgunitlevel4 query Google</th>
#       <td id="T_6438f_row19_col0" class="data row19 col0" >78</td>
#       <td id="T_6438f_row19_col1" class="data row19 col1" >0.6%</td>
#     </tr>
#     <tr>
#       <th id="T_6438f_level0_row20" class="row_heading level0 row20" >orgunitlevel4 query OSM</th>
#       <td id="T_6438f_row20_col0" class="data row20 col0" >9</td>
#       <td id="T_6438f_row20_col1" class="data row20 col1" >0.1%</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # Map and save results

# %%
results = records.copy()

# %%
results.geocoding_method.unique()
# Out:
# array(['NAME and adm3 query Google', 'NAME5 and adm3 query Google',
#        'Location from Health Sites IO and within admin 2',
#        'NAME and adm3 query OSM', 'NAME and adm3 query Bing',
#        'Location from Health Sites IO and within admin 1',
#        'NAME5 and adm3 query Bing', 'NAME5 and adm3 query OSM',
#        'orgunitlevel4 and adm2 query OSM', 'NAME and adm2 query Google',
#        'orgunitlevel4 query OSM', 'NAME and adm2 query Bing',
#        'NAME and adm1 query Bing', 'NAME and adm2 query OSM',
#        'District centroid', 'orgunitlevel4 and adm2 query Google',
#        'orgunitlevel4 and adm2 query Bing', 'NAME and adm1 query Google',
#        'orgunitlevel4 and adm1 query OSM', 'orgunitlevel4 query Google',
#        'orgunitlevel4 and adm1 query Bing'], dtype=object)

# %%
# facility name and adm 3
results.loc[results.geocoding_method=="NAME and adm3 query Bing", "geocoding_method"] = "orgunitlevel6 and adm3 query"
results.loc[results.geocoding_method=="NAME and adm3 query OSM", "geocoding_method"] = "orgunitlevel6 and adm3 query"
results.loc[results.geocoding_method=="NAME and adm3 query Google", "geocoding_method"] = "orgunitlevel6 and adm3 query"

# facility name and adm 2
results.loc[results.geocoding_method=="NAME and adm2 query Bing", "geocoding_method"] = "orgunitlevel6 and adm2 query"
results.loc[results.geocoding_method=="NAME and adm2 query OSM", "geocoding_method"] = "orgunitlevel6 and adm2 query"
results.loc[results.geocoding_method=="NAME and adm2 query Google", "geocoding_method"] = "orgunitlevel6 and adm2 query"

# facility name and adm 1
results.loc[results.geocoding_method=="NAME and adm1 query Bing", "geocoding_method"] = "orgunitlevel6 and adm1 query"
results.loc[results.geocoding_method=="NAME and adm1 query OSM", "geocoding_method"] = "orgunitlevel6 and adm1 query"
results.loc[results.geocoding_method=="NAME and adm1 query Google", "geocoding_method"] = "orgunitlevel6 and adm1 query"

# facility name and adm 3
results.loc[results.geocoding_method=="NAME5 and adm3 query Bing", "geocoding_method"] = "orgunitlevel5 and adm3 query"
results.loc[results.geocoding_method=="NAME5 and adm3 query OSM", "geocoding_method"] = "orgunitlevel5 and adm3 query"
results.loc[results.geocoding_method=="NAME5 and adm3 query Google", "geocoding_method"] = "orgunitlevel5 and adm3 query"

# facility name and adm 2
results.loc[results.geocoding_method=="NAME5 and adm2 query Bing", "geocoding_method"] = "orgunitlevel5 and adm2 query"
results.loc[results.geocoding_method=="NAME5 and adm2 query OSM", "geocoding_method"] = "orgunitlevel5 and adm2 query"
results.loc[results.geocoding_method=="NAME5 and adm2 query Google", "geocoding_method"] = "orgunitlevel5 and adm2 query"

# facility name and adm 1
results.loc[results.geocoding_method=="NAME5 and adm1 query Bing", "geocoding_method"] = "orgunitlevel5 and adm1 query"
results.loc[results.geocoding_method=="NAME5 and adm1 query OSM", "geocoding_method"] = "orgunitlevel5 and adm1 query"
results.loc[results.geocoding_method=="NAME5 and adm1 query Google", "geocoding_method"] = "orgunitlevel5 and adm1 query"

# adm 3 name
results.loc[results.geocoding_method=="orgunitlevel4 query Bing", "geocoding_method"] = "orgunitlevel4 query"
results.loc[results.geocoding_method=="orgunitlevel4 query OSM", "geocoding_method"] = "orgunitlevel4 query"
results.loc[results.geocoding_method=="orgunitlevel4 query Google", "geocoding_method"] = "orgunitlevel4 query"

# adm 3 name and adm2
results.loc[results.geocoding_method=="orgunitlevel4 and adm2 query Bing", "geocoding_method"] = "orgunitlevel4 and adm2 query"
results.loc[results.geocoding_method=="orgunitlevel4 and adm2 query OSM", "geocoding_method"] = "orgunitlevel4 and adm2 query"
results.loc[results.geocoding_method=="orgunitlevel4 and adm2 query Google", "geocoding_method"] = "orgunitlevel4 and adm2 query"

# adm 3 name and adm2
results.loc[results.geocoding_method=="orgunitlevel4 and adm1 query Bing", "geocoding_method"] = "orgunitlevel4 and adm1 query"
results.loc[results.geocoding_method=="orgunitlevel4 and adm1 query OSM", "geocoding_method"] = "orgunitlevel4 and adm1 query"
results.loc[results.geocoding_method=="orgunitlevel4 and adm1 query Google", "geocoding_method"] = "orgunitlevel4 and adm1 query"

# Centroid
results.loc[results.geocoding_method=="District centroid", "geocoding_method"] = "Adm3 centroid"

# %%
report_geocoding(results)
# Out:
# <style type="text/css">
# </style>
# <table id="T_78e48_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >count</th>
#       <th class="col_heading level0 col1" >pct</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >geocoding_method</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_78e48_level0_row0" class="row_heading level0 row0" >Adm3 centroid</th>
#       <td id="T_78e48_row0_col0" class="data row0 col0" >83</td>
#       <td id="T_78e48_row0_col1" class="data row0 col1" >0.6%</td>
#     </tr>
#     <tr>
#       <th id="T_78e48_level0_row1" class="row_heading level0 row1" >Location from Health Sites IO and within admin 1</th>
#       <td id="T_78e48_row1_col0" class="data row1 col0" >207</td>
#       <td id="T_78e48_row1_col1" class="data row1 col1" >1.5%</td>
#     </tr>
#     <tr>
#       <th id="T_78e48_level0_row2" class="row_heading level0 row2" >Location from Health Sites IO and within admin 2</th>
#       <td id="T_78e48_row2_col0" class="data row2 col0" >7</td>
#       <td id="T_78e48_row2_col1" class="data row2 col1" >0.1%</td>
#     </tr>
#     <tr>
#       <th id="T_78e48_level0_row3" class="row_heading level0 row3" >orgunitlevel4 and adm1 query</th>
#       <td id="T_78e48_row3_col0" class="data row3 col0" >96</td>
#       <td id="T_78e48_row3_col1" class="data row3 col1" >0.7%</td>
#     </tr>
#     <tr>
#       <th id="T_78e48_level0_row4" class="row_heading level0 row4" >orgunitlevel4 and adm2 query</th>
#       <td id="T_78e48_row4_col0" class="data row4 col0" >399</td>
#       <td id="T_78e48_row4_col1" class="data row4 col1" >2.9%</td>
#     </tr>
#     <tr>
#       <th id="T_78e48_level0_row5" class="row_heading level0 row5" >orgunitlevel4 query</th>
#       <td id="T_78e48_row5_col0" class="data row5 col0" >87</td>
#       <td id="T_78e48_row5_col1" class="data row5 col1" >0.6%</td>
#     </tr>
#     <tr>
#       <th id="T_78e48_level0_row6" class="row_heading level0 row6" >orgunitlevel5 and adm3 query</th>
#       <td id="T_78e48_row6_col0" class="data row6 col0" >357</td>
#       <td id="T_78e48_row6_col1" class="data row6 col1" >2.6%</td>
#     </tr>
#     <tr>
#       <th id="T_78e48_level0_row7" class="row_heading level0 row7" >orgunitlevel6 and adm1 query</th>
#       <td id="T_78e48_row7_col0" class="data row7 col0" >5</td>
#       <td id="T_78e48_row7_col1" class="data row7 col1" >0.0%</td>
#     </tr>
#     <tr>
#       <th id="T_78e48_level0_row8" class="row_heading level0 row8" >orgunitlevel6 and adm2 query</th>
#       <td id="T_78e48_row8_col0" class="data row8 col0" >151</td>
#       <td id="T_78e48_row8_col1" class="data row8 col1" >1.1%</td>
#     </tr>
#     <tr>
#       <th id="T_78e48_level0_row9" class="row_heading level0 row9" >orgunitlevel6 and adm3 query</th>
#       <td id="T_78e48_row9_col0" class="data row9 col0" >12420</td>
#       <td id="T_78e48_row9_col1" class="data row9 col1" >89.9%</td>
#     </tr>
#   </tbody>
# </table>

# %%
results.loc[:, "geometry"] = results.apply(lambda x: Point(x.longitude, x.latitude), axis=1)
results = gpd.GeoDataFrame(results, geometry='geometry', crs='EPSG:4326')

# %%
fig, ax = plt.subplots(1, 1, figsize=(10,10))
geob3.boundary.plot(ax=ax, color='black', linewidth=1).set_axis_off()
results.loc[results.geocoding_method!="None"].plot(ax=ax, column='geocoding_method', edgecolor='white', markersize=50, alpha=0.75, legend=True)
ctx.add_basemap(ax, source=ctx.providers.Stamen.Terrain, crs='EPSG:4326', zorder=-10)

# %% [markdown]
# ## Join attributes from adminsitrative polygons

# %% [markdown]
# Join admin data back to results.
# For adm3 features, use spatial join to geob3.

# %%
results2 = results.loc[~(results.longitude.isna())].copy()

# %%
records_subset = records.loc[records.geocoding_method=="None"].copy()

# %%
len(records_subset)
# Out:
# 0

# %%
results2 = gpd.sjoin(results2, geob3[["shapeName", "shapeID", "geometry"]], how='left', predicate='intersects')
results2.drop('index_right', axis=1, inplace=True)

# %%
results2.rename(
    columns={
        'shapeName':'geob_adm3',
        'shapeID':'geob_adm3_id',
    }, inplace=True)

# %%
results2 = gpd.sjoin(results2, geob2[["shapeName", "shapeID", "geometry"]], how='left', predicate='intersects')
results2.drop('index_right', axis=1, inplace=True)

# %%
results2.rename(
    columns={
        'shapeName':'geob_adm2',
        'shapeID':'geob_adm2_id',
    }, inplace=True)

# %%
results2 = gpd.sjoin(results2, geob1[["shapeName", "shapeID", "geometry"]], how='left', predicate='intersects')
results2.drop('index_right', axis=1, inplace=True)

# %%
results2.rename(
    columns={
        'shapeName':'geob_adm1',
        'shapeID':'geob_adm1_id',
    }, inplace=True)

# %%
results2.geob_adm3.isna().sum(), results2.geob_adm2.isna().sum(), results2.geob_adm1.isna().sum()
# Out:
# (0, 0, 119)

# %%
results2.rename(
    columns={
        'adm1':'fuzzy_match_adm1',
        'adm2':'fuzzy_match_adm2',
        'adm3':'fuzzy_match_adm3'
    }, inplace=True)

# %%
results_final = results2.copy()

# %%
# results_final = pd.concat([results2, records_subset])
# results_final.sort_index(inplace=True)

results_final.to_csv(join(output_dir, "BGD_geocoding_1.24.23.csv"))
results_final.to_file(join(output_dir, "BGD_geocoding_1.24.23.json"), driver="GeoJSON")
